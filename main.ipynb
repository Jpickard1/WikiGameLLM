# %% [markdown]
# # Code to Play

# %%
import os
import numpy as np
import pandas as pd
import getpass
import difflib
import requests
import random
import string
import wikipediaapi
import logging

from bs4 import BeautifulSoup
from sentence_transformers import SentenceTransformer
from scipy.spatial.distance import cosine

from langchain_nvidia_ai_endpoints import NVIDIAEmbeddings, ChatNVIDIA
from langchain.memory import ConversationBufferMemory

# %%
log = logging.getLogger(__name__)
logging.basicConfig(level=os.environ.get("LOGLEVEL", "INFO"))
log.info('What is up?!')
# Out:
# INFO:__main__:What is up?!

# %% [markdown]
# ## Funcs

# %%
def get_page_summary(wiki_page):
    """
    Retrieves a brief summary of a given Wikipedia page.

    This function takes a Wikipedia page object and returns the summary of the page. However, rather than 
    returning the entire summary, it returns only the first few lines. This is particularly useful for 
    getting a quick overview or introduction to the page's content without needing to process the entire 
    summary text.

    Parameters
    ----------
    wiki_page : WikipediaPage object
        A Wikipedia page object from which the summary is to be extracted. The object should have a 'summary' 
        attribute containing the text of the page's summary.

    Returns
    -------
    str
        A string containing the first few lines of the Wikipedia page's summary. The exact number of lines 
        returned is set to 5 in this implementation.
    """
    # return just the first few lines if there are multiple
    return wiki_page.summary[:100] + "..."
    # return ". ".join(wiki_page.summary.split("\n")[:1]) + "..."

def search_wiki(search_term):
    """Search common name for search term and returns most relevant Wiki Page"""
    search_url = f"https://en.wikipedia.org/w/index.php?search={'+'.join(search_term.split())}&title=Special:Search&profile=advanced&fulltext=1&ns0=1"
    soup = BeautifulSoup(requests.get(search_url, timeout=30).content, "html.parser")
    bad_prefixes = ["list of", "history of", "Template:", "Wikipedia:", "Category:", "Portal:", "Talk:", "Template talk:"]
    for result in soup.find_all("div", class_ = "mw-search-result-heading"):
        if result.a:
            if result.a['href']:
                text = result.a['href'].replace("/wiki/", "").strip()
                starts_with_bad_prefix = any(text.lower().replace("_", " ").startswith(prefix.lower()) for prefix in bad_prefixes)
                if not starts_with_bad_prefix:
                    return text

def getWikiTemplate():
    template = """You must are playing the Wikipedia Game where you must find a chain of
Wikipedia pages that connect a source topic to a target topic. Your current topic is {current} and
you must select a new wikipedia page closer to the target topic {target1}. You can select a topic from
the following list:

{{links}}

If the target topic of {target2} is available, you should select the target topic {target3}. Otherwise, select
a next topic that is likely to be closer or fewer connections to the topic {target4}. Format your output as:
Next topic=<topic here>
"""
    return template

# %%
search_wiki('python programming langugae')
# Out:
# 'Python_(programming_language)'

# %% [markdown]
# ## LLM Bot

# %%
class WikiGameLLMBot():
    def __init__(self, wiki_wiki,
                 start_topic = None,
                 target_topic = None,
                 model_name='meta/llama3-70b-instruct',
                 temperature=0.1):

        assert start_topic != target_topic, "Please enter different start and target topics."
        
        ################################################################
        #
        #    Save some things
        #
        ################################################################
        
        self.wiki_wiki     = wiki_wiki
        self.start_topic   = start_topic
        self.target_topic  = target_topic
        self.target_page   = self.wiki_wiki.page(self.target_topic)
        self.start_page    = self.wiki_wiki.page(self.start_topic)
        self.current_topic = self.start_page
        self.current_page  = self.start_page
        self.visited       = [self.start_page]

        ################################################################
        #
        #    Load NVIDIA model and chatbot history
        #
        ################################################################

        if not os.environ.get("NVIDIA_API_KEY", "").startswith("nvapi-"):
            nvidia_api_key = getpass.getpass("Enter your NVIDIA API key: ")
            assert nvidia_api_key.startswith("nvapi-"), f"{nvidia_api_key[:5]}... is not a valid key"
            os.environ["NVIDIA_API_KEY"] = nvidia_api_key
        else:
            nvidia_api_key = os.environ["NVIDIA_API_KEY"]
            
        self.llm = ChatNVIDIA(model       = model_name,
                              api_key     = nvidia_api_key,
                              temperature = temperature,
                             )
        self.memory = ConversationBufferMemory(ai_prefix="System")

    def get_filled_templates(self, alltitles, allsummaries):
        i = 0
        k = 100 # batch size
        templates, titles, summaries  = [], [], []
        while i < len(alltitles):
            titlesTemplate    = alltitles[i:i+k]
            summariesTemplate = allsummaries[i:i+k]
            titles.append(titlesTemplate)
            summaries.append(summariesTemplate)
            templates.append(self.get_filled_template(titlesTemplate, summariesTemplate))
            i += k
        return templates, titles, summaries
    
    def get_filled_template(self, titles, summaries):
        template = getWikiTemplate()
        template = template.format(target1 = self.target_topic,
                                   target2 = self.target_topic,
                                   target3 = self.target_topic,
                                   target4 = self.target_topic,
                                   current = self.current_topic,
                                  )
        link_table = """Topic\tDescription
--------\t\t\t-----------
"""
        for i in range(len(titles)):
            link_table += ("title:" + titles[i] + '\t' + summaries[i] + '\n')

        template = template.format(links = link_table)
        return template
    
    def take_turn(self):
        # Get all linked pages
        print(type(self.current_page))
        page_titles = list(self.current_page.links)

        badpages = ['Category', 'Help', 'Wikipedia', 'Portal', 'List', 'Talk', 'Template']
        badpages_lower = [bad.lower() for bad in badpages]
        page_titles = [title for title in page_titles if not any(title.lower().startswith(bad) for bad in badpages_lower)]
        
        pages = []

        print('Got all titles')
        for i, title in enumerate(page_titles):
            print(title + '\t\t' + str(i) + '/' + str(len(page_titles)))
            pages.append(self.wiki_wiki.page(title))

        # get the summaries of these pages
        titles, summaries = [], []
        page_title_lookup = {}
        for page in pages:
            titles.append(page.title)
            summaries.append(get_page_summary(page))
            page_title_lookup[page.title] = page

        templates, titleSets, summarySets = self.get_filled_templates(titles, summaries)
        bestTitles, bestSummaries = [], []
        for i, template in enumerate(templates):
            print("Template")
            log.info(template)
    
            response = self.llm.invoke(template)
            print("Response")
            print(response)
    
            print("Parsed Response")
            proposedPage = response.content.split('=')[1]
            print(proposedPage)
            
            print("Most similar page")
            most_similar = difflib.get_close_matches(proposedPage, titleSets[i], n=1)[0]
            log.info(most_similar)
            bestTitles.append(most_similar)
            bestSummaries.append(get_page_summary(page_title_lookup[most_similar]))

        # reduce it further
        if len(bestTitles) > 1:
            template = self.get_filled_template(bestTitles, bestSummaries)
            log.info(template)
            response = self.llm.invoke(template)
            
            print("Response")
            print(response)
    
            print("Parsed Response")
            proposedPage = response.content.split('=')[1]
            print(proposedPage)
            
            print("Most similar page")
            most_similar = difflib.get_close_matches(proposedPage, bestTitles, n=1)[0]
        else:
            most_similar = bestTitles[0]
            
        # reset the current page
        log.info(most_similar)
        self.current_page = page_title_lookup[most_similar]
        
        if self.target_page.fullurl == self.current_page.fullurl:
            return True

        return False

# %% [markdown]
# # Play Game

# %%
global wiki_wiki
random_string = 'XXX' # generate_random_string(10)
wiki_wiki = wikipediaapi.Wikipedia(
    f'WikiBot-{random_string} (https://www.linkedin.com/in/kmaurinjones/)',
    'en',
    timeout = 30
    )
# Out:
# INFO:wikipediaapi:Wikipedia: language=en, user_agent: WikiBot-XXX (https://www.linkedin.com/in/kmaurinjones/) (Wikipedia-API/0.6.0; https://github.com/martin-majlis/Wikipedia-API/), extract_format=1

# %%
bot = WikiGameLLMBot(wiki_wiki,
                 start_topic = 'CRISPE',
                 target_topic = 'Israel',
                 model_name='meta/llama3-70b-instruct',
                 temperature=0.1)
# Out:
# Enter your NVIDIA API key:  ········

# %%
found = False
i = 0
while not found:
    found = bot.take_turn()
    print(bot.current_page.title)
    i += 1
    if i > 5:
        break
# Out:
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=links&titles=Kayvan Najarian&pllimit=500
# <class 'wikipediaapi.WikipediaPage'>
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Amirkabir University of Technology&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=CRC Press&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=ISBN (identifier)&explaintext=1&exsectionformat=wiki
# Got all titles
# Amirkabir University of Technology		0/6
# CRC Press		1/6
# ISBN (identifier)		2/6
# Sharif University of Technology		3/6
# University of British Columbia		4/6
# University of Michigan		5/6
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Sharif University of Technology&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=University of British Columbia&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=University of Michigan&explaintext=1&exsectionformat=wiki
# INFO:__main__:You must are playing the Wikipedia Game where you must find a chain of
# Wikipedia pages that connect a source topic to a target topic. Your current topic is Kayvan Najarian (id: 26555151, ns: 0) and
# you must select a new wikipedia page closer to the target topic Israel. You can select a topic from
# the following list:
#
# Topic	Description
# --------			-----------
# title:Amirkabir University of Technology	Amirkabir University of Technology (AUT) (Persian:...
# title:CRC Press	The CRC Press, LLC is an American publishing group...
# title:ISBN (identifier)	The International Standard Book Number (ISBN) is a...
# title:Sharif University of Technology	Sharif University of Technology (SUT; Persian: دان...
# title:University of British Columbia	The University of British Columbia (UBC) is a publ...
# title:University of Michigan	The University of Michigan (U-M, UMich, or simply ...
#
#
# If the target topic of Israel is available, you should select the target topic Israel. Otherwise, select
# a next topic that is likely to be closer or fewer connections to the topic Israel. Format your output as:
# Next topic=<topic here>
# Template
# INFO:__main__:Sharif University of Technology
# INFO:__main__:Sharif University of Technology
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=info&titles=Israel&inprop=protection|talkid|watched|watchers|visitingwatchers|notificationtimestamp|subjectid|url|readable|preload|displaytitle
# Response
# content='Next topic=Sharif University of Technology' response_metadata={'role': 'assistant', 'content': 'Next topic=Sharif University of Technology', 'token_usage': {'prompt_tokens': 260, 'total_tokens': 269, 'completion_tokens': 9}, 'model_name': 'meta/llama3-70b-instruct'} id='run-3ea3ea8f-bb68-43d7-ad7a-fc304c23878c-0' role='assistant'
# Parsed Response
# Sharif University of Technology
# Most similar page
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=info&titles=Sharif University of Technology&inprop=protection|talkid|watched|watchers|visitingwatchers|notificationtimestamp|subjectid|url|readable|preload|displaytitle
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=links&titles=Sharif University of Technology&pllimit=500
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=1979 revolution&explaintext=1&exsectionformat=wiki
# Sharif University of Technology
# <class 'wikipediaapi.WikipediaPage'>
# Got all titles
# 1979 revolution		0/143
# AJA University of Medical Sciences		1/143
# Abbas Anvari		2/143
# Academic Ranking of World Universities		3/143
# Adel Ferdosipour		4/143
# Ali Akbar Salehi		5/143
# Ali Daei		6/143
# Ali Larijani		7/143
# Ali Mohammad Ranjbar		8/143
# Alireza Mehran		9/143
# Allameh Tabatabaei University		10/143
# Alzahra University		11/143
# Amin Police University		12/143
# Amirkabir University of Technology		13/143
# Anonymous martyr		14/143
# Azadi Square		15/143
# Azadi Tower		16/143
# Baqiyatallah University of Medical Sciences		17/143
# Basij		18/143
# CWTS Leiden Ranking		19/143
# Civil Aviation Technology College		20/143
# College and university rankings		21/143
# Doctorate		22/143
# Doi (identifier)		23/143
# Elshan Moradi		24/143
# Eshaq Jahangiri		25/143
# Farhangian University		26/143
# FarsiTeX		27/143
# Fazlollah Reza		28/143
# Fields Medal		29/143
# Financial endowment		30/143
# Geographic coordinate system		31/143
# Government of Hassan Rouhani (2013–2017)		32/143
# Hassan Rouhani		33/143
# Higher education in Iran		34/143
# Hossein Ali Anvari		35/143
# Hossein Nasr		36/143
# IAESTE Iran		37/143
# Imam Hossein University		38/143
# Imam Sadiq University		39/143
# Iran		40/143
# Iran Broadcasting University		41/143
# Iran University of Medical Sciences		42/143
# Iran University of Science and Technology		43/143
# Iranian Machine Design Competition		44/143
# Iranian Principlists		45/143
# Iranian national football team		46/143
# Iranian reform movement		47/143
# Iran–Iraq War		48/143
# Isfahan		49/143
# Isfahan University of Technology		50/143
# Islamic Azad University		51/143
# Islamic Azad University, Science and Research Branch, Tehran		52/143
# Islamic Azad University, Tehran Medical Branch		53/143
# Islamic Azad University, West Tehran Branch		54/143
# Islamic Azad University Central Tehran Branch		55/143
# Islamic Azad University North Tehran Branch		56/143
# Islamic Azad University South Tehran Branch		57/143
# Islamic Republic News Agency		58/143
# K.N.Toosi University of Technology		59/143
# Kharazmi University		60/143
# Kish Island		61/143
# Kouhyar Goudarzi		62/143
# Mahmud Fotuhi Firuzabad		63/143
# Mahsa Amini protests		64/143
# Majid Sharif Vaghefi		65/143
# Malek Ashtar University of Technology		66/143
# Maryam Mirzakhani		67/143
# Massachusetts Institute of Technology		68/143
# Mathematical logician		69/143
# Mehdi Zarghamee		70/143
# Ministry of Health and Medical Education		71/143
# Ministry of Science, Research and Technology (Iran)		72/143
# Mohammad-Javad Larijani		73/143
# Mohammad Ali Mojtahedi		74/143
# Mohammad Etemadi		75/143
# Mohammad Khatami		76/143
# Mohammad Reza Amin		77/143
# Mohammad Reza Pahlavi		78/143
# Mohammad Reza Shah Pahlavi		79/143
# NPR		80/143
# Omid Kokabee		81/143
# Pardis Technology Park		82/143
# Payame Noor University		83/143
# People's Mujahedin of Iran		84/143
# Persian Gulf		85/143
# Persian language		86/143
# Postgraduate education		87/143
# Private university		88/143
# Public university		89/143
# QS World University Rankings		90/143
# Research University		91/143
# Research university		92/143
# Reza Roosta Azad		93/143
# RoboCup		94/143
# Romanization of Persian		95/143
# S2CID (identifier)		96/143
# STEM		97/143
# Saeed Sohrabpour		98/143
# Sanctions against Iranian scientists		99/143
# Sayed Khatiboleslam Sadrnezhaad		100/143
# School colors		101/143
# Science, technology, engineering, and mathematics		102/143
# Scientia Iranica		103/143
# Seyyed Hossein Nasr		104/143
# Shahbal		105/143
# Shahed University		106/143
# Shahid Beheshti University		107/143
# Shahid Beheshti University of Medical Sciences		108/143
# Shahid Rajaee Teacher Training University		109/143
# Sharif Graduate School of Management and Economics		110/143
# Sharif University Metro Station		111/143
# Sharif University of Technology International Campus - Kish Island		112/143
# Sharif University of Technology International Campus – Kish Island		113/143
# Sivan Design Group		114/143
# Society of Students Against Poverty		115/143
# Soore University		116/143
# Stanford University		117/143
# Tarasht		118/143
# Tarbiat Modares University		119/143
# Technical and Vocational University		120/143
# Tehran		121/143
# Tehran University of Art		122/143
# Tehran University of Medical Sciences		123/143
# Tehran province		124/143
# The Daily Texan		125/143
# The Washington Post		126/143
# Times Higher Education		127/143
# Times Higher Education World University Rankings		128/143
# U.S. News & World Report		129/143
# U.S. News & World Report Best Colleges Ranking		130/143
# U.S. News & World Report Best Global University Ranking		131/143
# Undergraduate education		132/143
# United States dollar		133/143
# University of Applied Science and Technology		134/143
# University of Judicial Sciences and Administrative Services		135/143
# University of Science and Culture		136/143
# University of Social Welfare and Rehabilitation Sciences		137/143
# University of Tehran		138/143
# University president		139/143
# University system		140/143
# Vice President of Iran		141/143
# Wayback Machine		142/143
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=AJA University of Medical Sciences&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Abbas Anvari&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Academic Ranking of World Universities&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Adel Ferdosipour&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Ali Akbar Salehi&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Ali Daei&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Ali Larijani&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Ali Mohammad Ranjbar&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Alireza Mehran&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Allameh Tabatabaei University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Alzahra University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Amin Police University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Amirkabir University of Technology&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Anonymous martyr&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Azadi Square&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Azadi Tower&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Baqiyatallah University of Medical Sciences&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Basij&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=CWTS Leiden Ranking&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Civil Aviation Technology College&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=College and university rankings&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Doctorate&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Doi (identifier)&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Elshan Moradi&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Eshaq Jahangiri&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Farhangian University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=FarsiTeX&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Fazlollah Reza&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Fields Medal&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Financial endowment&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Geographic coordinate system&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Government of Hassan Rouhani (2013–2017)&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Hassan Rouhani&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Higher education in Iran&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Hossein Ali Anvari&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Hossein Nasr&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=IAESTE Iran&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Imam Hossein University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Imam Sadiq University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Iran&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Iran Broadcasting University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Iran University of Medical Sciences&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Iran University of Science and Technology&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Iranian Machine Design Competition&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Iranian Principlists&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Iranian national football team&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Iranian reform movement&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Iran–Iraq War&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Isfahan&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Isfahan University of Technology&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Islamic Azad University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Islamic Azad University, Science and Research Branch, Tehran&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Islamic Azad University, Tehran Medical Branch&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Islamic Azad University, West Tehran Branch&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Islamic Azad University Central Tehran Branch&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Islamic Azad University North Tehran Branch&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Islamic Azad University South Tehran Branch&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Islamic Republic News Agency&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=K.N.Toosi University of Technology&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Kharazmi University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Kish Island&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Kouhyar Goudarzi&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Mahmud Fotuhi Firuzabad&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Mahsa Amini protests&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Majid Sharif Vaghefi&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Malek Ashtar University of Technology&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Maryam Mirzakhani&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Massachusetts Institute of Technology&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Mathematical logician&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Mehdi Zarghamee&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Ministry of Health and Medical Education&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Ministry of Science, Research and Technology (Iran)&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Mohammad-Javad Larijani&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Mohammad Ali Mojtahedi&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Mohammad Etemadi&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Mohammad Khatami&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Mohammad Reza Amin&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Mohammad Reza Pahlavi&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Mohammad Reza Shah Pahlavi&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=NPR&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Omid Kokabee&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Pardis Technology Park&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Payame Noor University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=People's Mujahedin of Iran&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Persian Gulf&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Persian language&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Postgraduate education&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Private university&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Public university&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=QS World University Rankings&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Research University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Research university&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Reza Roosta Azad&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=RoboCup&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Romanization of Persian&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=S2CID (identifier)&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=STEM&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Saeed Sohrabpour&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Sanctions against Iranian scientists&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Sayed Khatiboleslam Sadrnezhaad&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=School colors&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Science, technology, engineering, and mathematics&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Scientia Iranica&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Seyyed Hossein Nasr&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Shahbal&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Shahed University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Shahid Beheshti University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Shahid Beheshti University of Medical Sciences&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Shahid Rajaee Teacher Training University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Sharif Graduate School of Management and Economics&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Sharif University Metro Station&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Sharif University of Technology International Campus - Kish Island&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Sharif University of Technology International Campus – Kish Island&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Sivan Design Group&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Society of Students Against Poverty&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Soore University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Stanford University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Tarasht&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Tarbiat Modares University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Technical and Vocational University&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Tehran&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Tehran University of Art&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Tehran University of Medical Sciences&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Tehran province&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=The Daily Texan&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=The Washington Post&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Times Higher Education&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Times Higher Education World University Rankings&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=U.S. News & World Report&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=U.S. News & World Report Best Colleges Ranking&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=U.S. News & World Report Best Global University Ranking&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Undergraduate education&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=United States dollar&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=University of Applied Science and Technology&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=University of Judicial Sciences and Administrative Services&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=University of Science and Culture&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=University of Social Welfare and Rehabilitation Sciences&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=University of Tehran&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=University president&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=University system&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Vice President of Iran&explaintext=1&exsectionformat=wiki
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Wayback Machine&explaintext=1&exsectionformat=wiki
# INFO:__main__:You must are playing the Wikipedia Game where you must find a chain of
# Wikipedia pages that connect a source topic to a target topic. Your current topic is Kayvan Najarian (id: 26555151, ns: 0) and
# you must select a new wikipedia page closer to the target topic Israel. You can select a topic from
# the following list:
#
# Topic	Description
# --------			-----------
# title:1979 revolution	The Iranian Revolution (Persian: انقلاب ایران, Enq...
# title:AJA University of Medical Sciences	AJA University of Medical Sciences (Persian: دانشگ...
# title:Abbas Anvari	Abbas Anvari is an Iranian Professor in Physics. H...
# title:Academic Ranking of World Universities	The Academic Ranking of World Universities (ARWU),...
# title:Adel Ferdosipour	Adel Ferdosipour (Persian: عادل فردوسی‌پور; born 3...
# title:Ali Akbar Salehi	Ali Akbar Salehi (Persian: علی‌اکبر صالحی, ; born ...
# title:Ali Daei	Ali Daei (Persian:  pronounced [ʔæliː dɑːjiː]; bor...
# title:Ali Larijani	Ali Ardeshir Larijani (Persian: علی لاریجانی, Pers...
# title:Ali Mohammad Ranjbar	Ali Mohammad Ranjbar (Persian: علی محمد رنجبر, bor...
# title:Alireza Mehran	Dr. Alireza Mehran (Persian: علیرضا مهران) was cha...
# title:Allameh Tabatabaei University	Allameh Tabataba'i University (ATU; [ˌælɒːˈme tæbɒ...
# title:Alzahra University	Alzahra University (Persian: دانشگاه الزهرا, Dānes...
# title:Amin Police University	Amin Police Academy (Persian: دانشگاه علوم انتظامی...
# title:Amirkabir University of Technology	Amirkabir University of Technology (AUT) (Persian:...
# title:Anonymous martyr	Anonymous martyr (Persian: شهید گمنام) is a term c...
# title:Azadi Square	Shahyad Square (Persian: میدان آزادی Meydāne Āzādi...
# title:Azadi Tower	The Azadi Tower (Persian: برج آزادی, Borj-e Āzādi;...
# title:Baqiyatallah University of Medical Sciences	Baqiyatallah University of Medical Sciences (بقية‌...
# title:Basij	The Basij (Persian: بسيج, lit. "The Mobilization")...
# title:CWTS Leiden Ranking	The CWTS Leiden Ranking is an annual global univer...
# title:Civil Aviation Technology College	The Civil Aviation Technology College (CATC Colleg...
# title:College and university rankings	College and university rankings order higher educa...
# title:Doctorate	A doctorate (from Latin doctor, meaning "teacher")...
# title:Doi (identifier)	A digital object identifier (DOI) is a persistent ...
# title:Elshan Moradi	Elshan Moradi Abadi (Persian: الشن مرادی ابدی, bor...
# title:Eshaq Jahangiri	Eshaq Jahangiri Kouhshahi (Persian: ‌اسحاق جهانگیر...
# title:Farhangian University	Farhangian University (Persian: دانشگاه فرهنگیان) ...
# title:FarsiTeX	FarsiTeX  is a free Persian/English bidirectional ...
# title:Fazlollah Reza	Fazlollah Reza (Persian: فضل‌الله رضا; January 1, ...
# title:Fields Medal	The Fields Medal is a prize awarded to two, three,...
# title:Financial endowment	A financial endowment is a legal structure for man...
# title:Geographic coordinate system	A geographic coordinate system (GCS) is a spherica...
# title:Government of Hassan Rouhani (2013–2017)	The President of Iran is the second formal positio...
# title:Hassan Rouhani	Hassan Rouhani (Persian: حسن روحانی, Standard Pers...
# title:Higher education in Iran	Iran has a network of private, public, and state-a...
# title:Hossein Ali Anvari	Hossein Ali Anvari was an Iranian professor in ele...
# title:Hossein Nasr	Seyyed Hossein Nasr (; Persian: سید حسین نصر, born...
# title:IAESTE Iran	The International Association for the Exchange of ...
# title:Imam Hossein University	The Imam Hossein Comprehensive University (also re...
# title:Imam Sadiq University	The Imam Sadiq University is an Islamic  private u...
# title:Iran	Iran, officially the Islamic Republic of Iran (IRI...
# title:Iran Broadcasting University	The Iran Broadcasting University (Persian: دانشگاه...
# title:Iran University of Medical Sciences	Iran University of Medical Sciences (IUMS) (Persia...
# title:Iran University of Science and Technology	Iran University of Science and Technology (IUST) (...
# title:Iranian Machine Design Competition	The Iranian Machine Design Competition (Persian: م...
# title:Iranian Principlists	The Principlists (Persian: اصول‌گرایان, romanized:...
# title:Iranian national football team	The Iran national football team (Persian: تیم ملی ...
# title:Iranian reform movement	The Reformists (Persian: اصلاح‌طلبان, romanized: E...
# title:Iran–Iraq War	The Iran–Iraq War, also known as the First Gulf Wa...
# title:Isfahan	Isfahan (Persian: اصفهان; [esfæˈhɒːn] ) is a major...
# title:Isfahan University of Technology	The Isfahan University of Technology (IUT) (Persia...
# title:Islamic Azad University	The Islamic Azad University (IAU; Persian: دانشگاه...
# title:Islamic Azad University, Science and Research Branch, Tehran	The Islamic Azad University, Science and Research ...
# title:Islamic Azad University, Tehran Medical Branch	The Islamic Azad University, Tehran Medical Scienc...
# title:Islamic Azad University, West Tehran Branch	The Islamic Azad University, West Tehran Branch, (...
# title:Islamic Azad University Central Tehran Branch	Islamic Azad University, Central Tehran Branch (Pe...
# title:Islamic Azad University North Tehran Branch	The Islamic Azad University, North Tehran Branch (...
# title:Islamic Azad University South Tehran Branch	The Islamic Azad University, South Tehran Branch i...
# title:Islamic Republic News Agency	The Islamic Republic News Agency (Persian: خبرگزار...
# title:K.N.Toosi University of Technology	The Khajeh Nasir Toosi University of Technology (K...
# title:Kharazmi University	Kharazmi University (Abbreviation: KHU) (Persian: ...
# title:Kish Island	Kish (Persian: کیش , is a 91.5-square-kilometre (3...
# title:Kouhyar Goudarzi	Kouhyar Goudarzi (Persian: کوهیار گودرزی) is an Ir...
# title:Mahmud Fotuhi Firuzabad	Mahmoud Fotouhi Firouzabad (born 1959) is the form...
# title:Mahsa Amini protests	Civil unrest and protests against the government o...
# title:Majid Sharif Vaghefi	Majid Sharif-Vaghefi (Persian: مجید شریف واقفی, 19...
# title:Malek Ashtar University of Technology	Malek Ashtar University of Technology (MUT) (Persi...
# title:Maryam Mirzakhani	Maryam Mirzakhani (Persian: مریم میرزاخانی, pronou...
# title:Massachusetts Institute of Technology	The Massachusetts Institute of Technology (MIT) is...
# title:Mathematical logician	Mathematical logic is the study of formal logic wi...
# title:Mehdi Zarghamee	Dr. Mehdi Shaghaghi Zarghamee (Persian: مهدی شقاقی...
# title:Ministry of Health and Medical Education	The Ministry of Health and Medical Education (MOHM...
# title:Ministry of Science, Research and Technology (Iran)	The Ministry of Science, Research and Technology (...
# title:Mohammad-Javad Larijani	Mohammad-Javad Ardeshir Larijani (Persian: محمدجوا...
# title:Mohammad Ali Mojtahedi	Dr. Mohammad Ali Modjtahedi Gilani (Persian: محمدع...
# title:Mohammad Etemadi	Mohammad Etemadi (Persian: محمد اعتمادی) is an Ira...
# title:Mohammad Khatami	Mohammad Khatami (Persian: سید محمد خاتمی, romaniz...
# title:Mohammad Reza Amin	Dr. Mohammad Reza Amin (c.1927 – 27 September 2003...
# title:Mohammad Reza Pahlavi	Mohammed Reza Pahlavi (26 October 1919 – 27 July 1...
# title:Mohammad Reza Shah Pahlavi	Mohammed Reza Pahlavi (26 October 1919 – 27 July 1...
# title:NPR	National Public Radio (NPR, stylized as npr) is an...
# title:Omid Kokabee	Omid Kokabee (Persian: امید کوکبی; born 1982) is a...
# title:Pardis Technology Park	Pardis Technology Park (PTP) (Persian: پارک فناوری...
# title:Payame Noor University	Payame Noor University (PNU; Persian: Dāneŝgāhe Pa...
# title:People's Mujahedin of Iran	The People's Mojahedin Organization of Iran (PMOI)...
# title:Persian Gulf	The Persian Gulf (Persian: خلیج فارس, romanized: x...
# title:Persian language	Persian ( PUR-zhən, -⁠shən), also known by its end...
# title:Postgraduate education	Postgraduate education, graduate education, or gra...
# title:Private university	Private universities and private colleges are high...
# title:Public university	A public university or public college is a univers...
# title:QS World University Rankings	The QS World University Rankings is a portfolio of...
# title:Research University	A research university or a research-intensive univ...
# title:Research university	A research university or a research-intensive univ...
# title:Reza Roosta Azad	Reza Roosta Azad (23 February 1962 – 11 October 20...
# title:RoboCup	RoboCup is an annual international robotics compet...
# title:Romanization of Persian	Romanization or Latinization of Persian (Persian: ...
# title:S2CID (identifier)	Semantic Scholar is a research tool for scientific...
# title:STEM	Science, technology, engineering, and mathematics ...
# title:Saeed Sohrabpour	Saeed Sohrabpour (Persian: سعيد سهراب پور), (born ...
# title:Sanctions against Iranian scientists	...
#
#
# If the target topic of Israel is available, you should select the target topic Israel. Otherwise, select
# a next topic that is likely to be closer or fewer connections to the topic Israel. Format your output as:
# Next topic=<topic here>
# Template
# INFO:__main__:Hassan Rouhani
# INFO:__main__:You must are playing the Wikipedia Game where you must find a chain of
# Wikipedia pages that connect a source topic to a target topic. Your current topic is Kayvan Najarian (id: 26555151, ns: 0) and
# you must select a new wikipedia page closer to the target topic Israel. You can select a topic from
# the following list:
#
# Topic	Description
# --------			-----------
# title:Sayed Khatiboleslam Sadrnezhaad	Sayed Khatiboleslam Sadrnezhaad is an Iranian dist...
# title:School colors	School colors, also known as university colors or ...
# title:Science, technology, engineering, and mathematics	Science, technology, engineering, and mathematics ...
# title:Scientia Iranica	Scientia Iranica is a peer-reviewed scientific jou...
# title:Seyyed Hossein Nasr	Seyyed Hossein Nasr (; Persian: سید حسین نصر, born...
# title:Shahbal	Shahbal is an unmanned aerial vehicle (UAV) design...
# title:Shahed University	Shahed University (Persian: دانشگاه شاهد) is a pub...
# title:Shahid Beheshti University	Shahid Beheshti University (SBU) (Persian: دانشگاه...
# title:Shahid Beheshti University of Medical Sciences	Shahid Beheshti University of Medical Sciences (SB...
# title:Shahid Rajaee Teacher Training University	Shahid Rajaee Teacher Training University (SRTTU),...
# title:Sharif Graduate School of Management and Economics	...
# title:Sharif University Metro Station	Sharif University Metro Station is a station on Te...
# title:Sharif University of Technology International Campus - Kish Island	International Campus of Sharif University of Techn...
# title:Sharif University of Technology International Campus – Kish Island	International Campus of Sharif University of Techn...
# title:Sivan Design Group	Sivan Design Group, also known as C1 Design Group,...
# title:Society of Students Against Poverty	Society of Students Against Poverty (Imam Ali's Po...
# title:Soore University	Soore University (SU) (Persian: دانشگاه سوره, Dâne...
# title:Stanford University	Stanford University (officially Leland Stanford Ju...
# title:Tarasht	Tarasht is a very old neighborhood in west Tehran ...
# title:Tarbiat Modares University	Tarbiat Modares University (Persian: دانشگاه تربیت...
# title:Technical and Vocational University	The Technical and Vocational University (TVU) (Per...
# title:Tehran	Tehran (; Persian: تهران Tehrân [tehˈɾɒːn] ) is th...
# title:Tehran University of Art	University of Art (Persian: دانشگاه هنر, Daneshgah...
# title:Tehran University of Medical Sciences	Tehran University of Medical Sciences (TUMS) (Pers...
# title:Tehran province	Tehran Province (Persian: استان تهران) is one of t...
# title:The Daily Texan	The Daily Texan is the student newspaper of the Un...
# title:The Washington Post	The Washington Post, locally known as "the Post" a...
# title:Times Higher Education	Times Higher Education (THE), formerly The Times H...
# title:Times Higher Education World University Rankings	The Times Higher Education World University Rankin...
# title:U.S. News & World Report	U.S. News & World Report (USNWR, US NEWS) is an Am...
# title:U.S. News & World Report Best Colleges Ranking	The U.S. News & World Report Best Colleges Ranking...
# title:U.S. News & World Report Best Global University Ranking	The Best Global Universities ranking by U.S. News ...
# title:Undergraduate education	Undergraduate education is education conducted aft...
# title:United States dollar	The United States dollar (symbol: $; currency code...
# title:University of Applied Science and Technology	The University of Applied Science and Technology (...
# title:University of Judicial Sciences and Administrative Services	University of Judicial Sciences and Administrative...
# title:University of Science and Culture	The University of Science and Culture (Persian: دا...
# title:University of Social Welfare and Rehabilitation Sciences	The University of Social Welfare and Rehabilitatio...
# title:University of Tehran	The University of Tehran (Tehran University or UT,...
# title:University president	A chancellor is a leader of a college or universit...
# title:University system	A university system is a set of multiple affiliate...
# title:Vice President of Iran	A vice president of Iran (Persian: معاون رئیس‌جمهو...
# title:Wayback Machine	The Wayback Machine is a digital archive of the Wo...
#
#
# If the target topic of Israel is available, you should select the target topic Israel. Otherwise, select
# a next topic that is likely to be closer or fewer connections to the topic Israel. Format your output as:
# Next topic=<topic here>
# Response
# content='Next topic=Hassan Rouhani' response_metadata={'role': 'assistant', 'content': 'Next topic=Hassan Rouhani', 'token_usage': {'prompt_tokens': 2408, 'total_tokens': 2417, 'completion_tokens': 9}, 'model_name': 'meta/llama3-70b-instruct'} id='run-191dcb19-1c1e-4244-b4df-7c333143c589-0' role='assistant'
# Parsed Response
# Hassan Rouhani
# Most similar page
# Template
# INFO:__main__:Tehran
# INFO:__main__:You must are playing the Wikipedia Game where you must find a chain of
# Wikipedia pages that connect a source topic to a target topic. Your current topic is Kayvan Najarian (id: 26555151, ns: 0) and
# you must select a new wikipedia page closer to the target topic Israel. You can select a topic from
# the following list:
#
# Topic	Description
# --------			-----------
# title:Hassan Rouhani	Hassan Rouhani (Persian: حسن روحانی, Standard Pers...
# title:Tehran	Tehran (; Persian: تهران Tehrân [tehˈɾɒːn] ) is th...
#
#
# If the target topic of Israel is available, you should select the target topic Israel. Otherwise, select
# a next topic that is likely to be closer or fewer connections to the topic Israel. Format your output as:
# Next topic=<topic here>
# Response
# content='Next topic=Tehran' response_metadata={'role': 'assistant', 'content': 'Next topic=Tehran', 'token_usage': {'prompt_tokens': 1022, 'total_tokens': 1028, 'completion_tokens': 6}, 'model_name': 'meta/llama3-70b-instruct'} id='run-fbb33032-862f-405b-8cbc-931ea5da6083-0' role='assistant'
# Parsed Response
# Tehran
# Most similar page
# INFO:__main__:Tehran
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=info&titles=Tehran&inprop=protection|talkid|watched|watchers|visitingwatchers|notificationtimestamp|subjectid|url|readable|preload|displaytitle
# Response
# content='Next topic=Tehran' response_metadata={'role': 'assistant', 'content': 'Next topic=Tehran', 'token_usage': {'prompt_tokens': 195, 'total_tokens': 201, 'completion_tokens': 6}, 'model_name': 'meta/llama3-70b-instruct'} id='run-f872527e-d779-47c2-803e-5a6588752068-0' role='assistant'
# Parsed Response
# Tehran
# Most similar page
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=links&titles=Tehran&pllimit=500
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=links&titles=Tehran&pllimit=500&plcontinue=57654|0|Mahmoodieh
# INFO:wikipediaapi:Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=1908 bombardment of the Majlis&explaintext=1&exsectionformat=wiki
# Tehran
# <class 'wikipediaapi.WikipediaPage'>
# Got all titles
# 1908 bombardment of the Majlis		0/879
# 1951 Asian Games		1/879
# 1954 Asian Games		2/879
# 1958 Asian Games		3/879
# 1962 Asian Games		4/879
# 1966 Asian Games		5/879
# 1968 AFC Asian Cup		6/879
# 1970 Asian Games		7/879
# 1974 Asian Games		8/879
# 1976 AFC Asian Cup		9/879
# 1978 Asian Games		10/879
# 1979 Revolution		11/879
# 1982 Asian Games		12/879
# 1986 Asian Games		13/879
# 1986 Asian Winter Games		14/879
# 1990 Asian Games		15/879
# 1990 Asian Winter Games		16/879
# 1994 Asian Games		17/879
# 1996 Asian Winter Games		18/879
# 1998 Asian Games		19/879
# 1999 Asian Winter Games		20/879
# ...
# title:Cathedral of Saint James, Jerusalem	The Cathedral of Saint James (Armenian: Սրբոց Յակո...
# title:Catholic Church	The Catholic Church, also known as the Roman Catho...
# title:Catholic Church and Judaism	The Catholic Church and Judaism have a long and co...
# title:Cave of Hira	Jabal al-Nour (Arabic: جَبَل ٱلنُّوْر, romanized: ...
# title:Cave of the Patriarchs	The Cave of the Patriarchs or Tomb of the Patriarc...
# title:Celtis australis	Celtis australis, the European nettle tree, Medite...
# title:Cenacle	The Cenacle (from the Latin cenaculum, "dining roo...
# title:Center for Jewish History	The Center for Jewish History is a partnership of ...
# title:Center of Contemporary Jewish Documentation	The Center for Contemporary Jewish Documentation i...
# title:Central District (Israel)	The Central District (Hebrew: מְחוֹז הַמֶּרְכָּז, ...
# title:Chagos Archipelago sovereignty dispute	Sovereignty over the Chagos Archipelago is dispute...
# title:Chalcolithic	The Chalcolithic (also called the Copper Age and E...
# title:Channel 10 (Israel)	Channel 10 (Hebrew: ערוץ עשר, romanized: Arutz Ese...
# title:Channel 2 (Israel)	Channel 2 (Hebrew: ערוץ שתיים, romanized: Arutz Sh...
# title:Chapel of Saint Helena, Jerusalem	The Chapel of Saint Helena is a 12th-century Armen...
# title:Chapel of Simon of Cyrene	The Chapel of Simon of Cyrene is a Catholic chapel...
# title:Chevron yeshiva	Hebron Yeshiva, also known as Yeshivas Hevron, or ...
# title:Chief Rabbi of Jerusalem	The position of Chief Rabbi of Jerusalem was insti...
# title:China	China, officially the People's Republic of China (...
# title:Chios	Chios (; Greek: Χίος, romanized: Chíos [ˈçi.os] , ...
# title:Chords Bridge	The Chords Bridge (Hebrew: גשר המיתרים, Gesher HaM...
# title:Christ Church, Jerusalem	Christ Church, Jerusalem (Hebrew: כנסיית המשיח), i...
# title:Christendom	Christendom refers to Christian states, Christian-...
# title:Christian Church	In ecclesiology, the Christian Church is what diff...
# title:Christian Quarter	The Christian Quarter (Arabic: حارة النصارى, roman...
# title:Christianity	Christianity () is an Abrahamic monotheistic relig...
# title:Christianity and Judaism	Christianity began as a movement within Second Tem...
# title:Christians	A Christian ( ) is a person who follows or adheres...
# title:Christmas Island	The Territory of Christmas Island is an Australian...
# title:Church of Our Lady of Sorrows, Jerusalem	The Church of Our Lady of Sorrows (Hebrew: כנסיית ...
# title:Church of Saint Anne, Jerusalem	The Church of Saint Anne (French: Église Sainte-An...
# title:Church of Saint Mary of the Germans	The Church of Saint Mary of the Germans (Hebrew: כ...
# title:Church of Saint Mary of the Latins	The Church of Saint Mary of the Latins (Latin: Lat...
# title:Church of Saint Toros	Church of Saint Toros  (Armenian: Սուրբ Աստվածածին...
# title:Church of the Condemnation	The Church of the Condemnation and Imposition of t...
# title:Church of the Flagellation	The Church of the Flagellation is a Roman Catholic...
# title:Church of the Holy Archangels, Jerusalem	The Church of the Holy Archangels (Armenian: Սրբոց...
# title:Church of the Holy Family, Jerusalem	The Church of the Holy Family (Hebrew: כנסיית המשפ...
# title:Church of the Holy Sepulchre	The Church of the Holy Sepulchre, also known as th...
# title:Church of the Redeemer, Jerusalem	The Lutheran Church of the Redeemer (Hebrew: כנסיי...
# title:Chuts	Chuts  is the name applied to Jews who immigrated ...
# title:Cilicia	Cilicia () is a geographical region in southern An...
# title:Cinema of Palestine	Cinema of Palestine is relatively young in compari...
# title:Cinemas	A movie theater (American English), cinema (Britis...
# title:Cisco Systems	Cisco Systems, Inc. (using the trademark Cisco) is...
# title:City Line (Jerusalem)	City Line (Hebrew: הקו העירוני, romanized: ha-Kav ...
# title:City council	A municipal council is the legislative body of a m...
# title:City council (Israel)	A city council (Hebrew: עִירִיָּה, Iriya) is the o...
# title:City of David (Silwan)	Wadi Hilweh is a neighborhood in the Palestinian A...
# title:City of David (archaeological site)	The City of David (Hebrew: עיר דוד, romanized: ʿĪr...
# title:City of David (historic)	The City of David (Hebrew: עיר דוד, romanized: ʿĪr...
# title:Classical Arabic	Classical Arabic or Quranic Arabic (Arabic: العربي...
# title:Clifford Edmund Bosworth	Clifford Edmund Bosworth FBA (29 December 1928 – 2...
# title:Co-Cathedral of the Most Holy Name of Jesus	The Co-Cathedral of the Most Holy Name of Jesus, a...
# title:Cochin Jews	Cochin Jews (also known as Malabar Jews or Kochini...
# title:Cocos (Keeling) Islands	The Cocos (Keeling) Islands (Cocos Islands Malay: ...
# title:Common Era	Common Era (CE) and Before the Common Era (BCE) ar...
# title:Companions of the Prophet	The Companions of the Prophet (Arabic: اَلصَّحَابَ...
# title:Companions of the Rass	The Companions of the Rass, also known as the Peop...
# title:Conquest of Mecca	The conquest of Mecca (Arabic: فَتْحُ مَكَّةَ Fatḥ...
# title:Conservative Judaism	Conservative Judaism, also known as Masorti Judais...
# title:Constantine I	Constantine I (27 February c. 272 – 22 May 337), a...
# title:Constantinople	Constantinople (see other names) became the capita...
# title:Constantinopolitan Karaites	The Constantinopolitan Karaites or Greco-Karaites ...
# title:Consulate General of France, Jerusalem	The Consulate General of France in Jerusalem (Fren...
# title:Convent of the Sisters of Zion	The Convent of the Sisters of Zion is a Roman Cath...
# title:Conversion to Judaism	Conversion to Judaism (Hebrew: גִּיּוּר, romanized...
# title:Coptic Orthodox Archdiocese of Jerusalem	The Holy and Ancient Archdiocese of Jerusalem, All...
#
#
# If the target topic of Israel is available, you should select the target topic Israel. Otherwise, select
# a next topic that is likely to be closer or fewer connections to the topic Israel. Format your output as:
# Next topic=<topic here>
# Response
# content='Next topic=Bank of Israel' response_metadata={'role': 'assistant', 'content': 'Next topic=Bank of Israel', 'token_usage': {'prompt_tokens': 2999, 'total_tokens': 3006, 'completion_tokens': 7}, 'model_name': 'meta/llama3-70b-instruct'} id='run-ec466dc2-d2b7-4a51-9d75-b2267c52c62c-0' role='assistant'
# Parsed Response
# Bank of Israel
# Most similar page
# Template
# INFO:__main__:Cabinet of Israel
# INFO:__main__:You must are playing the Wikipedia Game where you must find a chain of
# Wikipedia pages that connect a source topic to a target topic. Your current topic is Kayvan Najarian (id: 26555151, ns: 0) and
# you must select a new wikipedia page closer to the target topic Israel. You can select a topic from
# the following list:
#
# Topic	Description
# --------			-----------
# title:Coptic Orthodox Church	The Coptic Orthodox Church (Coptic: Ϯⲉⲕ̀ⲕⲗⲏⲥⲓⲁ ⲛ̀ⲣ...
# title:Copts	Copts (Coptic: ⲛⲓⲣⲉⲙⲛ̀ⲭⲏⲙⲓ, romanized: niremənkhēm...
# title:Corpus separatum (Jerusalem)	Corpus separatum (Latin for "separated body") was ...
# title:Costa Rica	Costa Rica (UK: , US:  ; Spanish: [ˈkosta ˈrika]; ...
# title:Courtyard neighborhood	Courtyard neighborhoods are Jewish neighborhoods b...
# title:Crimean Karaites	The Crimean Karaites or Krymkaraylar (Crimean Kara...
# title:Crucifixion	Crucifixion is a method of capital punishment in w...
# title:Crucifixion of Jesus	The crucifixion of Jesus occurred in 1st-century J...
# title:Crusades	The Crusades were a series of religious wars initi...
# title:Cucumber	The cucumber (Cucumis sativus) is a widely-cultiva...
# title:Curlie	DMOZ (stylized dmoz in its logo; from directory.mo...
# title:Cusco	Cusco or Cuzco ([ˈkusko]; Quechua: Qusqu or Qosqo ...
# title:Custody of the Holy Land	The Custody of the Holy Land (Latin: Custodia Terr...
# title:Cyprus	Cyprus ( ), officially the Republic of Cyprus, is ...
# title:Cyprus dispute	The Cyprus problem, also known as the Cyprus confl...
# title:Cyrus the Great	Cyrus II of Persia (Old Persian: 𐎤𐎢𐎽𐎢𐏁 Kūruš; c. 6...
# title:Czesław Dźwigaj	Czesław Dźwigaj (born 18 June 1950 in Nowy Wiśnicz...
# title:Daguerreotype	Daguerreotype ( ; French: daguerréotype) was the f...
# title:Damascus	Damascus (, UK also  də-MAH-skəs; Arabic: دِمَشق, ...
# title:Damascus Gate	The Damascus Gate is one of the main Gates of the ...
# title:Dan Bahat	Dan Bahat (Hebrew: דן בהט, born 1938 in Lviv in Po...
# title:Dan Bus Company	Dan Bus Company (Hebrew: דן חברה לתחבורה ציבורית) ...
# title:Daniel Kahneman	Daniel Kahneman (; Hebrew: דניאל כהנמן; March 5, 1...
# title:Daniel Libeskind	Daniel Libeskind (born May 12, 1946) is a Polish-A...
# title:Darius I of Persia	Darius I (Old Persian: 𐎭𐎠𐎼𐎹𐎺𐎢𐏁 Dārayavaʰuš; Greek:...
# title:Date palm	Phoenix dactylifera, commonly known as the date pa...
# title:David	David (; Biblical Hebrew: דָּוִד‎, romanized: Dāwī...
# title:David's Tomb	David's Tomb (Hebrew: קבר דוד המלך Kever David Ha-...
# title:David Ben-Gurion	David Ben-Gurion ( ben GOOR-ee-ən; Hebrew: דָּוִד ...
# title:David Fromkin	David Henry Fromkin (August 27, 1932 – June 11, 20...
# title:David Gross	David Jonathan Gross (; born February 19, 1941) is...
# title:David in Islam	Dawud (Arabic: دَاوُوْد, romanized: Dāwūd [daːwuːd...
# title:Daylight saving time	Daylight saving time (DST), also referred to as da...
# title:Dead Sea	The Dead Sea (Arabic: اَلْبَحْر الْمَيِّت, romaniz...
# title:Dead Sea Scrolls	The Dead Sea Scrolls, also called the Qumran Caves...
# title:Dead Sea scrolls	The Dead Sea Scrolls, also called the Qumran Caves...
# title:Declaration of Independence (Israel)	The Israeli Declaration of Independence, formally ...
# title:Deir Yassin	Deir Yassin (Arabic: دير ياسين, romanized: Dayr Yā...
# title:Deir Yassin massacre	The Deir Yassin massacre took place on April 9, 19...
# title:Deir es-Sultan	Deir es-Sultan, literally the Monastery of the Sul...
# title:Demographic history of Jerusalem	Jerusalem's population size and composition has sh...
# title:Demographics of Jerusalem by quarter	This article provides the demographics of Jerusale...
# title:Demolition of Masjid al-Dirar	The demolition or burning of Masjid al-Dirar  (Ara...
# title:Demon	A demon is a malevolent supernatural entity. Histo...
# title:Demonym	A demonym (; from Ancient Greek  δῆμος (dêmos) 'pe...
# title:Dependent territory	A dependent territory, dependent area, or dependen...
# title:Derbe	Derbe or Dervi (Greek: Δέρβη), also called Derveia...
# title:Desi Jews	Desi Jews are Jews living in South Asia (or origin...
# title:Devil	A devil is the personification of evil as it is co...
# title:Dhaka	Dhaka ( DAH-kə or  DAK-ə; Bengali: ঢাকা, romanized...
# title:Dhikr	Dhikr (Arabic: ذِكْر; ; lit. 'remembrance, reminde...
# title:Dhimmi	Dhimmī (Arabic: ذمي ḏimmī, IPA: [ˈðimmiː], collect...
# title:Dhu al-Hijjah	Dhu al-Hijjah (also Dhu al-Hijja Arabic: ذُو ٱلْحِ...
# title:Dhu al-Qarnayn	Dhu al-Qarnayn, (Arabic: ذُو ٱلْقَرْنَيْن, romaniz...
# title:Dhul-Kifl	Dhu al-Kifl (Arabic: ذُو الْكِفْل ḏū l-kifl, lit. ...
# title:Dili	Dili (Portuguese and Tetum: Díli) is the capital a...
# title:Dimona	Dimona (Hebrew: דִּימוֹנָה, Arabic: ديمونا) is an ...
# title:Disciples of Jesus in Islam	The Quranic account of the disciples (Arabic: الحو...
# title:Diskin Orphanage	The Diskin Orphanage was an orphanage in the Old C...
# title:Districts of Israel	There are six main administrative districts of Isr...
# title:Divorce in Judaism	The relationship between religion and divorce is c...
# title:Doha	Doha (Arabic: الدوحة, romanized: ad-Dawḥa [adˈduħa...
# title:Doi (identifier)	A digital object identifier (DOI) is a persistent ...
# title:Dome of Yusuf	The Dome of Yusuf (Arabic: قبة يوسف Qubbat Yūsuf) ...
# title:Dome of al-Khalili	The Dome of al-Khalili (Arabic: قبة الخليلي, roman...
# title:Dome of al-Khidr	The Dome of al-Khidr (Arabic: قبة الخضر, romanized...
# title:Dome of the Ascension	The Dome of the Ascension (Arabic: قبة المعراج, ro...
# title:Dome of the Chain	Dome of the Chain (Arabic: قبة السلسلة, romanized:...
# title:Dome of the Prophet	The Dome of the Prophet (Arabic: قبة النبي, romani...
# title:Dome of the Rock	The Dome of the Rock (Arabic: قبة الصخرة, romanize...
# title:Donald Trump	Donald John Trump (born June 14, 1946) is an Ameri...
# title:Donkey	The donkey is a domesticated equine. It derives fr...
# title:Dore Gold	Dore Gold (Hebrew: דורי גולד, born 1953) is an Ame...
# title:Doric columns	The Doric order was one of the three orders of anc...
# title:Downtown Triangle (Jerusalem)	The Downtown Triangle (Hebrew: המשולש, Ha-Meshulas...
# title:Dua	In Islam, duʿāʾ (Arabic: دعاء  IPA: [duˈʕæːʔ], plu...
# title:Dual (grammatical number)	Dual (abbreviated DU) is a grammatical number that...
# title:Dunam	A dunam (Ottoman Turkish, Arabic: دونم; Turkish: d...
# title:Dung Gate	The Dung Gate (Hebrew: שער האשפות Sha'ar Ha'ashpot...
# title:Dushanbe	Dushanbe is the capital and largest city of Tajiki...
# title:Dönmeh	The Dönme (Hebrew: דוֹנְמֶה, romanized: Dōnme, Ott...
# title:Early Bronze Age	The Bronze Age was a historical period lasting fro...
# title:East Jerusalem	East Jerusalem (Arabic: القدس الشرقية, al-Quds ash...
# title:East Jerusalem Central Bus Station	The East Jerusalem Central Bus Station is an Arab ...
# title:East Talpiot	East Talpiot (Hebrew: תלפיות מזרח Talpiot Mizrach)...
# title:East Timor	East Timor, also known as Timor-Leste, officially ...
# title:Eastern Orthodox Church	The Eastern Orthodox Church, officially the Orthod...
# title:Eastern Yiddish	Yiddish dialects are varieties of the Yiddish lang...
# title:Edmund Allenby, 1st Viscount Allenby	Field Marshal Edmund Henry Hynman Allenby, 1st Vis...
# title:Edom	Edom (; Edomite: 𐤀𐤃𐤌 ʾDM; Hebrew: אֱדוֹם ʾĔḏōm, li...
# title:Edward Said National Conservatory of Music	The Edward Said National Conservatory of Music (Ar...
# title:Egged (company)	Egged Transportation Ltd (Hebrew: אֶגֶד, pronounce...
# title:Egypt	Egypt (Arabic: مصر Miṣr [mesˁr], Egyptian Arabic p...
# title:Egypt in the Middle Ages	Following the Islamic conquest in 641-642, Lower E...
# title:Egyptians	Egyptians (Arabic: مِصرِيُّون, romanized: Miṣriyyū...
# title:Ehud Barak	Ehud Barak (Hebrew: אֵהוּד בָּרָק [eˈhud baˈʁak] ;...
# title:Eilat	Eilat ( ay-LAHT, UK also  ay-LAT; Hebrew: אֵילַת [...
# title:Ein Karem	Ein Karem (Hebrew: עֵין כֶּרֶם, ʿEin Kerem lit. "S...
# title:Ein Kerem	Ein Karem (Hebrew: עֵין כֶּרֶם, ʿEin Kerem lit. "S...
# title:Eizariya	Bethany (Greek: Βηθανία, Syriac: ܒܝܬ ܥܢܝܐ Bēṯ ʿAny...
#
#
# If the target topic of Israel is available, you should select the target topic Israel. Otherwise, select
# a next topic that is likely to be closer or fewer connections to the topic Israel. Format your output as:
# Next topic=<topic here>
# Response
# content='Next topic=Cabinet of Israel' response_metadata={'role': 'assistant', 'content': 'Next topic=Cabinet of Israel', 'token_usage': {'prompt_tokens': 2589, 'total_tokens': 2596, 'completion_tokens': 7}, 'model_name': 'meta/llama3-70b-instruct'} id='run-3691d746-4caa-4df3-82f5-936132841a61-0' role='assistant'
# Parsed Response
# Cabinet of Israel
# Most similar page
# Template
# INFO:__main__:Declaration of Independence (Israel)
# Response
# content='Next topic=Declaration of Independence (Israel)' response_metadata={'role': 'assistant', 'content': 'Next topic=Declaration of Independence (Israel)', 'token_usage': {'prompt_tokens': 2792, 'total_tokens': 2802, 'completion_tokens': 10}, 'model_name': 'meta/llama3-70b-instruct'} id='run-9391541f-66db-46e7-96fb-f8bd575a0746-0' role='assistant'
# Parsed Response
# Declaration of Independence (Israel)
# Most similar page
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 4
#       2 i = 0
#       3 while not found:
# ----> 4     found = bot.take_turn()
#       5     print(bot.current_page.title)
#       6     i += 1
#
# Cell In[10], line 116, in WikiGameLLMBot.take_turn(self)
#     114     log.info(most_similar)
#     115     bestTitles.append(most_similar)
# --> 116     bestSummaries.append(get_page_summary(page_title_lookup[most_similar]))
#     118 # reduce it further
#     119 if len(bestTitles) > 1:
#
# KeyError: 'Declaration of Independence (Israel)'

# %%
def play_game(self, verbose = True):
    # turn number
    turn_num = 0

    # first 'current' topic is starting topic
    current_topic = self.start_topic

    # to prevent duplicates
    visited = set()

    # keep playing until target is reached
    while True:

        # for turn time tracking
        turn_start = time.time()

        # find most similar topic on current page to target topic
        visited.add(current_topic)
        next_topic = self.take_turn(current_topic, list(visited))

        # for turn time tracking
        turn_time = time.time() - turn_start

        self.log_turn(
            {
                'starting_topic': self.start_topic,
                'target_topic': self.start_topic,
                'turn': turn_num,             
                'current_topic': current_topic,
                'current_summary': self.current_summary
            }
        )

        if verbose:
            printouts = [
                "-" * 50,
                f"Turn: {turn_num}",
                f"Start topic: {self.start_topic.replace('_', ' ')}",
                f"Current topic: {current_topic.replace('_', ' ')}",
                f"Next topic: {next_topic.replace('_', ' ')}",
                f"Target topic: {self.target_topic.replace('_', ' ')}",
            ]

            self.printouts.append(printouts)

            # print progress
            for i in self.printouts[-1]:
                print(i)

        # else, set new next_topic to current topic and loop
        current_topic = next_topic

        # increment turn
        turn_num += 1

# %%
page = wiki_wiki.page('Python_(programming_language)')
print(page.title)
# Python (programming language)
# Out:
# Python_(programming_language)

# %%
help(wiki_wiki.page)
# Out:
# Help on method page in module wikipediaapi:
#
# page(title: str, ns: Union[wikipediaapi.Namespace, int] = <Namespace.MAIN: 0>, unquote: bool = False) -> 'WikipediaPage' method of wikipediaapi.Wikipedia instance
#     Constructs Wikipedia page with title `title`.
#
#     Creating `WikipediaPage` object is always the first step for extracting
#     any information.
#
#     Example::
#
#         wiki_wiki = wikipediaapi.Wikipedia('en')
#         page_py = wiki_wiki.page('Python_(programming_language)')
#         print(page_py.title)
#         # Python (programming language)
#
#         wiki_hi = wikipediaapi.Wikipedia('hi')
#
#         page_hi_py = wiki_hi.article(
#             title='%E0%A4%AA%E0%A4%BE%E0%A4%87%E0%A4%A5%E0%A4%A8',
#             unquote=True,
#         )
#         print(page_hi_py.title)
#         # पाइथन
#
#     :param title: page title as used in Wikipedia URL
#     :param ns: :class:`WikiNamespace`
#     :param unquote: if true it will unquote title
#     :return: object representing :class:`WikipediaPage`

# %%
# ?wiki_wiki.page
# Out:
# Signature:
# wiki_wiki.page(
#     title: str,
#     ns: Union[wikipediaapi.Namespace, int] = <Namespace.MAIN: 0>,
#     unquote: bool = False,
# ) -> 'WikipediaPage'
# Docstring:
# Constructs Wikipedia page with title `title`.
#
# Creating `WikipediaPage` object is always the first step for extracting
# any information.
#
# Example::
#
#     wiki_wiki = wikipediaapi.Wikipedia('en')
#     page_py = wiki_wiki.page('Python_(programming_language)')
#     print(page_py.title)
#     # Python (programming language)
#
#     wiki_hi = wikipediaapi.Wikipedia('hi')
#
#     page_hi_py = wiki_hi.article(
#         title='%E0%A4%AA%E0%A4%BE%E0%A4%87%E0%A4%A5%E0%A4%A8',
#         unquote=True,
#     )
#     print(page_hi_py.title)
#     # पाइथन
#
# :param title: page title as used in Wikipedia URL
# :param ns: :class:`WikiNamespace`
# :param unquote: if true it will unquote title
# :return: object representing :class:`WikipediaPage`
# File:      ~/.local/lib/python3.11/site-packages/wikipediaapi/__init__.py
# Type:      method

# %%
page.links
# Out:
# {'"Hello, World!" program': "Hello, World!" program (id: ??, ns: 0),
#  '3ds Max': 3ds Max (id: ??, ns: 0),
#  '?:': ?: (id: ??, ns: 0),
#  'ABC (programming language)': ABC (programming language) (id: ??, ns: 0),
#  'ADMB': ADMB (id: ??, ns: 0),
#  'ALGOL': ALGOL (id: ??, ns: 0),
#  'ALGOL 68': ALGOL 68 (id: ??, ns: 0),
#  'APL (programming language)': APL (programming language) (id: ??, ns: 0),
#  'ATmega': ATmega (id: ??, ns: 0),
#  'AVR microcontrollers': AVR microcontrollers (id: ??, ns: 0),
#  'Abaqus': Abaqus (id: ??, ns: 0),
#  'Academic Free License': Academic Free License (id: ??, ns: 0),
#  'Academic conference': Academic conference (id: ??, ns: 0),
#  'Action selection': Action selection (id: ??, ns: 0),
#  'Activation function': Activation function (id: ??, ns: 0),
#  'Ada (programming language)': Ada (programming language) (id: ??, ns: 0),
#  'Advanced Simulation Library': Advanced Simulation Library (id: ??, ns: 0),
#  'Adversarial machine learning': Adversarial machine learning (id: ??, ns: 0),
#  'AlexNet': AlexNet (id: ??, ns: 0),
#  'Alex Graves (computer scientist)': Alex Graves (computer scientist) (id: ??, ns: 0),
#  'Alex Martelli': Alex Martelli (id: ??, ns: 0),
#  'Algebra': Algebra (id: ??, ns: 0),
#  'AlphaFold': AlphaFold (id: ??, ns: 0),
#  'AlphaGo': AlphaGo (id: ??, ns: 0),
#  'AlphaZero': AlphaZero (id: ??, ns: 0),
#  'Alternative terms for free software': Alternative terms for free software (id: ??, ns: 0),
#  'Amazon (company)': Amazon (company) (id: ??, ns: 0),
#  'AmigaOS 4': AmigaOS 4 (id: ??, ns: 0),
#  'Amoeba (operating system)': Amoeba (operating system) (id: ??, ns: 0),
#  'Anaconda (installer)': Anaconda (installer) (id: ??, ns: 0),
#  'Analyse-it': Analyse-it (id: ??, ns: 0),
#  'Andrew Ng': Andrew Ng (id: ??, ns: 0),
#  'Android (operating system)': Android (operating system) (id: ??, ns: 0),
#  'Anonymous function': Anonymous function (id: ??, ns: 0),
#  'Anthropic': Anthropic (id: ??, ns: 0),
#  'Apache Groovy': Apache Groovy (id: ??, ns: 0),
#  'Apache License': Apache License (id: ??, ns: 0),
#  'Apache webserver': Apache webserver (id: ??, ns: 0),
#  'Aphorism': Aphorism (id: ??, ns: 0),
#  'Apple M1': Apple M1 (id: ??, ns: 0),
#  'Apple Public Source License': Apple Public Source License (id: ??, ns: 0),
#  'ArXiv (identifier)': ArXiv (identifier) (id: ??, ns: 0),
#  'Arbitrary-precision arithmetic': Arbitrary-precision arithmetic (id: ??, ns: 0),
#  'ArcGIS': ArcGIS (id: ??, ns: 0),
#  'Arithmetic operations': Arithmetic operations (id: ??, ns: 0),
#  'ArkTS': ArkTS (id: ??, ns: 0),
#  'Array index': Array index (id: ??, ns: 0),
#  'Array slicing': Array slicing (id: ??, ns: 0),
#  'Artificial intelligence': Artificial intelligence (id: ??, ns: 0),
#  'Artificial neural network': Artificial neural network (id: ??, ns: 0),
#  'Artistic License': Artistic License (id: ??, ns: 0),
#  'Aspect-oriented programming': Aspect-oriented programming (id: ??, ns: 0),
#  'Assembly language': Assembly language (id: ??, ns: 0),
#  'Assertion (programming)': Assertion (programming) (id: ??, ns: 0),
#  'Assignment (computer science)': Assignment (computer science) (id: ??, ns: 0),
#  'Associative array': Associative array (id: ??, ns: 0),
#  'Astropy': Astropy (id: ??, ns: 0),
#  'Asynchronous Server Gateway Interface': Asynchronous Server Gateway Interface (id: ??, ns: 0),
#  'Attention (machine learning)': Attention (machine learning) (id: ??, ns: 0),
#  'Auto-GPT': Auto-GPT (id: ??, ns: 0),
#  'Autodesk Softimage': Autodesk Softimage (id: ??, ns: 0),
#  'Autoencoder': Autoencoder (id: ??, ns: 0),
#  'Automatic differentiation': Automatic differentiation (id: ??, ns: 0),
#  'Automation': Automation (id: ??, ns: 0),
#  'Autoregressive model': Autoregressive model (id: ??, ns: 0),
#  'BASIC': BASIC (id: ??, ns: 0),
#  'BERT (language model)': BERT (language model) (id: ??, ns: 0),
#  'BLOOM (language model)': BLOOM (language model) (id: ??, ns: 0),
#  'BMDP': BMDP (id: ??, ns: 0),
#  'BSD licenses': BSD licenses (id: ??, ns: 0),
#  'BV4.1 (software)': BV4.1 (software) (id: ??, ns: 0),
#  'Backporting': Backporting (id: ??, ns: 0),
#  'Backpropagation': Backpropagation (id: ??, ns: 0),
#  'Backward compatibility': Backward compatibility (id: ??, ns: 0),
#  'Bard (chatbot)': Bard (chatbot) (id: ??, ns: 0),
#  'Batch normalization': Batch normalization (id: ??, ns: 0),
#  'Bazel (software)': Bazel (software) (id: ??, ns: 0),
#  'Beerware': Beerware (id: ??, ns: 0),
#  'Benevolent dictator for life': Benevolent dictator for life (id: ??, ns: 0),
#  'Berkeley Software Distribution': Berkeley Software Distribution (id: ??, ns: 0),
#  'Beta release': Beta release (id: ??, ns: 0),
#  'Bibcode (identifier)': Bibcode (identifier) (id: ??, ns: 0),
#  'Biopython': Biopython (id: ??, ns: 0),
#  'Blender (software)': Blender (software) (id: ??, ns: 0),
#  'Block (programming)': Block (programming) (id: ??, ns: 0),
#  'Boo (programming language)': Boo (programming language) (id: ??, ns: 0),
#  'Boolean value': Boolean value (id: ??, ns: 0),
#  'Break statement': Break statement (id: ??, ns: 0),
#  'Bug tracker': Bug tracker (id: ??, ns: 0),
#  'Byte': Byte (id: ??, ns: 0),
#  'Bytecode': Bytecode (id: ??, ns: 0),
#  'C++': C++ (id: ??, ns: 0),
#  'C++11': C++11 (id: ??, ns: 0),
#  'C++17': C++17 (id: ??, ns: 0),
#  'C11 (C standard revision)': C11 (C standard revision) (id: ??, ns: 0),
#  'C89 (C version)': C89 (C version) (id: ??, ns: 0),
#  'C99': C99 (id: ??, ns: 0),
#  'CCP Games': CCP Games (id: ??, ns: 0),
#  'CERN': CERN (id: ??, ns: 0),
#  'CLPython': CLPython (id: ??, ns: 0),
#  'CLU (programming language)': CLU (programming language) (id: ??, ns: 0),
#  'COBOL': COBOL (id: ??, ns: 0),
#  'CPython': CPython (id: ??, ns: 0),
#  'CSPro': CSPro (id: ??, ns: 0),
#  'C (programming language)': C (programming language) (id: ??, ns: 0),
#  'C Sharp (programming language)': C Sharp (programming language) (id: ??, ns: 0),
#  'Cache poisoning': Cache poisoning (id: ??, ns: 0),
#  'Calculus': Calculus (id: ??, ns: 0),
#  'Call stack': Call stack (id: ??, ns: 0),
#  'Capella (notation program)': Capella (notation program) (id: ??, ns: 0),
#  'Centrum Wiskunde & Informatica': Centrum Wiskunde & Informatica (id: ??, ns: 0),
#  'Chapel (programming language)': Chapel (programming language) (id: ??, ns: 0),
#  'ChatGPT': ChatGPT (id: ??, ns: 0),
#  'CherryPy': CherryPy (id: ??, ns: 0),
#  'Chinchilla AI': Chinchilla AI (id: ??, ns: 0),
#  'Chris Lattner': Chris Lattner (id: ??, ns: 0),
#  'Cinema 4D': Cinema 4D (id: ??, ns: 0),
#  'CircuitPython': CircuitPython (id: ??, ns: 0),
#  'CiteSeerX (identifier)': CiteSeerX (identifier) (id: ??, ns: 0),
#  'Class (computer science)': Class (computer science) (id: ??, ns: 0),
#  'Cluster analysis': Cluster analysis (id: ??, ns: 0),
#  'Cobra (programming language)': Cobra (programming language) (id: ??, ns: 0),
#  'Code readability': Code readability (id: ??, ns: 0),
#  'CoffeeScript': CoffeeScript (id: ??, ns: 0),
#  'Combinatorics': Combinatorics (id: ??, ns: 0),
#  'Command line interpreter': Command line interpreter (id: ??, ns: 0),
#  'Commercial software': Commercial software (id: ??, ns: 0),
#  'Common Development and Distribution License': Common Development and Distribution License (id: ??, ns: 0),
#  'Common Language Runtime': Common Language Runtime (id: ??, ns: 0),
#  'Common Lisp': Common Lisp (id: ??, ns: 0),
#  'Community of practice': Community of practice (id: ??, ns: 0),
#  'Comparison of free and open-source software licenses': Comparison of free and open-source software licenses (id: ??, ns: 0),
#  'Comparison of free software for audio': Comparison of free software for audio (id: ??, ns: 0),
#  'Comparison of integrated development environments': Comparison of integrated development environments (id: ??, ns: 0),
#  'Comparison of numerical-analysis software': Comparison of numerical-analysis software (id: ??, ns: 0),
#  'Comparison of open-source and closed-source software': Comparison of open-source and closed-source software (id: ??, ns: 0),
#  'Comparison of open-source configuration management software': Comparison of open-source configuration management software (id: ??, ns: 0),
#  'Comparison of open-source operating systems': Comparison of open-source operating systems (id: ??, ns: 0),
#  'Comparison of open-source wireless drivers': Comparison of open-source wireless drivers (id: ??, ns: 0),
#  'Comparison of programming languages': Comparison of programming languages (id: ??, ns: 0),
#  'Comparison of shopping cart software': Comparison of shopping cart software (id: ??, ns: 0),
#  'Comparison of source-code-hosting facilities': Comparison of source-code-hosting facilities (id: ??, ns: 0),
#  'Comparison of statistical packages': Comparison of statistical packages (id: ??, ns: 0),
#  'Compile time': Compile time (id: ??, ns: 0),
#  'Compiler': Compiler (id: ??, ns: 0),
#  'Complex number': Complex number (id: ??, ns: 0),
#  'Computational learning theory': Computational learning theory (id: ??, ns: 0),
#  'Computational science': Computational science (id: ??, ns: 0),
#  'Computer algebra system': Computer algebra system (id: ??, ns: 0),
#  'Computer file': Computer file (id: ??, ns: 0),
#  'Computer networking': Computer networking (id: ??, ns: 0),
#  'Computer vision': Computer vision (id: ??, ns: 0),
#  'Concatenation': Concatenation (id: ??, ns: 0),
#  'Conditional (programming)': Conditional (programming) (id: ??, ns: 0),
#  'Contributor License Agreement': Contributor License Agreement (id: ??, ns: 0),
#  'Convolution': Convolution (id: ??, ns: 0),
#  'Convolutional neural network': Convolutional neural network (id: ??, ns: 0),
#  'Copyleft': Copyleft (id: ??, ns: 0),
#  'Coroutine': Coroutine (id: ??, ns: 0),
#  'Creative Commons license': Creative Commons license (id: ??, ns: 0),
#  'Cross-platform software': Cross-platform software (id: ??, ns: 0),
#  'CubicWeb': CubicWeb (id: ??, ns: 0),
#  'CumFreq': CumFreq (id: ??, ns: 0),
#  'Curly bracket programming language': Curly bracket programming language (id: ??, ns: 0),
#  'Cycle detection': Cycle detection (id: ??, ns: 0),
#  'Cython': Cython (id: ??, ns: 0),
#  'DADiSP': DADiSP (id: ??, ns: 0),
#  'DALL-E': DALL-E (id: ??, ns: 0),
#  'DAP (software)': DAP (software) (id: ??, ns: 0),
#  'D (programming language)': D (programming language) (id: ??, ns: 0),
#  'Data Desk': Data Desk (id: ??, ns: 0),
#  'Data analytics': Data analytics (id: ??, ns: 0),
#  'Data augmentation': Data augmentation (id: ??, ns: 0),
#  'Data mapper pattern': Data mapper pattern (id: ??, ns: 0),
#  'Data type': Data type (id: ??, ns: 0),
#  'Database': Database (id: ??, ns: 0),
#  'Dataplot': Dataplot (id: ??, ns: 0),
#  'David Silver (computer scientist)': David Silver (computer scientist) (id: ??, ns: 0),
#  'Debian Free Software Guidelines': Debian Free Software Guidelines (id: ??, ns: 0),
#  'Decimal floating point': Decimal floating point (id: ??, ns: 0),
#  'Deep learning': Deep learning (id: ??, ns: 0),
#  'Deep learning speech synthesis': Deep learning speech synthesis (id: ??, ns: 0),
#  'Definite clause grammar': Definite clause grammar (id: ??, ns: 0),
#  'Definition of Free Cultural Works': Definition of Free Cultural Works (id: ??, ns: 0),
#  'Demis Hassabis': Demis Hassabis (id: ??, ns: 0),
#  'Denial-of-service attack': Denial-of-service attack (id: ??, ns: 0),
#  'Design by contract': Design by contract (id: ??, ns: 0),
#  'Device driver': Device driver (id: ??, ns: 0),
#  'Differentiable function': Differentiable function (id: ??, ns: 0),
#  'Differentiable neural computer': Differentiable neural computer (id: ??, ns: 0),
#  'Differentiable programming': Differentiable programming (id: ??, ns: 0),
#  'Diffusion process': Diffusion process (id: ??, ns: 0),
#  'Digital image processing': Digital image processing (id: ??, ns: 0),
#  'Digital rights management': Digital rights management (id: ??, ns: 0),
#  'Dispose pattern': Dispose pattern (id: ??, ns: 0),
#  'Django (web framework)': Django (web framework) (id: ??, ns: 0),
#  'Documentation': Documentation (id: ??, ns: 0),
#  'Doi (identifier)': Doi (identifier) (id: ??, ns: 0),
#  'Double-precision floating-point format': Double-precision floating-point format (id: ??, ns: 0),
#  'Doxygen': Doxygen (id: ??, ns: 0),
#  'Dropbox (service)': Dropbox (service) (id: ??, ns: 0),
#  'Duck typing': Duck typing (id: ??, ns: 0),
#  'Dylan (programming language)': Dylan (programming language) (id: ??, ns: 0),
#  'Dynamic type': Dynamic type (id: ??, ns: 0),
#  'Dynamic typing': Dynamic typing (id: ??, ns: 0),
#  'ECMAScript': ECMAScript (id: ??, ns: 0),
#  'EViews': EViews (id: ??, ns: 0),
#  'Echo state network': Echo state network (id: ??, ns: 0),
#  'Eclipse Public License': Eclipse Public License (id: ??, ns: 0),
#  'EleutherAI': EleutherAI (id: ??, ns: 0),
#  'Ellipsis (programming operator)': Ellipsis (programming operator) (id: ??, ns: 0),
#  'End-of-life product': End-of-life product (id: ??, ns: 0),
#  'Epi Info': Epi Info (id: ??, ns: 0),
#  'Eric Python IDE': Eric Python IDE (id: ??, ns: 0),
#  'Erlang (programming language)': Erlang (programming language) (id: ??, ns: 0),
#  'Escape character': Escape character (id: ??, ns: 0),
#  'Esri': Esri (id: ??, ns: 0),
#  'Euler (software)': Euler (software) (id: ??, ns: 0),
#  'Exception handling': Exception handling (id: ??, ns: 0),
#  'Exception handling (programming)': Exception handling (programming) (id: ??, ns: 0),
#  'Exception handling syntax': Exception handling syntax (id: ??, ns: 0),
#  'Exponentiation': Exponentiation (id: ??, ns: 0),
#  'Expression (computer science)': Expression (computer science) (id: ??, ns: 0),
#  'Extensibility': Extensibility (id: ??, ns: 0),
#  'FEATool Multiphysics': FEATool Multiphysics (id: ??, ns: 0),
#  'F Sharp (programming language)': F Sharp (programming language) (id: ??, ns: 0),
#  'Facebook': Facebook (id: ??, ns: 0),
#  'Facial recognition system': Facial recognition system (id: ??, ns: 0),
#  'Factorial': Factorial (id: ??, ns: 0),
#  'FastAPI': FastAPI (id: ??, ns: 0),
#  'Fedora Linux': Fedora Linux (id: ??, ns: 0),
#  'Fei-Fei Li': Fei-Fei Li (id: ??, ns: 0),
#  'Fellow': Fellow (id: ??, ns: 0),
#  'Filename extension': Filename extension (id: ??, ns: 0),
#  'Finite element method': Finite element method (id: ??, ns: 0),
#  'Firaxis Games': Firaxis Games (id: ??, ns: 0),
#  'First-class continuations': First-class continuations (id: ??, ns: 0),
#  'Flask (web framework)': Flask (web framework) (id: ??, ns: 0),
#  'Floating-point arithmetic': Floating-point arithmetic (id: ??, ns: 0),
#  'Floor division': Floor division (id: ??, ns: 0),
#  'Flux (machine-learning framework)': Flux (machine-learning framework) (id: ??, ns: 0),
#  'Foobar': Foobar (id: ??, ns: 0),
#  'Foreach': Foreach (id: ??, ns: 0),
#  'Fork (software development)': Fork (software development) (id: ??, ns: 0),
#  'Forth (programming language)': Forth (programming language) (id: ??, ns: 0),
#  'Fortran': Fortran (id: ??, ns: 0),
#  'Fortress (programming language)': Fortress (programming language) (id: ??, ns: 0),
#  'Free-software license': Free-software license (id: ??, ns: 0),
#  'FreeBSD': FreeBSD (id: ??, ns: 0),
#  'FreeCAD': FreeCAD (id: ??, ns: 0),
#  'FreeFem++': FreeFem++ (id: ??, ns: 0),
#  'FreeMat': FreeMat (id: ??, ns: 0),
#  'Free Software Foundation': Free Software Foundation (id: ??, ns: 0),
#  'Free Software Movement of India': Free Software Movement of India (id: ??, ns: 0),
#  'Free and open-source graphics device driver': Free and open-source graphics device driver (id: ??, ns: 0),
#  'Free and open-source software': Free and open-source software (id: ??, ns: 0),
#  'Free license': Free license (id: ??, ns: 0),
#  'Free software': Free software (id: ??, ns: 0),
#  'Free software movement': Free software movement (id: ??, ns: 0),
#  'Freeware': Freeware (id: ??, ns: 0),
#  'Function (computing)': Function (computing) (id: ??, ns: 0),
#  'Function (programming)': Function (programming) (id: ??, ns: 0),
#  'Functional programming': Functional programming (id: ??, ns: 0),
#  'GAUSS (software)': GAUSS (software) (id: ??, ns: 0),
#  'GDScript': GDScript (id: ??, ns: 0),
#  'GIMP': GIMP (id: ??, ns: 0),
#  'GNU Affero General Public License': GNU Affero General Public License (id: ??, ns: 0),
#  'GNU Debugger': GNU Debugger (id: ??, ns: 0),
#  'GNU General Public License': GNU General Public License (id: ??, ns: 0),
#  'GNU Lesser General Public License': GNU Lesser General Public License (id: ??, ns: 0),
#  'GNU Manifesto': GNU Manifesto (id: ??, ns: 0),
#  'GNU Octave': GNU Octave (id: ??, ns: 0),
#  'GPT-1': GPT-1 (id: ??, ns: 0),
#  'GPT-2': GPT-2 (id: ??, ns: 0),
#  'GPT-3': GPT-3 (id: ??, ns: 0),
#  'GPT-4': GPT-4 (id: ??, ns: 0),
#  'GPT-J': GPT-J (id: ??, ns: 0),
#  'GTK': GTK (id: ??, ns: 0),
#  'Garbage collection (computer science)': Garbage collection (computer science) (id: ??, ns: 0),
#  'Gated recurrent unit': Gated recurrent unit (id: ??, ns: 0),
#  'Gemini (language model)': Gemini (language model) (id: ??, ns: 0),
#  'General-purpose programming language': General-purpose programming language (id: ??, ns: 0),
#  'Generational list of programming languages': Generational list of programming languages (id: ??, ns: 0),
#  'Generative adversarial network': Generative adversarial network (id: ??, ns: 0),
#  'Generator (computer programming)': Generator (computer programming) (id: ??, ns: 0),
#  'Generator (computer science)': Generator (computer science) (id: ??, ns: 0),
#  'Genie (programming language)': Genie (programming language) (id: ??, ns: 0),
#  'Genius (mathematics software)': Genius (mathematics software) (id: ??, ns: 0),
#  'Genstat': Genstat (id: ??, ns: 0),
#  'Gentoo Linux': Gentoo Linux (id: ??, ns: 0),
#  'Geoffrey Hinton': Geoffrey Hinton (id: ??, ns: 0),
#  'GitHub': GitHub (id: ??, ns: 0),
#  'Global interpreter lock': Global interpreter lock (id: ??, ns: 0),
#  'Gmsh': Gmsh (id: ??, ns: 0),
#  'Go (programming language)': Go (programming language) (id: ??, ns: 0),
#  'Godot (game engine)': Godot (game engine) (id: ??, ns: 0),
#  'Google': Google (id: ??, ns: 0),
#  'Google App Engine': Google App Engine (id: ??, ns: 0),
#  'Google DeepMind': Google DeepMind (id: ??, ns: 0),
#  'Google JAX': Google JAX (id: ??, ns: 0),
#  'Gradient descent': Gradient descent (id: ??, ns: 0),
#  'GraphPad InStat': GraphPad InStat (id: ??, ns: 0),
#  'GraphPad Prism': GraphPad Prism (id: ??, ns: 0),
#  'Graph neural network': Graph neural network (id: ??, ns: 0),
#  'Graphcore': Graphcore (id: ??, ns: 0),
#  'Graphical user interface': Graphical user interface (id: ??, ns: 0),
#  'Graphviz': Graphviz (id: ??, ns: 0),
#  'Gratis versus libre': Gratis versus libre (id: ??, ns: 0),
#  'Gretl': Gretl (id: ??, ns: 0),
#  'Grok (web framework)': Grok (web framework) (id: ??, ns: 0),
#  'Groovy (programming language)': Groovy (programming language) (id: ??, ns: 0),
#  'Guido van Rossum': Guido van Rossum (id: ??, ns: 0),
#  'Half-open interval': Half-open interval (id: ??, ns: 0),
#  'Hallucination (artificial intelligence)': Hallucination (artificial intelligence) (id: ??, ns: 0),
#  'Handwriting recognition': Handwriting recognition (id: ??, ns: 0),
#  'Hardware description language': Hardware description language (id: ??, ns: 0),
#  'Haskell': Haskell (id: ??, ns: 0),
#  'Here document': Here document (id: ??, ns: 0),
#  'High-level programming language': High-level programming language (id: ??, ns: 0),
#  'History of Python': History of Python (id: ??, ns: 0),
#  'History of free and open-source software': History of free and open-source software (id: ??, ns: 0),
#  'History of programming languages': History of programming languages (id: ??, ns: 0),
#  'Houdini (software)': Houdini (software) (id: ??, ns: 0),
#  'Huawei': Huawei (id: ??, ns: 0),
#  'Huawei PanGu': Huawei PanGu (id: ??, ns: 0),
#  'Hugging Face': Hugging Face (id: ??, ns: 0),
#  'Human image synthesis': Human image synthesis (id: ??, ns: 0),
#  'Hypertext Transfer Protocol': Hypertext Transfer Protocol (id: ??, ns: 0),
#  'IBM Granite': IBM Granite (id: ??, ns: 0),
#  'IBM Watson': IBM Watson (id: ??, ns: 0),
#  'IBM Watsonx': IBM Watsonx (id: ??, ns: 0),
#  'IDLE': IDLE (id: ??, ns: 0),
#  'IDLE (Python)': IDLE (Python) (id: ??, ns: 0),
#  'IEEE 754': IEEE 754 (id: ??, ns: 0),
#  'IOS': IOS (id: ??, ns: 0),
#  'IPython': IPython (id: ??, ns: 0),
#  'ISBN (identifier)': ISBN (identifier) (id: ??, ns: 0),
#  'ISC license': ISC license (id: ??, ns: 0),
#  'ISSN (identifier)': ISSN (identifier) (id: ??, ns: 0),
#  'ITA Software': ITA Software (id: ??, ns: 0),
#  'Ian Goodfellow': Ian Goodfellow (id: ??, ns: 0),
#  'Icon (programming language)': Icon (programming language) (id: ??, ns: 0),
#  'If-then-else': If-then-else (id: ??, ns: 0),
#  'Ilya Sutskever': Ilya Sutskever (id: ??, ns: 0),
#  'Image processing': Image processing (id: ??, ns: 0),
#  'Immutable': Immutable (id: ??, ns: 0),
#  'Immutable object': Immutable object (id: ??, ns: 0),
#  'Imperative programming': Imperative programming (id: ??, ns: 0),
#  'Include directive': Include directive (id: ??, ns: 0),
#  'Inductive bias': Inductive bias (id: ??, ns: 0),
#  'Industrial Light & Magic': Industrial Light & Magic (id: ??, ns: 0),
#  'Infix notation': Infix notation (id: ??, ns: 0),
#  'InfoWorld': InfoWorld (id: ??, ns: 0),
#  'Information geometry': Information geometry (id: ??, ns: 0),
#  'Information security': Information security (id: ??, ns: 0),
#  'Inkscape': Inkscape (id: ??, ns: 0),
#  'Instagram': Instagram (id: ??, ns: 0),
#  'Instance data': Instance data (id: ??, ns: 0),
#  'Integer (computer science)': Integer (computer science) (id: ??, ns: 0),
#  'Integrated development environment': Integrated development environment (id: ??, ns: 0),
#  'IronPython': IronPython (id: ??, ns: 0),
#  'Iterator': Iterator (id: ??, ns: 0),
#  'JASP': JASP (id: ??, ns: 0),
#  'JMP (statistical software)': JMP (statistical software) (id: ??, ns: 0),
#  'JMulTi': JMulTi (id: ??, ns: 0),
#  'JavaScript': JavaScript (id: ??, ns: 0),
#  'Java (programming language)': Java (programming language) (id: ??, ns: 0),
#  'Java (software platform)': Java (software platform) (id: ??, ns: 0),
#  'Jeff Dean (computer scientist)': Jeff Dean (computer scientist) (id: ??, ns: 0),
#  'Julia (programming language)': Julia (programming language) (id: ??, ns: 0),
#  'Just-in-time compilation': Just-in-time compilation (id: ??, ns: 0),
#  'Just-in-time compiler': Just-in-time compiler (id: ??, ns: 0),
#  'Just another Gibbs sampler': Just another Gibbs sampler (id: ??, ns: 0),
#  'Jython': Jython (id: ??, ns: 0),
#  'Jürgen Schmidhuber': Jürgen Schmidhuber (id: ??, ns: 0),
#  'Keras': Keras (id: ??, ns: 0),
#  'Kotlin (programming language)': Kotlin (programming language) (id: ??, ns: 0),
#  'LIMDEP': LIMDEP (id: ??, ns: 0),
#  'LISREL': LISREL (id: ??, ns: 0),
#  'LLVM': LLVM (id: ??, ns: 0),
#  'LLaMA': LLaMA (id: ??, ns: 0),
#  'LaMDA': LaMDA (id: ??, ns: 0),
#  'LabVIEW': LabVIEW (id: ??, ns: 0),
#  'Lambda (programming)': Lambda (programming) (id: ??, ns: 0),
#  'Language binding': Language binding (id: ??, ns: 0),
#  'Language model': Language model (id: ??, ns: 0),
#  'Large language model': Large language model (id: ??, ns: 0),
#  'Late binding': Late binding (id: ??, ns: 0),
#  'Lazy evaluation': Lazy evaluation (id: ??, ns: 0),
#  'Lego Mindstorms EV3': Lego Mindstorms EV3 (id: ??, ns: 0),
#  'LibreOffice': LibreOffice (id: ??, ns: 0),
#  'License proliferation': License proliferation (id: ??, ns: 0),
#  'LightWave 3D': LightWave 3D (id: ??, ns: 0),
#  'Linux': Linux (id: ??, ns: 0),
#  'Linux distribution': Linux distribution (id: ??, ns: 0),
#  'Lisp (programming language)': Lisp (programming language) (id: ??, ns: 0),
#  'List (computer science)': List (computer science) (id: ??, ns: 0),
#  'List comprehension': List comprehension (id: ??, ns: 0),
#  'List comprehensions': List comprehensions (id: ??, ns: 0),
#  'List of Python software': List of Python software (id: ??, ns: 0),
#  'List of commercial open-source applications and services': List of commercial open-source applications and services (id: ??, ns: 0),
#  'List of formerly free and open-source software': List of formerly free and open-source software (id: ??, ns: 0),
#  'List of formerly proprietary software': List of formerly proprietary software (id: ??, ns: 0),
#  'List of free-software events': List of free-software events (id: ??, ns: 0),
#  'List of free and open-source Android applications': List of free and open-source Android applications (id: ??, ns: 0),
#  'List of free and open-source iOS applications': List of free and open-source iOS applications (id: ??, ns: 0),
#  'List of free and open-source software organizations': List of free and open-source software organizations (id: ??, ns: 0),
#  'List of free and open-source software packages': List of free and open-source software packages (id: ??, ns: 0),
#  'List of free and open-source web applications': List of free and open-source web applications (id: ??, ns: 0),
#  'List of free software project directories': List of free software project directories (id: ??, ns: 0),
#  'List of free television software': List of free television software (id: ??, ns: 0),
#  'List of integrated development environments for Python': List of integrated development environments for Python (id: ??, ns: 0),
#  'List of numerical-analysis software': List of numerical-analysis software (id: ??, ns: 0),
#  'List of office suites': List of office suites (id: ??, ns: 0),
#  'List of open-source bioinformatics software': List of open-source bioinformatics software (id: ??, ns: 0),
#  'List of open-source codecs': List of open-source codecs (id: ??, ns: 0),
#  'List of open-source health software': List of open-source health software (id: ??, ns: 0),
#  'List of open-source routing platforms': List of open-source routing platforms (id: ??, ns: 0),
#  'List of open-source software for mathematics': List of open-source software for mathematics (id: ??, ns: 0),
#  'List of open-source video games': List of open-source video games (id: ??, ns: 0),
#  'List of programming languages': List of programming languages (id: ??, ns: 0),
#  'List of programming languages by type': List of programming languages by type (id: ??, ns: 0),
#  'List of statistical software': List of statistical software (id: ??, ns: 0),
#  'Lock (computer science)': Lock (computer science) (id: ??, ns: 0),
#  'Logic programming': Logic programming (id: ??, ns: 0),
#  'Long-term support': Long-term support (id: ??, ns: 0),
#  'Long short-term memory': Long short-term memory (id: ??, ns: 0),
#  'Loss functions for classification': Loss functions for classification (id: ??, ns: 0),
#  'Lua (programming language)': Lua (programming language) (id: ??, ns: 0),
#  'MATLAB': MATLAB (id: ??, ns: 0),
#  'MFEM': MFEM (id: ??, ns: 0),
#  'MIME': MIME (id: ??, ns: 0),
#  'MIT Computer Science and Artificial Intelligence Laboratory': MIT Computer Science and Artificial Intelligence Laboratory (id: ??, ns: 0),
#  'MIT License': MIT License (id: ??, ns: 0),
#  'ML (programming language)': ML (programming language) (id: ??, ns: 0),
#  'MLwiN': MLwiN (id: ??, ns: 0),
#  'MacOS': MacOS (id: ??, ns: 0),
#  'Machine learning': Machine learning (id: ??, ns: 0),
#  'Mamba (deep learning)': Mamba (deep learning) (id: ??, ns: 0),
#  'Maple (software)': Maple (software) (id: ??, ns: 0),
#  'Mathcad': Mathcad (id: ??, ns: 0),
#  'Mathematics': Mathematics (id: ??, ns: 0),
#  'Matplotlib': Matplotlib (id: ??, ns: 0),
#  'Matrix multiplication': Matrix multiplication (id: ??, ns: 0),
#  'Maya (software)': Maya (software) (id: ??, ns: 0),
#  'MedCalc': MedCalc (id: ??, ns: 0),
#  'Memory management': Memory management (id: ??, ns: 0),
#  'Memristor': Memristor (id: ??, ns: 0),
#  'Mercurial': Mercurial (id: ??, ns: 0),
#  'Meta AI': Meta AI (id: ??, ns: 0),
#  'Metaclass': Metaclass (id: ??, ns: 0),
#  'Metaobject': Metaobject (id: ??, ns: 0),
#  'Metaprogramming': Metaprogramming (id: ??, ns: 0),
#  'Metasyntactic variable': Metasyntactic variable (id: ??, ns: 0),
#  'Method (computing)': Method (computing) (id: ??, ns: 0),
#  'Method (programming)': Method (programming) (id: ??, ns: 0),
#  'MicroPython': MicroPython (id: ??, ns: 0),
#  'Microcontroller': Microcontroller (id: ??, ns: 0),
#  'Microfit': Microfit (id: ??, ns: 0),
#  'Microsoft Excel': Microsoft Excel (id: ??, ns: 0),
#  'Microsoft Open Specification Promise': Microsoft Open Specification Promise (id: ??, ns: 0),
#  'Microsoft Windows': Microsoft Windows (id: ??, ns: 0),
#  'Microthread': Microthread (id: ??, ns: 0),
#  'Midjourney': Midjourney (id: ??, ns: 0),
#  'Mila (research institute)': Mila (research institute) (id: ??, ns: 0),
#  'MindSpore': MindSpore (id: ??, ns: 0),
#  'Minitab': Minitab (id: ??, ns: 0),
#  'Mobile app': Mobile app (id: ??, ns: 0),
#  'Mod wsgi': Mod wsgi (id: ??, ns: 0),
#  'Modo (software)': Modo (software) (id: ??, ns: 0),
#  'Modula-3': Modula-3 (id: ??, ns: 0),
#  'Modular programming': Modular programming (id: ??, ns: 0),
#  'Modulo operation': Modulo operation (id: ??, ns: 0),
#  'Mojo (programming language)': Mojo (programming language) (id: ??, ns: 0),
#  'Monty Python': Monty Python (id: ??, ns: 0),
#  'MotionBuilder': MotionBuilder (id: ??, ns: 0),
#  'Mozilla Public License': Mozilla Public License (id: ??, ns: 0),
#  'Mozilla software rebranded by Debian': Mozilla software rebranded by Debian (id: ??, ns: 0),
#  'MuZero': MuZero (id: ??, ns: 0),
#  'Multi-paradigm programming language': Multi-paradigm programming language (id: ??, ns: 0),
#  'Multilayer perceptron': Multilayer perceptron (id: ??, ns: 0),
#  'Multimedia': Multimedia (id: ??, ns: 0),
#  'Multithreading (computer architecture)': Multithreading (computer architecture) (id: ??, ns: 0),
#  'Musical notation': Musical notation (id: ??, ns: 0),
#  'MyHDL': MyHDL (id: ??, ns: 0),
#  'N900': N900 (id: ??, ns: 0),
#  'NASA': NASA (id: ??, ns: 0),
#  'NCSS (statistical software)': NCSS (statistical software) (id: ??, ns: 0),
#  'NOP (code)': NOP (code) (id: ??, ns: 0),
#  'Name resolution (programming languages)': Name resolution (programming languages) (id: ??, ns: 0),
#  'Natural language processing': Natural language processing (id: ??, ns: 0),
#  'Neologism': Neologism (id: ??, ns: 0),
#  'NetBSD': NetBSD (id: ??, ns: 0),
#  'Netherlands': Netherlands (id: ??, ns: 0),
#  'Neural Turing machine': Neural Turing machine (id: ??, ns: 0),
#  'Neural machine translation': Neural machine translation (id: ??, ns: 0),
#  'Neuromorphic engineering': Neuromorphic engineering (id: ??, ns: 0),
#  'Nevow': Nevow (id: ??, ns: 0),
#  'Nim (programming language)': Nim (programming language) (id: ??, ns: 0),
#  'Ninja-IDE': Ninja-IDE (id: ??, ns: 0),
#  'Nokia': Nokia (id: ??, ns: 0),
#  'Non-English-based programming languages': Non-English-based programming languages (id: ??, ns: 0),
#  'Norman Jouppi': Norman Jouppi (id: ??, ns: 0),
#  'Notebook interface': Notebook interface (id: ??, ns: 0),
#  'Nuitka': Nuitka (id: ??, ns: 0),
#  'Nuke (software)': Nuke (software) (id: ??, ns: 0),
#  'Null pointer': Null pointer (id: ??, ns: 0),
#  'NumPy': NumPy (id: ??, ns: 0),
#  'Numba': Numba (id: ??, ns: 0),
#  'Number theory': Number theory (id: ??, ns: 0),
#  'Numerical mathematics': Numerical mathematics (id: ??, ns: 0),
#  "O'Reilly Media": O'Reilly Media (id: ??, ns: 0),
#  "O'Reilly Open Source Convention": O'Reilly Open Source Convention (id: ??, ns: 0),
#  'OS/2': OS/2 (id: ??, ns: 0),
#  'Object-oriented programming': Object-oriented programming (id: ??, ns: 0),
#  'Object (computer science)': Object (computer science) (id: ??, ns: 0),
#  'Object Pascal': Object Pascal (id: ??, ns: 0),
#  'Objective-C': Objective-C (id: ??, ns: 0),
#  'Off-side rule': Off-side rule (id: ??, ns: 0),
#  'One Laptop per Child': One Laptop per Child (id: ??, ns: 0),
#  'Open-core model': Open-core model (id: ??, ns: 0),
#  'Open-source-software movement': Open-source-software movement (id: ??, ns: 0),
#  'Open-source hardware': Open-source hardware (id: ??, ns: 0),
#  'Open-source license': Open-source license (id: ??, ns: 0),
#  'Open-source software': Open-source software (id: ??, ns: 0),
#  'Open-source software advocacy': Open-source software advocacy (id: ??, ns: 0),
#  'Open-source software development': Open-source software development (id: ??, ns: 0),
#  'Open-source software security': Open-source software security (id: ??, ns: 0),
#  'OpenAI': OpenAI (id: ??, ns: 0),
#  'OpenAI Five': OpenAI Five (id: ??, ns: 0),
#  'OpenBSD': OpenBSD (id: ??, ns: 0),
#  'OpenBUGS': OpenBUGS (id: ??, ns: 0),
#  'OpenCV': OpenCV (id: ??, ns: 0),
#  'OpenFOAM': OpenFOAM (id: ??, ns: 0),
#  'OpenVMS': OpenVMS (id: ??, ns: 0),
#  'Operating system': Operating system (id: ??, ns: 0),
#  'Operator overloading': Operator overloading (id: ??, ns: 0),
#  'Optical character recognition': Optical character recognition (id: ??, ns: 0),
#  'Optional typing': Optional typing (id: ??, ns: 0),
#  'Orange (software)': Orange (software) (id: ??, ns: 0),
#  'Order of operations': Order of operations (id: ??, ns: 0),
#  'Outline of free software': Outline of free software (id: ??, ns: 0),
#  'Overfitting': Overfitting (id: ??, ns: 0),
#  'OxMetrics': OxMetrics (id: ??, ns: 0),
#  'PHP': PHP (id: ??, ns: 0),
#  'PSPP': PSPP (id: ??, ns: 0),
#  'PaLM': PaLM (id: ??, ns: 0),
#  'Package management system': Package management system (id: ??, ns: 0),
#  'Paint Shop Pro': Paint Shop Pro (id: ??, ns: 0),
#  'Pascal (programming language)': Pascal (programming language) (id: ??, ns: 0),
#  'Pattern matching': Pattern matching (id: ??, ns: 0),
#  'Pattern recognition': Pattern recognition (id: ??, ns: 0),
#  'Pdoc': Pdoc (id: ??, ns: 0),
#  'Perl': Perl (id: ??, ns: 0),
#  'Permissive software license': Permissive software license (id: ??, ns: 0),
#  'Peter Norvig': Peter Norvig (id: ??, ns: 0),
#  'Pip (package manager)': Pip (package manager) (id: ??, ns: 0),
#  'Pointer (computer programming)': Pointer (computer programming) (id: ??, ns: 0),
#  'Portage (software)': Portage (software) (id: ??, ns: 0),
#  'Ported': Ported (id: ??, ns: 0),
#  'Premature optimization': Premature optimization (id: ??, ns: 0),
#  'Prettyprint': Prettyprint (id: ??, ns: 0),
#  'Printf format string': Printf format string (id: ??, ns: 0),
#  'ProbLog': ProbLog (id: ??, ns: 0),
#  'Procedural programming': Procedural programming (id: ??, ns: 0),
#  'Programming idiom': Programming idiom (id: ??, ns: 0),
#  'Programming language': Programming language (id: ??, ns: 0),
#  'Programming language implementation': Programming language implementation (id: ??, ns: 0),
#  'Programming paradigm': Programming paradigm (id: ??, ns: 0),
#  'Project Debater': Project Debater (id: ??, ns: 0),
#  'Project Jupyter': Project Jupyter (id: ??, ns: 0),
#  'Prolog': Prolog (id: ??, ns: 0),
#  'Prompt engineering': Prompt engineering (id: ??, ns: 0),
#  'Proprietary device driver': Proprietary device driver (id: ??, ns: 0),
#  'Proprietary firmware': Proprietary firmware (id: ??, ns: 0),
#  'Proprietary software': Proprietary software (id: ??, ns: 0),
#  'Pseudorandom number generator': Pseudorandom number generator (id: ??, ns: 0),
#  'Psyco': Psyco (id: ??, ns: 0),
#  'Public-domain software': Public-domain software (id: ??, ns: 0),
#  'Public domain': Public domain (id: ??, ns: 0),
#  'PyCharm': PyCharm (id: ??, ns: 0),
#  'PyCon': PyCon (id: ??, ns: 0),
#  'PyDev': PyDev (id: ??, ns: 0),
#  'PyGTK': PyGTK (id: ??, ns: 0),
#  'PyLadies': PyLadies (id: ??, ns: 0),
#  'PyMC3': PyMC3 (id: ??, ns: 0),
#  'PyPy': PyPy (id: ??, ns: 0),
#  'PyQt': PyQt (id: ??, ns: 0),
#  'PyS60': PyS60 (id: ??, ns: 0),
#  'PyTorch': PyTorch (id: ??, ns: 0),
#  'Pydoc': Pydoc (id: ??, ns: 0),
#  'Pygame': Pygame (id: ??, ns: 0),
#  'Pyjs': Pyjs (id: ??, ns: 0),
#  'Pylons (web framework)': Pylons (web framework) (id: ??, ns: 0),
#  'Pylons project': Pylons project (id: ??, ns: 0),
#  'Pyramid (web framework)': Pyramid (web framework) (id: ??, ns: 0),
#  'Pyrex (programming language)': Pyrex (programming language) (id: ??, ns: 0),
#  'PythonAnywhere': PythonAnywhere (id: ??, ns: 0),
#  'Python Conference': Python Conference (id: ??, ns: 0),
#  'Python License': Python License (id: ??, ns: 0),
#  'Python Package Index': Python Package Index (id: ??, ns: 0),
#  'Python Software Foundation': Python Software Foundation (id: ??, ns: 0),
#  'Python Software Foundation License': Python Software Foundation License (id: ??, ns: 0),
#  'Python for S60': Python for S60 (id: ??, ns: 0),
#  'Python syntax and semantics': Python syntax and semantics (id: ??, ns: 0),
#  'Q-learning': Q-learning (id: ??, ns: 0),
#  'Qt (software)': Qt (software) (id: ??, ns: 0),
#  'Quixote (web framework)': Quixote (web framework) (id: ??, ns: 0),
#  'RATS (software)': RATS (software) (id: ??, ns: 0),
#  'RExcel': RExcel (id: ??, ns: 0),
#  'RPython': RPython (id: ??, ns: 0),
#  'RStudio': RStudio (id: ??, ns: 0),
#  'R (programming language)': R (programming language) (id: ??, ns: 0),
#  'Raspberry Pi': Raspberry Pi (id: ??, ns: 0),
#  'Raspberry Pi OS': Raspberry Pi OS (id: ??, ns: 0),
#  'Rational number': Rational number (id: ??, ns: 0),
#  'Raw string': Raw string (id: ??, ns: 0),
#  'Read–eval–print loop': Read–eval–print loop (id: ??, ns: 0),
#  'Rectifier (neural networks)': Rectifier (neural networks) (id: ??, ns: 0),
#  'Recurrent neural network': Recurrent neural network (id: ??, ns: 0),
#  'Red Hat Linux': Red Hat Linux (id: ??, ns: 0),
#  'Reddit': Reddit (id: ??, ns: 0),
#  'Reference counting': Reference counting (id: ??, ns: 0),
#  'Reference implementation': Reference implementation (id: ??, ns: 0),
#  'Reflective programming': Reflective programming (id: ??, ns: 0),
#  'Regression analysis': Regression analysis (id: ??, ns: 0),
#  'Regular expression': Regular expression (id: ??, ns: 0),
#  'Regularization (mathematics)': Regularization (mathematics) (id: ??, ns: 0),
#  'Relational database': Relational database (id: ??, ns: 0),
#  'Remote code execution': Remote code execution (id: ??, ns: 0),
#  'Residual neural network': Residual neural network (id: ??, ns: 0),
#  'Resource acquisition is initialization': Resource acquisition is initialization (id: ??, ns: 0),
#  'Revolution Analytics': Revolution Analytics (id: ??, ns: 0),
#  'Revolution OS': Revolution OS (id: ??, ns: 0),
#  'Ring-lang': Ring-lang (id: ??, ns: 0),
#  'Ring (programming language)': Ring (programming language) (id: ??, ns: 0),
#  'Robot control': Robot control (id: ??, ns: 0),
#  'Round to even': Round to even (id: ??, ns: 0),
#  'Rounding': Rounding (id: ??, ns: 0),
#  'Roundup (issue tracker)': Roundup (issue tracker) (id: ??, ns: 0),
#  'Ruby (programming language)': Ruby (programming language) (id: ??, ns: 0),
#  'Run-time algorithm specialization': Run-time algorithm specialization (id: ??, ns: 0),
#  'Rust (programming language)': Rust (programming language) (id: ??, ns: 0),
#  'S-PLUS': S-PLUS (id: ??, ns: 0),
#  'S2CID (identifier)': S2CID (identifier) (id: ??, ns: 0),
#  'SAS (software)': SAS (software) (id: ??, ns: 0),
#  'SCO–Linux disputes': SCO–Linux disputes (id: ??, ns: 0),
#  'SETL': SETL (id: ??, ns: 0),
#  'SHAZAM (software)': SHAZAM (software) (id: ??, ns: 0),
#  'SOFA Statistics': SOFA Statistics (id: ??, ns: 0),
#  'SPSS': SPSS (id: ??, ns: 0),
#  'SPSS Modeler': SPSS Modeler (id: ??, ns: 0),
#  'SQL': SQL (id: ??, ns: 0),
#  'SQLAlchemy': SQLAlchemy (id: ??, ns: 0),
#  'SUDAAN': SUDAAN (id: ??, ns: 0),
#  'SYSTAT (statistics package)': SYSTAT (statistics package) (id: ??, ns: 0),
#  'SageMath': SageMath (id: ??, ns: 0),
#  'Salome (software)': Salome (software) (id: ??, ns: 0),
#  'Scheme (programming language)': Scheme (programming language) (id: ??, ns: 0),
#  'SciPy': SciPy (id: ??, ns: 0),
#  'ScicosLab': ScicosLab (id: ??, ns: 0),
#  'Scientific computing': Scientific computing (id: ??, ns: 0),
#  'Scikit-learn': Scikit-learn (id: ??, ns: 0),
#  'Scilab': Scilab (id: ??, ns: 0),
#  'Scorewriter': Scorewriter (id: ??, ns: 0),
#  'Scratch (programming language)': Scratch (programming language) (id: ??, ns: 0),
#  'Scribus': Scribus (id: ??, ns: 0),
#  'Scripting language': Scripting language (id: ??, ns: 0),
#  'SegReg': SegReg (id: ??, ns: 0),
#  'Self-driving car': Self-driving car (id: ??, ns: 0),
#  'Self-hosting (web services)': Self-hosting (web services) (id: ??, ns: 0),
#  'Seq2seq': Seq2seq (id: ??, ns: 0),
#  'Series 60': Series 60 (id: ??, ns: 0),
#  'Set (computer science)': Set (computer science) (id: ??, ns: 0),
#  'Shallow copy': Shallow copy (id: ??, ns: 0),
#  'Shared Source Initiative': Shared Source Initiative (id: ??, ns: 0),
#  'Shed Skin': Shed Skin (id: ??, ns: 0),
#  'Shell script': Shell script (id: ??, ns: 0),
#  'SigmaStat': SigmaStat (id: ??, ns: 0),
#  'Sigmoid function': Sigmoid function (id: ??, ns: 0),
#  'SimFiT': SimFiT (id: ??, ns: 0),
#  'Simple DirectMedia Layer': Simple DirectMedia Layer (id: ??, ns: 0),
#  'Simula': Simula (id: ??, ns: 0),
#  'Single-board computer': Single-board computer (id: ??, ns: 0),
#  'Single-precision': Single-precision (id: ??, ns: 0),
#  'Sleepycat License': Sleepycat License (id: ??, ns: 0),
#  'Smalltalk': Smalltalk (id: ??, ns: 0),
#  'SmartPLS': SmartPLS (id: ??, ns: 0),
#  'Softmax function': Softmax function (id: ??, ns: 0),
#  'Software design': Software design (id: ??, ns: 0),
#  'Software developer': Software developer (id: ??, ns: 0),
#  'Software license': Software license (id: ??, ns: 0),
#  'Software patents and free software': Software patents and free software (id: ??, ns: 0),
#  'Software release life cycle': Software release life cycle (id: ??, ns: 0),
#  'Solaris (operating system)': Solaris (operating system) (id: ??, ns: 0),
#  'Sora (text-to-video model)': Sora (text-to-video model) (id: ??, ns: 0),
#  'Source-available software': Source-available software (id: ??, ns: 0),
#  'Spam (Monty Python)': Spam (Monty Python) (id: ??, ns: 0),
#  'Speakeasy (computational environment)': Speakeasy (computational environment) (id: ??, ns: 0),
#  'Speech recognition': Speech recognition (id: ??, ns: 0),
#  'Sphinx (documentation generator)': Sphinx (documentation generator) (id: ??, ns: 0),
#  'SpiNNaker': SpiNNaker (id: ??, ns: 0),
#  'Spotify': Spotify (id: ??, ns: 0),
#  'Spyder (software)': Spyder (software) (id: ??, ns: 0),
#  'Stable Diffusion': Stable Diffusion (id: ??, ns: 0),
#  'Stack Overflow': Stack Overflow (id: ??, ns: 0),
#  'Stackless Python': Stackless Python (id: ??, ns: 0),
#  'Stan (software)': Stan (software) (id: ??, ns: 0),
#  'Standard ML': Standard ML (id: ??, ns: 0),
#  'Standard library': Standard library (id: ??, ns: 0),
#  'StatView': StatView (id: ??, ns: 0),
#  'StatXact': StatXact (id: ??, ns: 0),
#  'Stata': Stata (id: ??, ns: 0),
#  'Statement (computer science)': Statement (computer science) (id: ??, ns: 0),
#  'State–action–reward–state–action': State–action–reward–state–action (id: ??, ns: 0),
#  'Statically-typed': Statically-typed (id: ??, ns: 0),
#  'Statistica': Statistica (id: ??, ns: 0),
#  'Statistical manifold': Statistical manifold (id: ??, ns: 0),
#  'StatsDirect': StatsDirect (id: ??, ns: 0),
#  'Stephen Grossberg': Stephen Grossberg (id: ??, ns: 0),
#  'Stochastic gradient descent': Stochastic gradient descent (id: ??, ns: 0),
#  'String (computer science)': String (computer science) (id: ??, ns: 0),
#  'String interpolation': String interpolation (id: ??, ns: 0),
#  'String literal': String literal (id: ??, ns: 0),
#  'Strong and weak typing': Strong and weak typing (id: ??, ns: 0),
#  'Struct': Struct (id: ??, ns: 0),
#  'Structured programming': Structured programming (id: ??, ns: 0),
#  'Stuart J. Russell': Stuart J. Russell (id: ??, ns: 0),
#  'Sugar (software)': Sugar (software) (id: ??, ns: 0),
#  'Sugar Labs': Sugar Labs (id: ??, ns: 0),
#  'Swift (programming language)': Swift (programming language) (id: ??, ns: 0),
#  'Symbian': Symbian (id: ??, ns: 0),
#  'Syntactic sugar': Syntactic sugar (id: ??, ns: 0),
#  'Syntax highlighting': Syntax highlighting (id: ??, ns: 0),
#  'System administration': System administration (id: ??, ns: 0),
#  'TACTIC (web framework)': TACTIC (web framework) (id: ??, ns: 0),
#  'TIOBE Programming Community Index': TIOBE Programming Community Index (id: ??, ns: 0),
#  'TSP (econometrics software)': TSP (econometrics software) (id: ??, ns: 0),
#  'Tail call': Tail call (id: ??, ns: 0),
#  'Tcl': Tcl (id: ??, ns: 0),
#  'TensorFlow': TensorFlow (id: ??, ns: 0),
#  'Tensor Processing Unit': Tensor Processing Unit (id: ??, ns: 0),
#  'Tensor calculus': Tensor calculus (id: ??, ns: 0),
#  'Test framework': Test framework (id: ??, ns: 0),
#  'Test suite': Test suite (id: ??, ns: 0),
#  'Text-to-image model': Text-to-image model (id: ??, ns: 0),
#  'Text-to-video model': Text-to-video model (id: ??, ns: 0),
#  'Text processing': Text processing (id: ??, ns: 0),
#  'The C Programming Language': The C Programming Language (id: ??, ns: 0),
#  'The Cathedral and the Bazaar': The Cathedral and the Bazaar (id: ??, ns: 0),
#  'The Computer Language Benchmarks Game': The Computer Language Benchmarks Game (id: ??, ns: 0),
#  'The Document Foundation': The Document Foundation (id: ??, ns: 0),
#  'The Free Software Definition': The Free Software Definition (id: ??, ns: 0),
#  'The Open Source Definition': The Open Source Definition (id: ??, ns: 0),
#  'The Unscrambler': The Unscrambler (id: ??, ns: 0),
#  'Theano (software)': Theano (software) (id: ??, ns: 0),
#  'There is more than one way to do it': There is more than one way to do it (id: ??, ns: 0),
#  'This (computer programming)': This (computer programming) (id: ??, ns: 0),
#  'Timeline of free and open-source software': Timeline of free and open-source software (id: ??, ns: 0),
#  'Timeline of programming languages': Timeline of programming languages (id: ??, ns: 0),
#  'Tkinter': Tkinter (id: ??, ns: 0),
#  'Tornado (web server)': Tornado (web server) (id: ??, ns: 0),
#  'Training, validation, and test sets': Training, validation, and test sets (id: ??, ns: 0),
#  'Transformer (machine learning model)': Transformer (machine learning model) (id: ??, ns: 0),
#  'Transpile': Transpile (id: ??, ns: 0),
#  'Transpiler': Transpiler (id: ??, ns: 0),
#  'Trusted Computing': Trusted Computing (id: ??, ns: 0),
#  'Tuple': Tuple (id: ??, ns: 0),
#  'TurboGears': TurboGears (id: ??, ns: 0),
#  'Twisted (software)': Twisted (software) (id: ??, ns: 0),
#  'Type system': Type system (id: ??, ns: 0),
#  'Ubiquity (software)': Ubiquity (software) (id: ??, ns: 0),
#  'Ubuntu (operating system)': Ubuntu (operating system) (id: ??, ns: 0),
#  'Unary operation': Unary operation (id: ??, ns: 0),
#  'Unicode': Unicode (id: ??, ns: 0),
#  'Unistat': Unistat (id: ??, ns: 0),
#  'Unit test': Unit test (id: ??, ns: 0),
#  'Unit testing': Unit testing (id: ??, ns: 0),
#  'Unix-like': Unix-like (id: ??, ns: 0),
#  'Unix shell': Unix shell (id: ??, ns: 0),
#  'Unladen Swallow': Unladen Swallow (id: ??, ns: 0),
#  'Unlicense': Unlicense (id: ??, ns: 0),
#  'VHDL': VHDL (id: ??, ns: 0),
#  'Variational autoencoder': Variational autoencoder (id: ??, ns: 0),
#  'Verilog': Verilog (id: ??, ns: 0),
#  'VideoPoet': VideoPoet (id: ??, ns: 0),
#  'Viral license': Viral license (id: ??, ns: 0),
#  'Virtual machine': Virtual machine (id: ??, ns: 0),
#  'VisSim': VisSim (id: ??, ns: 0),
#  'Vision processing unit': Vision processing unit (id: ??, ns: 0),
#  'Visual Basic (.NET)': Visual Basic (.NET) (id: ??, ns: 0),
#  'Visual Basic (classic)': Visual Basic (classic) (id: ??, ns: 0),
#  'WTFPL': WTFPL (id: ??, ns: 0),
#  'WaveNet': WaveNet (id: ??, ns: 0),
#  'Web2py': Web2py (id: ??, ns: 0),
#  'WebAssembly': WebAssembly (id: ??, ns: 0),
#  'Web Server Gateway Interface': Web Server Gateway Interface (id: ??, ns: 0),
#  'Web application': Web application (id: ??, ns: 0),
#  'Web browser': Web browser (id: ??, ns: 0),
#  'Web framework': Web framework (id: ??, ns: 0),
#  'Web scraping': Web scraping (id: ??, ns: 0),
#  'Weka (software)': Weka (software) (id: ??, ns: 0),
#  'While loop': While loop (id: ??, ns: 0),
#  'Whisper (speech recognition system)': Whisper (speech recognition system) (id: ??, ns: 0),
#  'Whitespace character': Whitespace character (id: ??, ns: 0),
#  'Wikipedia': Wikipedia (id: ??, ns: 0),
#  'WinBUGS': WinBUGS (id: ??, ns: 0),
#  'Windows': Windows (id: ??, ns: 0),
#  'Windows 7': Windows 7 (id: ??, ns: 0),
#  'Windows XP': Windows XP (id: ??, ns: 0),
#  'Wolfram Mathematica': Wolfram Mathematica (id: ??, ns: 0),
#  'Word2vec': Word2vec (id: ??, ns: 0),
#  'World Programming System': World Programming System (id: ??, ns: 0),
#  'X-12-ARIMA': X-12-ARIMA (id: ??, ns: 0),
#  'X10 (programming language)': X10 (programming language) (id: ??, ns: 0),
#  'XLfit': XLfit (id: ??, ns: 0),
#  'XLispStat': XLispStat (id: ??, ns: 0),
#  'XploRe': XploRe (id: ??, ns: 0),
#  'Yahoo!': Yahoo! (id: ??, ns: 0),
#  'Yann LeCun': Yann LeCun (id: ??, ns: 0),
#  'Yoshua Bengio': Yoshua Bengio (id: ??, ns: 0),
#  'Yukihiro Matsumoto': Yukihiro Matsumoto (id: ??, ns: 0),
#  'Zen of Python': Zen of Python (id: ??, ns: 0),
#  'Zero-based numbering': Zero-based numbering (id: ??, ns: 0),
#  'Zlib License': Zlib License (id: ??, ns: 0),
#  'Zope': Zope (id: ??, ns: 0),
#  'Wikipedia:Wikimedia sister projects': Wikipedia:Wikimedia sister projects (id: ??, ns: 4),
#  'Template:Differentiable computing': Template:Differentiable computing (id: ??, ns: 10),
#  'Template:FOSS': Template:FOSS (id: ??, ns: 10),
#  'Template:Latest preview software release/Python (programming language)': Template:Latest preview software release/Python (programming language) (id: ??, ns: 10),
#  'Template:Latest stable software release/Python (programming language)': Template:Latest stable software release/Python (programming language) (id: ??, ns: 10),
#  'Template:Numerical analysis software': Template:Numerical analysis software (id: ??, ns: 10),
#  'Template:Programming languages': Template:Programming languages (id: ??, ns: 10),
#  'Template:Python (programming language)': Template:Python (programming language) (id: ??, ns: 10),
#  'Template:Python web frameworks': Template:Python web frameworks (id: ??, ns: 10),
#  'Template:Statistical software': Template:Statistical software (id: ??, ns: 10),
#  'Template talk:Differentiable computing': Template talk:Differentiable computing (id: ??, ns: 11),
#  'Template talk:FOSS': Template talk:FOSS (id: ??, ns: 11),
#  'Template talk:Numerical analysis software': Template talk:Numerical analysis software (id: ??, ns: 11),
#  'Template talk:Programming languages': Template talk:Programming languages (id: ??, ns: 11),
#  'Template talk:Python (programming language)': Template talk:Python (programming language) (id: ??, ns: 11),
#  'Template talk:Python web frameworks': Template talk:Python web frameworks (id: ??, ns: 11),
#  'Template talk:Statistical software': Template talk:Statistical software (id: ??, ns: 11),
#  'Help:Authority control': Help:Authority control (id: ??, ns: 12),
#  'Category:Articles containing potentially dated statements from 2008': Category:Articles containing potentially dated statements from 2008 (id: ??, ns: 14),
#  'Category:Articles containing potentially dated statements from 2020': Category:Articles containing potentially dated statements from 2020 (id: ??, ns: 14),
#  'Category:Articles containing potentially dated statements from December 2022': Category:Articles containing potentially dated statements from December 2022 (id: ??, ns: 14),
#  'Category:Articles containing potentially dated statements from June 2023': Category:Articles containing potentially dated statements from June 2023 (id: ??, ns: 14),
#  'Category:Articles containing potentially dated statements from March 2024': Category:Articles containing potentially dated statements from March 2024 (id: ??, ns: 14),
#  'Category:Articles containing potentially dated statements from October 2023': Category:Articles containing potentially dated statements from October 2023 (id: ??, ns: 14),
#  'Category:Articles with BNF identifiers': Category:Articles with BNF identifiers (id: ??, ns: 14),
#  'Category:Articles with BNFdata identifiers': Category:Articles with BNFdata identifiers (id: ??, ns: 14),
#  'Category:Articles with FAST identifiers': Category:Articles with FAST identifiers (id: ??, ns: 14),
#  'Category:Articles with GND identifiers': Category:Articles with GND identifiers (id: ??, ns: 14),
#  'Category:Articles with J9U identifiers': Category:Articles with J9U identifiers (id: ??, ns: 14),
#  'Category:Articles with LCCN identifiers': Category:Articles with LCCN identifiers (id: ??, ns: 14),
#  'Category:Articles with NKC identifiers': Category:Articles with NKC identifiers (id: ??, ns: 14),
#  'Category:Articles with SUDOC identifiers': Category:Articles with SUDOC identifiers (id: ??, ns: 14),
#  'Category:Artificial neural networks': Category:Artificial neural networks (id: ??, ns: 14),
#  'Category:Free software': Category:Free software (id: ??, ns: 14),
#  'Category:Machine learning': Category:Machine learning (id: ??, ns: 14),
#  'Category:Programming languages': Category:Programming languages (id: ??, ns: 14),
#  'Category:Python (programming language) web frameworks': Category:Python (programming language) web frameworks (id: ??, ns: 14),
#  'Category:Statistical software': Category:Statistical software (id: ??, ns: 14),
#  'Category:Use dmy dates from November 2021': Category:Use dmy dates from November 2021 (id: ??, ns: 14),
#  'Portal:Computer programming': Portal:Computer programming (id: ??, ns: 100),
#  'Portal:Free and open-source software': Portal:Free and open-source software (id: ??, ns: 100),
#  'Portal:Technology': Portal:Technology (id: ??, ns: 100)}

# %%
links = list(page.links.keys())
links
# Out:
# ['"Hello, World!" program',
#  '3ds Max',
#  '?:',
#  'ABC (programming language)',
#  'ADMB',
#  'ALGOL',
#  'ALGOL 68',
#  'APL (programming language)',
#  'ATmega',
#  'AVR microcontrollers',
#  'Abaqus',
#  'Academic Free License',
#  'Academic conference',
#  'Action selection',
#  'Activation function',
#  'Ada (programming language)',
#  'Advanced Simulation Library',
#  'Adversarial machine learning',
#  'AlexNet',
#  'Alex Graves (computer scientist)',
#  'Alex Martelli',
#  'Algebra',
#  'AlphaFold',
#  'AlphaGo',
#  'AlphaZero',
#  'Alternative terms for free software',
#  'Amazon (company)',
#  'AmigaOS 4',
#  'Amoeba (operating system)',
#  'Anaconda (installer)',
#  'Analyse-it',
#  'Andrew Ng',
#  'Android (operating system)',
#  'Anonymous function',
#  'Anthropic',
#  'Apache Groovy',
#  'Apache License',
#  'Apache webserver',
#  'Aphorism',
#  'Apple M1',
#  'Apple Public Source License',
#  'ArXiv (identifier)',
#  'Arbitrary-precision arithmetic',
#  'ArcGIS',
#  'Arithmetic operations',
#  'ArkTS',
#  'Array index',
#  'Array slicing',
#  'Artificial intelligence',
#  'Artificial neural network',
#  'Artistic License',
#  'Aspect-oriented programming',
#  'Assembly language',
#  'Assertion (programming)',
#  'Assignment (computer science)',
#  'Associative array',
#  'Astropy',
#  'Asynchronous Server Gateway Interface',
#  'Attention (machine learning)',
#  'Auto-GPT',
#  'Autodesk Softimage',
#  'Autoencoder',
#  'Automatic differentiation',
#  'Automation',
#  'Autoregressive model',
#  'BASIC',
#  'BERT (language model)',
#  'BLOOM (language model)',
#  'BMDP',
#  'BSD licenses',
#  'BV4.1 (software)',
#  'Backporting',
#  'Backpropagation',
#  'Backward compatibility',
#  'Bard (chatbot)',
#  'Batch normalization',
#  'Bazel (software)',
#  'Beerware',
#  'Benevolent dictator for life',
#  'Berkeley Software Distribution',
#  'Beta release',
#  'Bibcode (identifier)',
#  'Biopython',
#  'Blender (software)',
#  'Block (programming)',
#  'Boo (programming language)',
#  'Boolean value',
#  'Break statement',
#  'Bug tracker',
#  'Byte',
#  'Bytecode',
#  'C++',
#  'C++11',
#  'C++17',
#  'C11 (C standard revision)',
#  'C89 (C version)',
#  'C99',
#  'CCP Games',
#  'CERN',
#  'CLPython',
#  'CLU (programming language)',
#  'COBOL',
#  'CPython',
#  'CSPro',
#  'C (programming language)',
#  'C Sharp (programming language)',
#  'Cache poisoning',
#  'Calculus',
#  'Call stack',
#  'Capella (notation program)',
#  'Centrum Wiskunde & Informatica',
#  'Chapel (programming language)',
#  'ChatGPT',
#  'CherryPy',
#  'Chinchilla AI',
#  'Chris Lattner',
#  'Cinema 4D',
#  'CircuitPython',
#  'CiteSeerX (identifier)',
#  'Class (computer science)',
#  'Cluster analysis',
#  'Cobra (programming language)',
#  'Code readability',
#  'CoffeeScript',
#  'Combinatorics',
#  'Command line interpreter',
#  'Commercial software',
#  'Common Development and Distribution License',
#  'Common Language Runtime',
#  'Common Lisp',
#  'Community of practice',
#  'Comparison of free and open-source software licenses',
#  'Comparison of free software for audio',
#  'Comparison of integrated development environments',
#  'Comparison of numerical-analysis software',
#  'Comparison of open-source and closed-source software',
#  'Comparison of open-source configuration management software',
#  'Comparison of open-source operating systems',
#  'Comparison of open-source wireless drivers',
#  'Comparison of programming languages',
#  'Comparison of shopping cart software',
#  'Comparison of source-code-hosting facilities',
#  'Comparison of statistical packages',
#  'Compile time',
#  'Compiler',
#  'Complex number',
#  'Computational learning theory',
#  'Computational science',
#  'Computer algebra system',
#  'Computer file',
#  'Computer networking',
#  'Computer vision',
#  'Concatenation',
#  'Conditional (programming)',
#  'Contributor License Agreement',
#  'Convolution',
#  'Convolutional neural network',
#  'Copyleft',
#  'Coroutine',
#  'Creative Commons license',
#  'Cross-platform software',
#  'CubicWeb',
#  'CumFreq',
#  'Curly bracket programming language',
#  'Cycle detection',
#  'Cython',
#  'DADiSP',
#  'DALL-E',
#  'DAP (software)',
#  'D (programming language)',
#  'Data Desk',
#  'Data analytics',
#  'Data augmentation',
#  'Data mapper pattern',
#  'Data type',
#  'Database',
#  'Dataplot',
#  'David Silver (computer scientist)',
#  'Debian Free Software Guidelines',
#  'Decimal floating point',
#  'Deep learning',
#  'Deep learning speech synthesis',
#  'Definite clause grammar',
#  'Definition of Free Cultural Works',
#  'Demis Hassabis',
#  'Denial-of-service attack',
#  'Design by contract',
#  'Device driver',
#  'Differentiable function',
#  'Differentiable neural computer',
#  'Differentiable programming',
#  'Diffusion process',
#  'Digital image processing',
#  'Digital rights management',
#  'Dispose pattern',
#  'Django (web framework)',
#  'Documentation',
#  'Doi (identifier)',
#  'Double-precision floating-point format',
#  'Doxygen',
#  'Dropbox (service)',
#  'Duck typing',
#  'Dylan (programming language)',
#  'Dynamic type',
#  'Dynamic typing',
#  'ECMAScript',
#  'EViews',
#  'Echo state network',
#  'Eclipse Public License',
#  'EleutherAI',
#  'Ellipsis (programming operator)',
#  'End-of-life product',
#  'Epi Info',
#  'Eric Python IDE',
#  'Erlang (programming language)',
#  'Escape character',
#  'Esri',
#  'Euler (software)',
#  'Exception handling',
#  'Exception handling (programming)',
#  'Exception handling syntax',
#  'Exponentiation',
#  'Expression (computer science)',
#  'Extensibility',
#  'FEATool Multiphysics',
#  'F Sharp (programming language)',
#  'Facebook',
#  'Facial recognition system',
#  'Factorial',
#  'FastAPI',
#  'Fedora Linux',
#  'Fei-Fei Li',
#  'Fellow',
#  'Filename extension',
#  'Finite element method',
#  'Firaxis Games',
#  'First-class continuations',
#  'Flask (web framework)',
#  'Floating-point arithmetic',
#  'Floor division',
#  'Flux (machine-learning framework)',
#  'Foobar',
#  'Foreach',
#  'Fork (software development)',
#  'Forth (programming language)',
#  'Fortran',
#  'Fortress (programming language)',
#  'Free-software license',
#  'FreeBSD',
#  'FreeCAD',
#  'FreeFem++',
#  'FreeMat',
#  'Free Software Foundation',
#  'Free Software Movement of India',
#  'Free and open-source graphics device driver',
#  'Free and open-source software',
#  'Free license',
#  'Free software',
#  'Free software movement',
#  'Freeware',
#  'Function (computing)',
#  'Function (programming)',
#  'Functional programming',
#  'GAUSS (software)',
#  'GDScript',
#  'GIMP',
#  'GNU Affero General Public License',
#  'GNU Debugger',
#  'GNU General Public License',
#  'GNU Lesser General Public License',
#  'GNU Manifesto',
#  'GNU Octave',
#  'GPT-1',
#  'GPT-2',
#  'GPT-3',
#  'GPT-4',
#  'GPT-J',
#  'GTK',
#  'Garbage collection (computer science)',
#  'Gated recurrent unit',
#  'Gemini (language model)',
#  'General-purpose programming language',
#  'Generational list of programming languages',
#  'Generative adversarial network',
#  'Generator (computer programming)',
#  'Generator (computer science)',
#  'Genie (programming language)',
#  'Genius (mathematics software)',
#  'Genstat',
#  'Gentoo Linux',
#  'Geoffrey Hinton',
#  'GitHub',
#  'Global interpreter lock',
#  'Gmsh',
#  'Go (programming language)',
#  'Godot (game engine)',
#  'Google',
#  'Google App Engine',
#  'Google DeepMind',
#  'Google JAX',
#  'Gradient descent',
#  'GraphPad InStat',
#  'GraphPad Prism',
#  'Graph neural network',
#  'Graphcore',
#  'Graphical user interface',
#  'Graphviz',
#  'Gratis versus libre',
#  'Gretl',
#  'Grok (web framework)',
#  'Groovy (programming language)',
#  'Guido van Rossum',
#  'Half-open interval',
#  'Hallucination (artificial intelligence)',
#  'Handwriting recognition',
#  'Hardware description language',
#  'Haskell',
#  'Here document',
#  'High-level programming language',
#  'History of Python',
#  'History of free and open-source software',
#  'History of programming languages',
#  'Houdini (software)',
#  'Huawei',
#  'Huawei PanGu',
#  'Hugging Face',
#  'Human image synthesis',
#  'Hypertext Transfer Protocol',
#  'IBM Granite',
#  'IBM Watson',
#  'IBM Watsonx',
#  'IDLE',
#  'IDLE (Python)',
#  'IEEE 754',
#  'IOS',
#  'IPython',
#  'ISBN (identifier)',
#  'ISC license',
#  'ISSN (identifier)',
#  'ITA Software',
#  'Ian Goodfellow',
#  'Icon (programming language)',
#  'If-then-else',
#  'Ilya Sutskever',
#  'Image processing',
#  'Immutable',
#  'Immutable object',
#  'Imperative programming',
#  'Include directive',
#  'Inductive bias',
#  'Industrial Light & Magic',
#  'Infix notation',
#  'InfoWorld',
#  'Information geometry',
#  'Information security',
#  'Inkscape',
#  'Instagram',
#  'Instance data',
#  'Integer (computer science)',
#  'Integrated development environment',
#  'IronPython',
#  'Iterator',
#  'JASP',
#  'JMP (statistical software)',
#  'JMulTi',
#  'JavaScript',
#  'Java (programming language)',
#  'Java (software platform)',
#  'Jeff Dean (computer scientist)',
#  'Julia (programming language)',
#  'Just-in-time compilation',
#  'Just-in-time compiler',
#  'Just another Gibbs sampler',
#  'Jython',
#  'Jürgen Schmidhuber',
#  'Keras',
#  'Kotlin (programming language)',
#  'LIMDEP',
#  'LISREL',
#  'LLVM',
#  'LLaMA',
#  'LaMDA',
#  'LabVIEW',
#  'Lambda (programming)',
#  'Language binding',
#  'Language model',
#  'Large language model',
#  'Late binding',
#  'Lazy evaluation',
#  'Lego Mindstorms EV3',
#  'LibreOffice',
#  'License proliferation',
#  'LightWave 3D',
#  'Linux',
#  'Linux distribution',
#  'Lisp (programming language)',
#  'List (computer science)',
#  'List comprehension',
#  'List comprehensions',
#  'List of Python software',
#  'List of commercial open-source applications and services',
#  'List of formerly free and open-source software',
#  'List of formerly proprietary software',
#  'List of free-software events',
#  'List of free and open-source Android applications',
#  'List of free and open-source iOS applications',
#  'List of free and open-source software organizations',
#  'List of free and open-source software packages',
#  'List of free and open-source web applications',
#  'List of free software project directories',
#  'List of free television software',
#  'List of integrated development environments for Python',
#  'List of numerical-analysis software',
#  'List of office suites',
#  'List of open-source bioinformatics software',
#  'List of open-source codecs',
#  'List of open-source health software',
#  'List of open-source routing platforms',
#  'List of open-source software for mathematics',
#  'List of open-source video games',
#  'List of programming languages',
#  'List of programming languages by type',
#  'List of statistical software',
#  'Lock (computer science)',
#  'Logic programming',
#  'Long-term support',
#  'Long short-term memory',
#  'Loss functions for classification',
#  'Lua (programming language)',
#  'MATLAB',
#  'MFEM',
#  'MIME',
#  'MIT Computer Science and Artificial Intelligence Laboratory',
#  'MIT License',
#  'ML (programming language)',
#  'MLwiN',
#  'MacOS',
#  'Machine learning',
#  'Mamba (deep learning)',
#  'Maple (software)',
#  'Mathcad',
#  'Mathematics',
#  'Matplotlib',
#  'Matrix multiplication',
#  'Maya (software)',
#  'MedCalc',
#  'Memory management',
#  'Memristor',
#  'Mercurial',
#  'Meta AI',
#  'Metaclass',
#  'Metaobject',
#  'Metaprogramming',
#  'Metasyntactic variable',
#  'Method (computing)',
#  'Method (programming)',
#  'MicroPython',
#  'Microcontroller',
#  'Microfit',
#  'Microsoft Excel',
#  'Microsoft Open Specification Promise',
#  'Microsoft Windows',
#  'Microthread',
#  'Midjourney',
#  'Mila (research institute)',
#  'MindSpore',
#  'Minitab',
#  'Mobile app',
#  'Mod wsgi',
#  'Modo (software)',
#  'Modula-3',
#  'Modular programming',
#  'Modulo operation',
#  'Mojo (programming language)',
#  'Monty Python',
#  'MotionBuilder',
#  'Mozilla Public License',
#  'Mozilla software rebranded by Debian',
#  'MuZero',
#  'Multi-paradigm programming language',
#  'Multilayer perceptron',
#  'Multimedia',
#  'Multithreading (computer architecture)',
#  'Musical notation',
#  'MyHDL',
#  'N900',
#  'NASA',
#  'NCSS (statistical software)',
#  'NOP (code)',
#  'Name resolution (programming languages)',
#  'Natural language processing',
#  'Neologism',
#  'NetBSD',
#  'Netherlands',
#  'Neural Turing machine',
#  'Neural machine translation',
#  'Neuromorphic engineering',
#  'Nevow',
#  'Nim (programming language)',
#  'Ninja-IDE',
#  'Nokia',
#  'Non-English-based programming languages',
#  'Norman Jouppi',
#  'Notebook interface',
#  'Nuitka',
#  'Nuke (software)',
#  'Null pointer',
#  'NumPy',
#  'Numba',
#  'Number theory',
#  'Numerical mathematics',
#  "O'Reilly Media",
#  "O'Reilly Open Source Convention",
#  'OS/2',
#  'Object-oriented programming',
#  'Object (computer science)',
#  'Object Pascal',
#  'Objective-C',
#  'Off-side rule',
#  'One Laptop per Child',
#  'Open-core model',
#  'Open-source-software movement',
#  'Open-source hardware',
#  'Open-source license',
#  'Open-source software',
#  'Open-source software advocacy',
#  'Open-source software development',
#  'Open-source software security',
#  'OpenAI',
#  'OpenAI Five',
#  'OpenBSD',
#  'OpenBUGS',
#  'OpenCV',
#  'OpenFOAM',
#  'OpenVMS',
#  'Operating system',
#  'Operator overloading',
#  'Optical character recognition',
#  'Optional typing',
#  'Orange (software)',
#  'Order of operations',
#  'Outline of free software',
#  'Overfitting',
#  'OxMetrics',
#  'PHP',
#  'PSPP',
#  'PaLM',
#  'Package management system',
#  'Paint Shop Pro',
#  'Pascal (programming language)',
#  'Pattern matching',
#  'Pattern recognition',
#  'Pdoc',
#  'Perl',
#  'Permissive software license',
#  'Peter Norvig',
#  'Pip (package manager)',
#  'Pointer (computer programming)',
#  'Portage (software)',
#  'Ported',
#  'Premature optimization',
#  'Prettyprint',
#  'Printf format string',
#  'ProbLog',
#  'Procedural programming',
#  'Programming idiom',
#  'Programming language',
#  'Programming language implementation',
#  'Programming paradigm',
#  'Project Debater',
#  'Project Jupyter',
#  'Prolog',
#  'Prompt engineering',
#  'Proprietary device driver',
#  'Proprietary firmware',
#  'Proprietary software',
#  'Pseudorandom number generator',
#  'Psyco',
#  'Public-domain software',
#  'Public domain',
#  'PyCharm',
#  'PyCon',
#  'PyDev',
#  'PyGTK',
#  'PyLadies',
#  'PyMC3',
#  'PyPy',
#  'PyQt',
#  'PyS60',
#  'PyTorch',
#  'Pydoc',
#  'Pygame',
#  'Pyjs',
#  'Pylons (web framework)',
#  'Pylons project',
#  'Pyramid (web framework)',
#  'Pyrex (programming language)',
#  'PythonAnywhere',
#  'Python Conference',
#  'Python License',
#  'Python Package Index',
#  'Python Software Foundation',
#  'Python Software Foundation License',
#  'Python for S60',
#  'Python syntax and semantics',
#  'Q-learning',
#  'Qt (software)',
#  'Quixote (web framework)',
#  'RATS (software)',
#  'RExcel',
#  'RPython',
#  'RStudio',
#  'R (programming language)',
#  'Raspberry Pi',
#  'Raspberry Pi OS',
#  'Rational number',
#  'Raw string',
#  'Read–eval–print loop',
#  'Rectifier (neural networks)',
#  'Recurrent neural network',
#  'Red Hat Linux',
#  'Reddit',
#  'Reference counting',
#  'Reference implementation',
#  'Reflective programming',
#  'Regression analysis',
#  'Regular expression',
#  'Regularization (mathematics)',
#  'Relational database',
#  'Remote code execution',
#  'Residual neural network',
#  'Resource acquisition is initialization',
#  'Revolution Analytics',
#  'Revolution OS',
#  'Ring-lang',
#  'Ring (programming language)',
#  'Robot control',
#  'Round to even',
#  'Rounding',
#  'Roundup (issue tracker)',
#  'Ruby (programming language)',
#  'Run-time algorithm specialization',
#  'Rust (programming language)',
#  'S-PLUS',
#  'S2CID (identifier)',
#  'SAS (software)',
#  'SCO–Linux disputes',
#  'SETL',
#  'SHAZAM (software)',
#  'SOFA Statistics',
#  'SPSS',
#  'SPSS Modeler',
#  'SQL',
#  'SQLAlchemy',
#  'SUDAAN',
#  'SYSTAT (statistics package)',
#  'SageMath',
#  'Salome (software)',
#  'Scheme (programming language)',
#  'SciPy',
#  'ScicosLab',
#  'Scientific computing',
#  'Scikit-learn',
#  'Scilab',
#  'Scorewriter',
#  'Scratch (programming language)',
#  'Scribus',
#  'Scripting language',
#  'SegReg',
#  'Self-driving car',
#  'Self-hosting (web services)',
#  'Seq2seq',
#  'Series 60',
#  'Set (computer science)',
#  'Shallow copy',
#  'Shared Source Initiative',
#  'Shed Skin',
#  'Shell script',
#  'SigmaStat',
#  'Sigmoid function',
#  'SimFiT',
#  'Simple DirectMedia Layer',
#  'Simula',
#  'Single-board computer',
#  'Single-precision',
#  'Sleepycat License',
#  'Smalltalk',
#  'SmartPLS',
#  'Softmax function',
#  'Software design',
#  'Software developer',
#  'Software license',
#  'Software patents and free software',
#  'Software release life cycle',
#  'Solaris (operating system)',
#  'Sora (text-to-video model)',
#  'Source-available software',
#  'Spam (Monty Python)',
#  'Speakeasy (computational environment)',
#  'Speech recognition',
#  'Sphinx (documentation generator)',
#  'SpiNNaker',
#  'Spotify',
#  'Spyder (software)',
#  'Stable Diffusion',
#  'Stack Overflow',
#  'Stackless Python',
#  'Stan (software)',
#  'Standard ML',
#  'Standard library',
#  'StatView',
#  'StatXact',
#  'Stata',
#  'Statement (computer science)',
#  'State–action–reward–state–action',
#  'Statically-typed',
#  'Statistica',
#  'Statistical manifold',
#  'StatsDirect',
#  'Stephen Grossberg',
#  'Stochastic gradient descent',
#  'String (computer science)',
#  'String interpolation',
#  'String literal',
#  'Strong and weak typing',
#  'Struct',
#  'Structured programming',
#  'Stuart J. Russell',
#  'Sugar (software)',
#  'Sugar Labs',
#  'Swift (programming language)',
#  'Symbian',
#  'Syntactic sugar',
#  'Syntax highlighting',
#  'System administration',
#  'TACTIC (web framework)',
#  'TIOBE Programming Community Index',
#  'TSP (econometrics software)',
#  'Tail call',
#  'Tcl',
#  'TensorFlow',
#  'Tensor Processing Unit',
#  'Tensor calculus',
#  'Test framework',
#  'Test suite',
#  'Text-to-image model',
#  'Text-to-video model',
#  'Text processing',
#  'The C Programming Language',
#  'The Cathedral and the Bazaar',
#  'The Computer Language Benchmarks Game',
#  'The Document Foundation',
#  'The Free Software Definition',
#  'The Open Source Definition',
#  'The Unscrambler',
#  'Theano (software)',
#  'There is more than one way to do it',
#  'This (computer programming)',
#  'Timeline of free and open-source software',
#  'Timeline of programming languages',
#  'Tkinter',
#  'Tornado (web server)',
#  'Training, validation, and test sets',
#  'Transformer (machine learning model)',
#  'Transpile',
#  'Transpiler',
#  'Trusted Computing',
#  'Tuple',
#  'TurboGears',
#  'Twisted (software)',
#  'Type system',
#  'Ubiquity (software)',
#  'Ubuntu (operating system)',
#  'Unary operation',
#  'Unicode',
#  'Unistat',
#  'Unit test',
#  'Unit testing',
#  'Unix-like',
#  'Unix shell',
#  'Unladen Swallow',
#  'Unlicense',
#  'VHDL',
#  'Variational autoencoder',
#  'Verilog',
#  'VideoPoet',
#  'Viral license',
#  'Virtual machine',
#  'VisSim',
#  'Vision processing unit',
#  'Visual Basic (.NET)',
#  'Visual Basic (classic)',
#  'WTFPL',
#  'WaveNet',
#  'Web2py',
#  'WebAssembly',
#  'Web Server Gateway Interface',
#  'Web application',
#  'Web browser',
#  'Web framework',
#  'Web scraping',
#  'Weka (software)',
#  'While loop',
#  'Whisper (speech recognition system)',
#  'Whitespace character',
#  'Wikipedia',
#  'WinBUGS',
#  'Windows',
#  'Windows 7',
#  'Windows XP',
#  'Wolfram Mathematica',
#  'Word2vec',
#  'World Programming System',
#  'X-12-ARIMA',
#  'X10 (programming language)',
#  'XLfit',
#  'XLispStat',
#  'XploRe',
#  'Yahoo!',
#  'Yann LeCun',
#  'Yoshua Bengio',
#  'Yukihiro Matsumoto',
#  'Zen of Python',
#  'Zero-based numbering',
#  'Zlib License',
#  'Zope',
#  'Wikipedia:Wikimedia sister projects',
#  'Template:Differentiable computing',
#  'Template:FOSS',
#  'Template:Latest preview software release/Python (programming language)',
#  'Template:Latest stable software release/Python (programming language)',
#  'Template:Numerical analysis software',
#  'Template:Programming languages',
#  'Template:Python (programming language)',
#  'Template:Python web frameworks',
#  'Template:Statistical software',
#  'Template talk:Differentiable computing',
#  'Template talk:FOSS',
#  'Template talk:Numerical analysis software',
#  'Template talk:Programming languages',
#  'Template talk:Python (programming language)',
#  'Template talk:Python web frameworks',
#  'Template talk:Statistical software',
#  'Help:Authority control',
#  'Category:Articles containing potentially dated statements from 2008',
#  'Category:Articles containing potentially dated statements from 2020',
#  'Category:Articles containing potentially dated statements from December 2022',
#  'Category:Articles containing potentially dated statements from June 2023',
#  'Category:Articles containing potentially dated statements from March 2024',
#  'Category:Articles containing potentially dated statements from October 2023',
#  'Category:Articles with BNF identifiers',
#  'Category:Articles with BNFdata identifiers',
#  'Category:Articles with FAST identifiers',
#  'Category:Articles with GND identifiers',
#  'Category:Articles with J9U identifiers',
#  'Category:Articles with LCCN identifiers',
#  'Category:Articles with NKC identifiers',
#  'Category:Articles with SUDOC identifiers',
#  'Category:Artificial neural networks',
#  'Category:Free software',
#  'Category:Machine learning',
#  'Category:Programming languages',
#  'Category:Python (programming language) web frameworks',
#  'Category:Statistical software',
#  'Category:Use dmy dates from November 2021',
#  'Portal:Computer programming',
#  'Portal:Free and open-source software',
#  'Portal:Technology']

# %%
# ?page
# Out:
# Type:        WikipediaPage
# String form: Run-D.M.C. (album) (id: 2431325, ns: 0)
# File:        ~/.local/lib/python3.11/site-packages/wikipediaapi/__init__.py
# Docstring:
# Represents Wikipedia page.
#
# Except properties mentioned as part of documentation, there are also
# these properties available:
#
# * `fullurl` - full URL of the page
# * `canonicalurl` - canonical URL of the page
# * `pageid` - id of the current page
# * `displaytitle` - title of the page to display
# * `talkid` - id of the page with discussion

# %%
page
# Out:
# Run-D.M.C. (album) (id: 2431325, ns: 0)

# %%
page.summary
# Out:
# 'Run-D.M.C. is the debut studio album by American hip hop group Run-D.M.C., released on March 27, 1984, by Profile Records, and re-issued by Arista Records. The album was primarily produced by Russell Simmons and Larry Smith.\nThe album was considered groundbreaking for its time, presenting a tougher, more hardcore form of rap. The album\'s sparse beats and aggressive rhymes were in sharp contrast with the light, party-oriented sound that was popular in contemporary hip hop. With the album, Run-D.M.C. came to be regarded by music critics as pioneering the movement of new-school hip hop of the mid-1980s. Five singles were released in support of it: "It\'s Like That", "Hard Times", "Rock Box", "30 Days" and "Hollis Crew". The first single from the album, "It\'s Like That", released on August 10, 1983, expanded lyrical boundaries in rap with its tone of social protest (unemployment, inflation). "It\'s Like That" is considered by many to be the first hardcore rap song, and the first new-school hip hop recording. "Sucker M.C.\'s" is one of the first diss tracks, and "Rock Box" is the first song in the rap rock genre.\nRun-D.M.C. peaked at number 53 on the Billboard 200 chart and number 14 on the Top R&B/Hip Hop Albums chart. The album became the first rap album to achieve a Gold certification from the Recording Industry Association of America (RIAA) (December 17, 1984). It was released to critical acclaim, and continues to be highly regarded as a seminal hip hop album. In 1989, it was ranked number 51 on Rolling Stone\'s list of the "100 Greatest Albums of the 1980s". In 2003, the album was ranked number 240 on the same magazine\'s list of the "500 Greatest Albums of All Time", with the ranking changing to numbers 242 and 378 in the 2012 and 2020 updates of the list, respectively. The album was reissued by Arista Records in 1999 and 2003. An expanded and remastered edition was released in 2005 and contained 4 previously unreleased songs.'

# %%
# ?wiki_wiki.page
# Out:
# Signature:
# wiki_wiki.page(
#     title: str,
#     ns: Union[wikipediaapi.Namespace, int] = <Namespace.MAIN: 0>,
#     unquote: bool = False,
# ) -> 'WikipediaPage'
# Docstring:
# Constructs Wikipedia page with title `title`.
#
# Creating `WikipediaPage` object is always the first step for extracting
# any information.
#
# Example::
#
#     wiki_wiki = wikipediaapi.Wikipedia('en')
#     page_py = wiki_wiki.page('Python_(programming_language)')
#     print(page_py.title)
#     # Python (programming language)
#
#     wiki_hi = wikipediaapi.Wikipedia('hi')
#
#     page_hi_py = wiki_hi.article(
#         title='%E0%A4%AA%E0%A4%BE%E0%A4%87%E0%A4%A5%E0%A4%A8',
#         unquote=True,
#     )
#     print(page_hi_py.title)
#     # पाइथन
#
# :param title: page title as used in Wikipedia URL
# :param ns: :class:`WikiNamespace`
# :param unquote: if true it will unquote title
# :return: object representing :class:`WikipediaPage`
# File:      ~/.local/lib/python3.11/site-packages/wikipediaapi/__init__.py
# Type:      method

# %%
source = get_random_wiki_page(wiki_wiki)
target = get_random_wiki_page(wiki_wiki)
print(f'source={source}')
print(f'target={target}')
# Out:
# source=Run-D.M.C._(album)
# target=Marculescu

# %%
page = wiki_wiki.page(source)

# %%
page.fullurl
# Out:
# 'https://en.wikipedia.org/wiki/Run-D.M.C._(album)'

# %%
page.canonicalurl
# Out:
# 'https://en.wikipedia.org/wiki/Run-D.M.C._(album)'

# %%
page.links
# Out:
# {'AMC (TV channel)': AMC (TV channel) (id: ??, ns: 0),
#  'Adobe Flash': Adobe Flash (id: ??, ns: 0),
#  'African American culture': African American culture (id: ??, ns: 0),
#  'Album': Album (id: ??, ns: 0),
#  'AllMusic': AllMusic (id: ??, ns: 0),
#  'Arista Records': Arista Records (id: ??, ns: 0),
#  'Back from Hell': Back from Hell (id: ??, ns: 0),
#  'Beats Per Minute (website)': Beats Per Minute (website) (id: ??, ns: 0),
#  'Billboard (magazine)': Billboard (magazine) (id: ??, ns: 0),
#  'Billboard 200': Billboard 200 (id: ??, ns: 0),
#  'Can You Rock It Like This': Can You Rock It Like This (id: ??, ns: 0),
#  'Checks Thugs and Rock n Roll': Checks Thugs and Rock n Roll (id: ??, ns: 0),
#  'Chicago Tribune': Chicago Tribune (id: ??, ns: 0),
#  'Christian Hoard': Christian Hoard (id: ??, ns: 0),
#  'Christmas in Hollis': Christmas in Hollis (id: ??, ns: 0),
#  'Complex (magazine)': Complex (magazine) (id: ??, ns: 0),
#  'Crown Royal (album)': Crown Royal (album) (id: ??, ns: 0),
#  'Danceteria': Danceteria (id: ??, ns: 0),
#  'Darryl McDaniels': Darryl McDaniels (id: ??, ns: 0),
#  'David Toop': David Toop (id: ??, ns: 0),
#  'Def Jam Recordings': Def Jam Recordings (id: ??, ns: 0),
#  'Diggy Simmons': Diggy Simmons (id: ??, ns: 0),
#  'Disco': Disco (id: ??, ns: 0),
#  'Disco Fever': Disco Fever (id: ??, ns: 0),
#  'Discogs': Discogs (id: ??, ns: 0),
#  'Diss (music)': Diss (music) (id: ??, ns: 0),
#  'Distortion (Joseph Simmons album)': Distortion (Joseph Simmons album) (id: ??, ns: 0),
#  'Down with the King (album)': Down with the King (album) (id: ??, ns: 0),
#  'Down with the King (song)': Down with the King (song) (id: ??, ns: 0),
#  'Drum machine': Drum machine (id: ??, ns: 0),
#  'East Coast hip hop': East Coast hip hop (id: ??, ns: 0),
#  'Eddie Martinez (musician)': Eddie Martinez (musician) (id: ??, ns: 0),
#  'Eric Weisbard': Eric Weisbard (id: ??, ns: 0),
#  'Faces (Run-D.M.C. song)': Faces (Run-D.M.C. song) (id: ??, ns: 0),
#  'Gold certification': Gold certification (id: ??, ns: 0),
#  'Graffiti Rock': Graffiti Rock (id: ??, ns: 0),
#  'Grandmaster Flash and the Furious Five': Grandmaster Flash and the Furious Five (id: ??, ns: 0),
#  'Greatest Hits (Run-D.M.C. album)': Greatest Hits (Run-D.M.C. album) (id: ??, ns: 0),
#  'Greene St. Recording': Greene St. Recording (id: ??, ns: 0),
#  'Greg Kot': Greg Kot (id: ??, ns: 0),
#  'Greg Tate': Greg Tate (id: ??, ns: 0),
#  'Hard Times (Run-D.M.C. song)': Hard Times (Run-D.M.C. song) (id: ??, ns: 0),
#  'Hardcore hip hop': Hardcore hip hop (id: ??, ns: 0),
#  'Hardcore rap': Hardcore rap (id: ??, ns: 0),
#  'High Profile: The Original Rhymes': High Profile: The Original Rhymes (id: ??, ns: 0),
#  'Hip Hop Connection': Hip Hop Connection (id: ??, ns: 0),
#  'Hip hop music': Hip hop music (id: ??, ns: 0),
#  "I'm Not Going Out Like That": I'm Not Going Out Like That (id: ??, ns: 0),
#  'ISBN (identifier)': ISBN (identifier) (id: ??, ns: 0),
#  'Ice-T': Ice-T (id: ??, ns: 0),
#  "It's Like That (Run-D.M.C. song)": It's Like That (Run-D.M.C. song) (id: ??, ns: 0),
#  "It's Tricky": It's Tricky (id: ??, ns: 0),
#  'Jam Master Jay': Jam Master Jay (id: ??, ns: 0),
#  'Jason Mizell': Jason Mizell (id: ??, ns: 0),
#  'Joseph Simmons': Joseph Simmons (id: ??, ns: 0),
#  'King of Rock': King of Rock (id: ??, ns: 0),
#  'King of Rock (song)': King of Rock (song) (id: ??, ns: 0),
#  'Krush Groove': Krush Groove (id: ??, ns: 0),
#  'Larry Smith (producer)': Larry Smith (producer) (id: ??, ns: 0),
#  'List of music recording certifications': List of music recording certifications (id: ??, ns: 0),
#  'Live at Montreux 2001': Live at Montreux 2001 (id: ??, ns: 0),
#  'Lovebug Starski': Lovebug Starski (id: ??, ns: 0),
#  'MTV': MTV (id: ??, ns: 0),
#  'Mary, Mary (song)': Mary, Mary (song) (id: ??, ns: 0),
#  'Melle Mel': Melle Mel (id: ??, ns: 0),
#  'Mizell Brothers': Mizell Brothers (id: ??, ns: 0),
#  'Music genre': Music genre (id: ??, ns: 0),
#  'Muze': Muze (id: ??, ns: 0),
#  'My Adidas': My Adidas (id: ??, ns: 0),
#  'Myspace': Myspace (id: ??, ns: 0),
#  'NME': NME (id: ??, ns: 0),
#  'Nathan Brackett': Nathan Brackett (id: ??, ns: 0),
#  'New-school hip hop': New-school hip hop (id: ??, ns: 0),
#  'New school hip hop': New school hip hop (id: ??, ns: 0),
#  'Oberheim DMX': Oberheim DMX (id: ??, ns: 0),
#  'Old-school hip hop': Old-school hip hop (id: ??, ns: 0),
#  'Ooh, Whatcha Gonna Do': Ooh, Whatcha Gonna Do (id: ??, ns: 0),
#  'Pause (Run-D.M.C. song)': Pause (Run-D.M.C. song) (id: ??, ns: 0),
#  'Peter Shapiro (journalist)': Peter Shapiro (journalist) (id: ??, ns: 0),
#  'Pitchfork (website)': Pitchfork (website) (id: ??, ns: 0),
#  'Profile Records': Profile Records (id: ??, ns: 0),
#  'Raising Hell (album)': Raising Hell (album) (id: ??, ns: 0),
#  'RapGenius': RapGenius (id: ??, ns: 0),
#  'Rap rock': Rap rock (id: ??, ns: 0),
#  'Record Collector': Record Collector (id: ??, ns: 0),
#  'Record label': Record label (id: ??, ns: 0),
#  'Record producer': Record producer (id: ??, ns: 0),
#  'Recording Industry Association of America': Recording Industry Association of America (id: ??, ns: 0),
#  'Riff': Riff (id: ??, ns: 0),
#  'Robert Christgau': Robert Christgau (id: ??, ns: 0),
#  'Rock Box': Rock Box (id: ??, ns: 0),
#  'Rock music': Rock music (id: ??, ns: 0),
#  'Rolling Stone': Rolling Stone (id: ??, ns: 0),
#  "Rolling Stone's 500 Greatest Albums of All Time": Rolling Stone's 500 Greatest Albums of All Time (id: ??, ns: 0),
#  "Run's House": Run's House (id: ??, ns: 0),
#  "Run's House (song)": Run's House (song) (id: ??, ns: 0),
#  'Run-D.M.C.': Run-D.M.C. (id: ??, ns: 0),
#  'Run-DMC': Run-DMC (id: ??, ns: 0),
#  'Run-DMC discography': Run-DMC discography (id: ??, ns: 0),
#  'Russell Simmons': Russell Simmons (id: ??, ns: 0),
#  'Russell Simmons Music Group': Russell Simmons Music Group (id: ??, ns: 0),
#  'Scratching': Scratching (id: ??, ns: 0),
#  'Sequence (group)': Sequence (group) (id: ??, ns: 0),
#  "Serpent's Tail": Serpent's Tail (id: ??, ns: 0),
#  'Simon & Schuster': Simon & Schuster (id: ??, ns: 0),
#  'Single (music)': Single (music) (id: ??, ns: 0),
#  'Snare drum': Snare drum (id: ??, ns: 0),
#  'Spin (magazine)': Spin (magazine) (id: ??, ns: 0),
#  'Spin Alternative Record Guide': Spin Alternative Record Guide (id: ??, ns: 0),
#  'Stephen Thomas Erlewine': Stephen Thomas Erlewine (id: ??, ns: 0),
#  'Street style': Street style (id: ??, ns: 0),
#  'Studio album': Studio album (id: ??, ns: 0),
#  "Sucker M.C.'s": Sucker M.C.'s (id: ??, ns: 0),
#  'The Best of Run-DMC': The Best of Run-DMC (id: ??, ns: 0),
#  'The Essential Run-D.M.C.': The Essential Run-D.M.C. (id: ??, ns: 0),
#  'The Observer': The Observer (id: ??, ns: 0),
#  'The Rolling Stone Album Guide': The Rolling Stone Album Guide (id: ??, ns: 0),
#  'The Source': The Source (id: ??, ns: 0),
#  'The Source (magazine)': The Source (magazine) (id: ??, ns: 0),
#  'The Village Voice': The Village Voice (id: ??, ns: 0),
#  'Together Forever: Greatest Hits 1983–1991': Together Forever: Greatest Hits 1983–1991 (id: ??, ns: 0),
#  'Top R&B/Hip-Hop Albums': Top R&B/Hip-Hop Albums (id: ??, ns: 0),
#  'Top R&B/Hip Hop Albums': Top R&B/Hip Hop Albums (id: ??, ns: 0),
#  'Tougher Than Leather': Tougher Than Leather (id: ??, ns: 0),
#  'Ultimate Run-D.M.C.': Ultimate Run-D.M.C. (id: ??, ns: 0),
#  'Uncut (magazine)': Uncut (magazine) (id: ??, ns: 0),
#  'Vintage Books': Vintage Books (id: ??, ns: 0),
#  'Walk This Way': Walk This Way (id: ??, ns: 0),
#  'Walk This Way (Run-D.M.C. song)': Walk This Way (Run-D.M.C. song) (id: ??, ns: 0),
#  'Warner Bros.': Warner Bros. (id: ??, ns: 0),
#  "What's It All About (song)": What's It All About (song) (id: ??, ns: 0),
#  'William Waring': William Waring (id: ??, ns: 0),
#  'XXL (magazine)': XXL (magazine) (id: ??, ns: 0),
#  "You Be Illin'": You Be Illin' (id: ??, ns: 0),
#  'You Talk Too Much (Run-DMC song)': You Talk Too Much (Run-DMC song) (id: ??, ns: 0),
#  'Template:Run-DMC': Template:Run-DMC (id: ??, ns: 10),
#  'Template talk:Run-DMC': Template talk:Run-DMC (id: ??, ns: 11),
#  'Help:Authority control': Help:Authority control (id: ??, ns: 12),
#  'Category:Articles with MusicBrainz release group identifiers': Category:Articles with MusicBrainz release group identifiers (id: ??, ns: 14),
#  'Category:Use mdy dates from April 2021': Category:Use mdy dates from April 2021 (id: ??, ns: 14)}

# %%
validate_pages(page)
# Out:
# ['AMC (TV channel)',
#  'Adobe Flash',
#  'African American culture',
#  'Album',
#  'AllMusic',
#  'Arista Records',
#  'Back from Hell',
#  'Beats Per Minute (website)',
#  'Billboard (magazine)',
#  'Billboard 200',
#  'Can You Rock It Like This',
#  'Checks Thugs and Rock n Roll',
#  'Chicago Tribune',
#  'Christian Hoard',
#  'Christmas in Hollis',
#  'Complex (magazine)',
#  'Crown Royal (album)',
#  'Danceteria',
#  'Darryl McDaniels',
#  'David Toop',
#  'Def Jam Recordings',
#  'Diggy Simmons',
#  'Disco',
#  'Disco Fever',
#  'Discogs',
#  'Diss (music)',
#  'Distortion (Joseph Simmons album)',
#  'Down with the King (album)',
#  'Down with the King (song)',
#  'Drum machine',
#  'East Coast hip hop',
#  'Eddie Martinez (musician)',
#  'Eric Weisbard',
#  'Faces (Run-D.M.C. song)',
#  'Gold certification',
#  'Graffiti Rock',
#  'Grandmaster Flash and the Furious Five',
#  'Greatest Hits (Run-D.M.C. album)',
#  'Greene St. Recording',
#  'Greg Kot',
#  'Greg Tate',
#  'Hard Times (Run-D.M.C. song)',
#  'Hardcore hip hop',
#  'Hardcore rap',
#  'High Profile: The Original Rhymes',
#  'Hip Hop Connection',
#  'Hip hop music',
#  "I'm Not Going Out Like That",
#  'ISBN (identifier)',
#  'Ice-T',
#  "It's Like That (Run-D.M.C. song)",
#  "It's Tricky",
#  'Jam Master Jay',
#  'Jason Mizell',
#  'Joseph Simmons',
#  'King of Rock',
#  'King of Rock (song)',
#  'Krush Groove',
#  'Larry Smith (producer)',
#  'Live at Montreux 2001',
#  'Lovebug Starski',
#  'MTV',
#  'Mary, Mary (song)',
#  'Melle Mel',
#  'Mizell Brothers',
#  'Music genre',
#  'Muze',
#  'My Adidas',
#  'Myspace',
#  'NME',
#  'Nathan Brackett',
#  'New-school hip hop',
#  'New school hip hop',
#  'Oberheim DMX',
#  'Old-school hip hop',
#  'Ooh, Whatcha Gonna Do',
#  'Pause (Run-D.M.C. song)',
#  'Peter Shapiro (journalist)',
#  'Pitchfork (website)',
#  'Profile Records',
#  'Raising Hell (album)',
#  'RapGenius',
#  'Rap rock',
#  'Record Collector',
#  'Record label',
#  'Record producer',
#  'Recording Industry Association of America',
#  'Riff',
#  'Robert Christgau',
#  'Rock Box',
#  'Rock music',
#  'Rolling Stone',
#  "Rolling Stone's 500 Greatest Albums of All Time",
#  "Run's House",
#  "Run's House (song)",
#  'Run-D.M.C.',
#  'Run-DMC',
#  'Run-DMC discography',
#  'Russell Simmons',
#  'Russell Simmons Music Group',
#  'Scratching',
#  'Sequence (group)',
#  "Serpent's Tail",
#  'Simon & Schuster',
#  'Single (music)',
#  'Snare drum',
#  'Spin (magazine)',
#  'Spin Alternative Record Guide',
#  'Stephen Thomas Erlewine',
#  'Street style',
#  'Studio album',
#  "Sucker M.C.'s",
#  'The Best of Run-DMC',
#  'The Essential Run-D.M.C.',
#  'The Observer',
#  'The Rolling Stone Album Guide',
#  'The Source',
#  'The Source (magazine)',
#  'The Village Voice',
#  'Together Forever: Greatest Hits 1983–1991',
#  'Top R&B/Hip-Hop Albums',
#  'Top R&B/Hip Hop Albums',
#  'Tougher Than Leather',
#  'Ultimate Run-D.M.C.',
#  'Uncut (magazine)',
#  'Vintage Books',
#  'Walk This Way',
#  'Walk This Way (Run-D.M.C. song)',
#  'Warner Bros.',
#  "What's It All About (song)",
#  'William Waring',
#  'XXL (magazine)',
#  "You Be Illin'",
#  'You Talk Too Much (Run-DMC song)',
#  'Help:Authority control']

# %%
page.links
# Out:
# {'AMC (TV channel)': AMC (TV channel) (id: ??, ns: 0),
#  'Adobe Flash': Adobe Flash (id: ??, ns: 0),
#  'African American culture': African American culture (id: ??, ns: 0),
#  'Album': Album (id: ??, ns: 0),
#  'AllMusic': AllMusic (id: ??, ns: 0),
#  'Arista Records': Arista Records (id: ??, ns: 0),
#  'Back from Hell': Back from Hell (id: ??, ns: 0),
#  'Beats Per Minute (website)': Beats Per Minute (website) (id: ??, ns: 0),
#  'Billboard (magazine)': Billboard (magazine) (id: ??, ns: 0),
#  'Billboard 200': Billboard 200 (id: ??, ns: 0),
#  'Can You Rock It Like This': Can You Rock It Like This (id: ??, ns: 0),
#  'Checks Thugs and Rock n Roll': Checks Thugs and Rock n Roll (id: ??, ns: 0),
#  'Chicago Tribune': Chicago Tribune (id: ??, ns: 0),
#  'Christian Hoard': Christian Hoard (id: ??, ns: 0),
#  'Christmas in Hollis': Christmas in Hollis (id: ??, ns: 0),
#  'Complex (magazine)': Complex (magazine) (id: ??, ns: 0),
#  'Crown Royal (album)': Crown Royal (album) (id: ??, ns: 0),
#  'Danceteria': Danceteria (id: ??, ns: 0),
#  'Darryl McDaniels': Darryl McDaniels (id: ??, ns: 0),
#  'David Toop': David Toop (id: ??, ns: 0),
#  'Def Jam Recordings': Def Jam Recordings (id: ??, ns: 0),
#  'Diggy Simmons': Diggy Simmons (id: ??, ns: 0),
#  'Disco': Disco (id: ??, ns: 0),
#  'Disco Fever': Disco Fever (id: ??, ns: 0),
#  'Discogs': Discogs (id: ??, ns: 0),
#  'Diss (music)': Diss (music) (id: ??, ns: 0),
#  'Distortion (Joseph Simmons album)': Distortion (Joseph Simmons album) (id: ??, ns: 0),
#  'Down with the King (album)': Down with the King (album) (id: ??, ns: 0),
#  'Down with the King (song)': Down with the King (song) (id: ??, ns: 0),
#  'Drum machine': Drum machine (id: ??, ns: 0),
#  'East Coast hip hop': East Coast hip hop (id: ??, ns: 0),
#  'Eddie Martinez (musician)': Eddie Martinez (musician) (id: ??, ns: 0),
#  'Eric Weisbard': Eric Weisbard (id: ??, ns: 0),
#  'Faces (Run-D.M.C. song)': Faces (Run-D.M.C. song) (id: ??, ns: 0),
#  'Gold certification': Gold certification (id: ??, ns: 0),
#  'Graffiti Rock': Graffiti Rock (id: ??, ns: 0),
#  'Grandmaster Flash and the Furious Five': Grandmaster Flash and the Furious Five (id: ??, ns: 0),
#  'Greatest Hits (Run-D.M.C. album)': Greatest Hits (Run-D.M.C. album) (id: ??, ns: 0),
#  'Greene St. Recording': Greene St. Recording (id: ??, ns: 0),
#  'Greg Kot': Greg Kot (id: ??, ns: 0),
#  'Greg Tate': Greg Tate (id: ??, ns: 0),
#  'Hard Times (Run-D.M.C. song)': Hard Times (Run-D.M.C. song) (id: ??, ns: 0),
#  'Hardcore hip hop': Hardcore hip hop (id: ??, ns: 0),
#  'Hardcore rap': Hardcore rap (id: ??, ns: 0),
#  'High Profile: The Original Rhymes': High Profile: The Original Rhymes (id: ??, ns: 0),
#  'Hip Hop Connection': Hip Hop Connection (id: ??, ns: 0),
#  'Hip hop music': Hip hop music (id: ??, ns: 0),
#  "I'm Not Going Out Like That": I'm Not Going Out Like That (id: ??, ns: 0),
#  'ISBN (identifier)': ISBN (identifier) (id: ??, ns: 0),
#  'Ice-T': Ice-T (id: ??, ns: 0),
#  "It's Like That (Run-D.M.C. song)": It's Like That (Run-D.M.C. song) (id: ??, ns: 0),
#  "It's Tricky": It's Tricky (id: ??, ns: 0),
#  'Jam Master Jay': Jam Master Jay (id: ??, ns: 0),
#  'Jason Mizell': Jason Mizell (id: ??, ns: 0),
#  'Joseph Simmons': Joseph Simmons (id: ??, ns: 0),
#  'King of Rock': King of Rock (id: ??, ns: 0),
#  'King of Rock (song)': King of Rock (song) (id: ??, ns: 0),
#  'Krush Groove': Krush Groove (id: ??, ns: 0),
#  'Larry Smith (producer)': Larry Smith (producer) (id: ??, ns: 0),
#  'List of music recording certifications': List of music recording certifications (id: ??, ns: 0),
#  'Live at Montreux 2001': Live at Montreux 2001 (id: ??, ns: 0),
#  'Lovebug Starski': Lovebug Starski (id: ??, ns: 0),
#  'MTV': MTV (id: ??, ns: 0),
#  'Mary, Mary (song)': Mary, Mary (song) (id: ??, ns: 0),
#  'Melle Mel': Melle Mel (id: ??, ns: 0),
#  'Mizell Brothers': Mizell Brothers (id: ??, ns: 0),
#  'Music genre': Music genre (id: ??, ns: 0),
#  'Muze': Muze (id: ??, ns: 0),
#  'My Adidas': My Adidas (id: ??, ns: 0),
#  'Myspace': Myspace (id: ??, ns: 0),
#  'NME': NME (id: ??, ns: 0),
#  'Nathan Brackett': Nathan Brackett (id: ??, ns: 0),
#  'New-school hip hop': New-school hip hop (id: ??, ns: 0),
#  'New school hip hop': New school hip hop (id: ??, ns: 0),
#  'Oberheim DMX': Oberheim DMX (id: ??, ns: 0),
#  'Old-school hip hop': Old-school hip hop (id: ??, ns: 0),
#  'Ooh, Whatcha Gonna Do': Ooh, Whatcha Gonna Do (id: ??, ns: 0),
#  'Pause (Run-D.M.C. song)': Pause (Run-D.M.C. song) (id: ??, ns: 0),
#  'Peter Shapiro (journalist)': Peter Shapiro (journalist) (id: ??, ns: 0),
#  'Pitchfork (website)': Pitchfork (website) (id: ??, ns: 0),
#  'Profile Records': Profile Records (id: ??, ns: 0),
#  'Raising Hell (album)': Raising Hell (album) (id: ??, ns: 0),
#  'RapGenius': RapGenius (id: ??, ns: 0),
#  'Rap rock': Rap rock (id: ??, ns: 0),
#  'Record Collector': Record Collector (id: ??, ns: 0),
#  'Record label': Record label (id: ??, ns: 0),
#  'Record producer': Record producer (id: ??, ns: 0),
#  'Recording Industry Association of America': Recording Industry Association of America (id: ??, ns: 0),
#  'Riff': Riff (id: ??, ns: 0),
#  'Robert Christgau': Robert Christgau (id: ??, ns: 0),
#  'Rock Box': Rock Box (id: ??, ns: 0),
#  'Rock music': Rock music (id: ??, ns: 0),
#  'Rolling Stone': Rolling Stone (id: ??, ns: 0),
#  "Rolling Stone's 500 Greatest Albums of All Time": Rolling Stone's 500 Greatest Albums of All Time (id: ??, ns: 0),
#  "Run's House": Run's House (id: ??, ns: 0),
#  "Run's House (song)": Run's House (song) (id: ??, ns: 0),
#  'Run-D.M.C.': Run-D.M.C. (id: ??, ns: 0),
#  'Run-DMC': Run-DMC (id: ??, ns: 0),
#  'Run-DMC discography': Run-DMC discography (id: ??, ns: 0),
#  'Russell Simmons': Russell Simmons (id: ??, ns: 0),
#  'Russell Simmons Music Group': Russell Simmons Music Group (id: ??, ns: 0),
#  'Scratching': Scratching (id: ??, ns: 0),
#  'Sequence (group)': Sequence (group) (id: ??, ns: 0),
#  "Serpent's Tail": Serpent's Tail (id: ??, ns: 0),
#  'Simon & Schuster': Simon & Schuster (id: ??, ns: 0),
#  'Single (music)': Single (music) (id: ??, ns: 0),
#  'Snare drum': Snare drum (id: ??, ns: 0),
#  'Spin (magazine)': Spin (magazine) (id: ??, ns: 0),
#  'Spin Alternative Record Guide': Spin Alternative Record Guide (id: ??, ns: 0),
#  'Stephen Thomas Erlewine': Stephen Thomas Erlewine (id: ??, ns: 0),
#  'Street style': Street style (id: ??, ns: 0),
#  'Studio album': Studio album (id: ??, ns: 0),
#  "Sucker M.C.'s": Sucker M.C.'s (id: ??, ns: 0),
#  'The Best of Run-DMC': The Best of Run-DMC (id: ??, ns: 0),
#  'The Essential Run-D.M.C.': The Essential Run-D.M.C. (id: ??, ns: 0),
#  'The Observer': The Observer (id: ??, ns: 0),
#  'The Rolling Stone Album Guide': The Rolling Stone Album Guide (id: ??, ns: 0),
#  'The Source': The Source (id: ??, ns: 0),
#  'The Source (magazine)': The Source (magazine) (id: ??, ns: 0),
#  'The Village Voice': The Village Voice (id: ??, ns: 0),
#  'Together Forever: Greatest Hits 1983–1991': Together Forever: Greatest Hits 1983–1991 (id: ??, ns: 0),
#  'Top R&B/Hip-Hop Albums': Top R&B/Hip-Hop Albums (id: ??, ns: 0),
#  'Top R&B/Hip Hop Albums': Top R&B/Hip Hop Albums (id: ??, ns: 0),
#  'Tougher Than Leather': Tougher Than Leather (id: ??, ns: 0),
#  'Ultimate Run-D.M.C.': Ultimate Run-D.M.C. (id: ??, ns: 0),
#  'Uncut (magazine)': Uncut (magazine) (id: ??, ns: 0),
#  'Vintage Books': Vintage Books (id: ??, ns: 0),
#  'Walk This Way': Walk This Way (id: ??, ns: 0),
#  'Walk This Way (Run-D.M.C. song)': Walk This Way (Run-D.M.C. song) (id: ??, ns: 0),
#  'Warner Bros.': Warner Bros. (id: ??, ns: 0),
#  "What's It All About (song)": What's It All About (song) (id: ??, ns: 0),
#  'William Waring': William Waring (id: ??, ns: 0),
#  'XXL (magazine)': XXL (magazine) (id: ??, ns: 0),
#  "You Be Illin'": You Be Illin' (id: ??, ns: 0),
#  'You Talk Too Much (Run-DMC song)': You Talk Too Much (Run-DMC song) (id: ??, ns: 0),
#  'Template:Run-DMC': Template:Run-DMC (id: ??, ns: 10),
#  'Template talk:Run-DMC': Template talk:Run-DMC (id: ??, ns: 11),
#  'Help:Authority control': Help:Authority control (id: ??, ns: 12),
#  'Category:Articles with MusicBrainz release group identifiers': Category:Articles with MusicBrainz release group identifiers (id: ??, ns: 14),
#  'Category:Use mdy dates from April 2021': Category:Use mdy dates from April 2021 (id: ??, ns: 14)}

# %%
# ?page
# Out:
# Type:        WikipediaPage
# String form: Run-D.M.C._(album) (id: ??, ns: 0)
# File:        ~/.local/lib/python3.11/site-packages/wikipediaapi/__init__.py
# Docstring:
# Represents Wikipedia page.
#
# Except properties mentioned as part of documentation, there are also
# these properties available:
#
# * `fullurl` - full URL of the page
# * `canonicalurl` - canonical URL of the page
# * `pageid` - id of the current page
# * `displaytitle` - title of the page to display
# * `talkid` - id of the page with discussion

# %%
# ?wiki_wiki.page
# Out:
# Signature:
# wiki_wiki.page(
#     title: str,
#     ns: Union[wikipediaapi.Namespace, int] = <Namespace.MAIN: 0>,
#     unquote: bool = False,
# ) -> 'WikipediaPage'
# Docstring:
# Constructs Wikipedia page with title `title`.
#
# Creating `WikipediaPage` object is always the first step for extracting
# any information.
#
# Example::
#
#     wiki_wiki = wikipediaapi.Wikipedia('en')
#     page_py = wiki_wiki.page('Python_(programming_language)')
#     print(page_py.title)
#     # Python (programming language)
#
#     wiki_hi = wikipediaapi.Wikipedia('hi')
#
#     page_hi_py = wiki_hi.article(
#         title='%E0%A4%AA%E0%A4%BE%E0%A4%87%E0%A4%A5%E0%A4%A8',
#         unquote=True,
#     )
#     print(page_hi_py.title)
#     # पाइथन
#
# :param title: page title as used in Wikipedia URL
# :param ns: :class:`WikiNamespace`
# :param unquote: if true it will unquote title
# :return: object representing :class:`WikipediaPage`
# File:      ~/.local/lib/python3.11/site-packages/wikipediaapi/__init__.py
# Type:      method

# %% [markdown]
# # Scratch

# %%
def get_linked_page_summary(topic):
    """
    Get the summary of a linked page
    """
    page = wiki_wiki.page(topic)
    summary = get_page_summary(current_page)
    return summary

def validate_pages(wiki_page):
    """
    Filters and validates the linked pages from a given Wikipedia page.

    This function takes a Wikipedia page object and extracts all the links (or references to other Wikipedia 
    pages) from it. It then filters out unwanted links based on predefined criteria, such as links with 
    certain prefixes (like "Template:", "Wikipedia:", etc.) and links that do not contain any alphabetical 
    characters. The purpose is to retain only relevant and potentially useful page links for further processing.

    Parameters
    ----------
    wiki_page : WikipediaPage object
        A Wikipedia page object from which the links are to be extracted and validated. The object is 
        expected to have a 'links' attribute containing a dictionary of linked page titles.

    Returns
    -------
    list
        A list of validated linked page titles. The titles in this list do not include any of the unwanted 
        prefixes and contain at least one alphabetical character.
    """
    # get all links
    links = list(wiki_page.links.keys())

    # various unwanted prefixes
    bad_prefixes = ["list of", "history of", "Template:", "Wikipedia:", "Category:", "Portal:", "Talk:", "Template talk:"]
    links = [link for link in links 
        if not any(link.lower().startswith(prefix.lower()) for prefix in bad_prefixes) 
        and any(char.isalpha() for char in link)
    ]
    return links

# %%
def generate_random_string(length):
    characters = string.ascii_letters + string.digits
    random_string = ''.join(random.choice(characters) for _ in range(length))
    return random_string

# %%
def get_random_wiki_page(wiki_wiki):
    """
    Selects a random Wikipedia page that meets certain validity criteria.

    This function repeatedly requests random Wikipedia pages until it finds one that satisfies specific 
    criteria: the title should not start with certain prefixes (like "Template:", "List of", etc.), should 
    not contain certain unwanted characters, and must contain at least one alphabetical character. The 
    function also checks if the page has a reasonable summary (at least 20 words) before accepting it.

    Returns
    -------
    str
        The title of a valid random Wikipedia page.
    """
    wiki_title = None
    while True:
        url = "https://en.wikipedia.org/wiki/Special:Random"
        response = requests.get(url, timeout = 30, allow_redirects = True)
        final_url = response.url
        wiki_title = final_url.split("wiki/")[-1]
        is_valid_title = True

        # various unwanted prefixes
        bad_prefixes = ["list of", "history of", "Template:", "Wikipedia:", "Category:", "Portal:", "Talk:", "Template talk:"]

        # check for unwanted chars
        for char in "[]{}:%":
            if char in wiki_title:
                is_valid_title = False
        
        # validation criteria
        starts_with_bad_prefix = any(wiki_title.lower().startswith(prefix.lower()) for prefix in bad_prefixes)
        contains_alpha = any(char.isalpha() for char in wiki_title)
        is_valid_title = not starts_with_bad_prefix and contains_alpha

        if is_valid_title:

            # check if a reasonable page summary is present (at least 20 words)
            summary = get_page_summary(wiki_wiki.page(wiki_title))
            if len(summary.split()) > 20:
                break

    return wiki_title
