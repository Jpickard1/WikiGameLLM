# %% [markdown]
# # Code to Play

# %%
import os
import numpy as np
import pandas as pd
import getpass
import difflib
import requests
import random
import string
import wikipediaapi
import logging

from bs4 import BeautifulSoup
from sentence_transformers import SentenceTransformer
from scipy.spatial.distance import cosine

from langchain_nvidia_ai_endpoints import NVIDIAEmbeddings, ChatNVIDIA
from langchain.memory import ConversationBufferMemory
# Out:
# /home/jpic/.local/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
log = logging.getLogger(__name__)
logging.basicConfig(level=os.environ.get("LOGLEVEL", "INFO"))
log.info('What is up?!')
# Out:
# INFO:__main__:What is up?!

# %% [markdown]
# ## Funcs

# %%
def get_page_summary(wiki_page):
    """
    Retrieves a brief summary of a given Wikipedia page.

    This function takes a Wikipedia page object and returns the summary of the page. However, rather than 
    returning the entire summary, it returns only the first few lines. This is particularly useful for 
    getting a quick overview or introduction to the page's content without needing to process the entire 
    summary text.

    Parameters
    ----------
    wiki_page : WikipediaPage object
        A Wikipedia page object from which the summary is to be extracted. The object should have a 'summary' 
        attribute containing the text of the page's summary.

    Returns
    -------
    str
        A string containing the first few lines of the Wikipedia page's summary. The exact number of lines 
        returned is set to 5 in this implementation.
    """
    # return just the first few lines if there are multiple
    return wiki_page.summary[:100] + "..."
    # return ". ".join(wiki_page.summary.split("\n")[:1]) + "..."

def search_wiki(search_term):
    """Search common name for search term and returns most relevant Wiki Page"""
    search_url = f"https://en.wikipedia.org/w/index.php?search={'+'.join(search_term.split())}&title=Special:Search&profile=advanced&fulltext=1&ns0=1"
    soup = BeautifulSoup(requests.get(search_url, timeout=30).content, "html.parser")
    bad_prefixes = ["list of", "history of", "Template:", "Wikipedia:", "Category:", "Portal:", "Talk:", "Template talk:"]
    for result in soup.find_all("div", class_ = "mw-search-result-heading"):
        if result.a:
            if result.a['href']:
                text = result.a['href'].replace("/wiki/", "").strip()
                starts_with_bad_prefix = any(text.lower().replace("_", " ").startswith(prefix.lower()) for prefix in bad_prefixes)
                if not starts_with_bad_prefix:
                    return text

def getWikiTemplate():
    template = """You must are playing the Wikipedia Game where you must find a chain of
Wikipedia pages that connect a source topic to a target topic. Your current topic is {current} and
you must select a new wikipedia page closer to the target topic {target1}. You can select a topic from
the following list:

{{links}}

If the target topic of {target2} is available, you should select the target topic {target3}. Otherwise, select
a next topic that is likely to be closer or fewer connections to the topic {target4}. If no topics appear relevant
you must still choose a topic to do next. You cannot say None. You have already visited the following pages,
which should be avoided in the future:

{visited}

Format your output as:
Next topic=<topic here>
"""
    return template

# %%
search_wiki('python programming langugae')
# Out:
# 'Python_(programming_language)'

# %% [markdown]
# ## LLM Bot

# %%
class WikiGameLLMBot():
    def __init__(self, wiki_wiki,
                 start_topic = None,
                 target_topic = None,
                 model_name='meta/llama3-70b-instruct',
                 temperature=0.1,
                 rag=True
                ):

        assert start_topic != target_topic, "Please enter different start and target topics."
        
        ################################################################
        #
        #    Save some things
        #
        ################################################################
        
        self.wiki_wiki     = wiki_wiki
        self.start_topic   = start_topic
        self.target_topic  = target_topic
        self.target_page   = self.wiki_wiki.page(self.target_topic)
        self.start_page    = self.wiki_wiki.page(self.start_topic)
        self.current_topic = self.start_page
        self.current_page  = self.start_page
        self.visited       = [self.start_page]
        self.rag           = rag

        ################################################################
        #
        #    Load NVIDIA model and chatbot history
        #
        ################################################################

        if not os.environ.get("NVIDIA_API_KEY", "").startswith("nvapi-"):
            nvidia_api_key = getpass.getpass("Enter your NVIDIA API key: ")
            assert nvidia_api_key.startswith("nvapi-"), f"{nvidia_api_key[:5]}... is not a valid key"
            os.environ["NVIDIA_API_KEY"] = nvidia_api_key
        else:
            nvidia_api_key = os.environ["NVIDIA_API_KEY"]
            
        self.llm = ChatNVIDIA(model       = model_name,
                              api_key     = nvidia_api_key,
                              temperature = temperature,
                             )
        self.memory = ConversationBufferMemory(ai_prefix="System")

    def get_filled_templates(self, alltitles, allsummaries):
        i = 0
        k = 100 # batch size
        templates, titles, summaries  = [], [], []
        while i < len(alltitles):
            titlesTemplate    = alltitles[i:i+k]
            titles.append(titlesTemplate)
            if self.rag:
                summariesTemplate = allsummaries[i:i+k]
                summaries.append(summariesTemplate)
                templates.append(self.get_filled_template(titlesTemplate, summaries=summariesTemplate))
            else:
                templates.append(self.get_filled_template(titlesTemplate))
            i += k
        return templates, titles, summaries
    
    def get_filled_template(self, titles, summaries=None):
        template = getWikiTemplate()
        visitedPages = ""
        for pg in self.visited:
            visitedPages += '- ' + str(pg.title) + '\n'
        template = template.format(target1 = self.target_topic,
                                   target2 = self.target_topic,
                                   target3 = self.target_topic,
                                   target4 = self.target_topic,
                                   current = self.current_topic,
                                   visited = visitedPages
                                  )
        if self.rag:
            link_table = """Topic\tDescription
--------\t-----------
"""
            for i in range(len(titles)):
                link_table += ("title:" + titles[i] + '\t' + summaries[i] + '\n')
        else:
            link_table = """Topic
----------
"""
            for i in range(len(titles)):
                link_table += ("title:" + titles[i] + '\n')

        template = template.format(links = link_table)
        return template
    
    def take_turn(self):
        # Get all linked pages
        print(type(self.current_page))
        page_titles = list(self.current_page.links)

        badpages = ['Category', 'Help', 'Wikipedia', 'Portal', 'List', 'Talk', 'Template']
        badpages_lower = [bad.lower() for bad in badpages]
        page_titles = [title for title in page_titles if not any(title.lower().startswith(bad) for bad in badpages_lower)]
        
        pages = []
        if self.rag:
            print('Got all titles')
            for i, title in enumerate(page_titles):
                print(title + '\t\t' + str(i) + '/' + str(len(page_titles)))
                pages.append(self.wiki_wiki.page(title))
    
            # get the summaries of these pages
            titles, summaries = [], []
            page_title_lookup = {}
            for page in pages:
                titles.append(page.title)
                summaries.append(get_page_summary(page))
                page_title_lookup[titles[-1]] = page
        else:
            titles = page_titles
            summaries = []
            page_title_lookup = []

        print(f'len(titles)={len(titles)}')
        print(f'len(summaries)={len(summaries)}')
        if self.rag:
            print(f'len(page_title_lookup.keys())={len(page_title_lookup.keys())}')

        if self.rag:
            print('page_title_lookup.keys()')
            print(list(page_title_lookup.keys()))

        templates, titleSets, summarySets = self.get_filled_templates(titles, summaries)
        bestTitles, bestSummaries = [], []
        for i in range(len(templates)):
            template = templates[i]

#            print('\n\n\n')
            print("Template")
            print(template)
#            print('\n\n\n')            
            print('Title Set')
            print(titleSets)
#            print('\n\n\n')

            response = self.llm.invoke(template)
            print("Response")
            print(response)
#            print('\n\n\n')
            print("Parsed Response")
            proposedPage = response.content.split('=')[1]
            print(proposedPage)
#            print('\n\n\n')

            print("Most similar page")
            most_similar = difflib.get_close_matches(proposedPage, titleSets[i], n=1)[0]
            print(most_similar)
#            print('\n\n\n')
            print('\n\n\n')

            bestTitles.append(most_similar)
            if self.rag:
                bestSummaries.append(get_page_summary(page_title_lookup[most_similar]))

        # reduce it further
        if len(bestTitles) > 1:
            template = self.get_filled_template(bestTitles, bestSummaries)
            print('Map Reduce Template')
            print(template)
            response = self.llm.invoke(template)

            print("Response")
            print(response)

            print("Parsed Response")
            proposedPage = response.content.split('=')[1]
            print(proposedPage)
            
            print("Most similar page")
            most_similar = difflib.get_close_matches(proposedPage, bestTitles, n=1)[0]
        else:
            most_similar = bestTitles[0]
            
        # reset the current page
        print('Selected Page')
        print(most_similar)
        if self.rag:
            self.current_page = page_title_lookup[most_similar]
        else:
            self.current_page = self.wiki_wiki.page(most_similar)

        self.visited.append(self.current_page)
        
        if self.target_page.fullurl == self.current_page.fullurl:
            return True

        return False

# %% [markdown]
# # Play Game

# %%
global wiki_wiki
random_string = 'XXX' # generate_random_string(10)
wiki_wiki = wikipediaapi.Wikipedia(
    f'WikiBot-{random_string} (https://www.linkedin.com/in/kmaurinjones/)',
    'en',
    timeout = 30
    )
# Out:
# INFO:wikipediaapi:Wikipedia: language=en, user_agent: WikiBot-XXX (https://www.linkedin.com/in/kmaurinjones/) (Wikipedia-API/0.6.0; https://github.com/martin-majlis/Wikipedia-API/), extract_format=1

# %%
bot = WikiGameLLMBot(wiki_wiki,
                 start_topic = 'Hot air balloon',
                 target_topic = 'CRISPR',
                 model_name='meta/llama3-70b-instruct',
                 temperature=0.1,
                 rag=False)
# Out:
# Enter your NVIDIA API key:  ········

# %%
found = False
i = 0
while not found:
    found = bot.take_turn()
    print(bot.current_page.title)
    i += 1
    if i > 25:
        break
# Out:
# <class 'wikipediaapi.WikipediaPage'>
# len(titles)=427
# len(summaries)=0
# Template
# You must are playing the Wikipedia Game where you must find a chain of
# Wikipedia pages that connect a source topic to a target topic. Your current topic is Hot air balloon (id: 38173, ns: 0) and
# you must select a new wikipedia page closer to the target topic CRISPR. You can select a topic from
# the following list:
#
# Topic
# ----------
# title:1,4-Butanediol
# title:Abattoir
# title:Abiogenesis
# title:Abiotic stress
# title:Acetone
# title:Adaptation
# title:Adverse effect (medicine)
# title:Aerobiology
# title:Agricultural science
# title:Agriculture
# title:Agronomy
# title:Agrostology
# title:Alexander Fleming
# title:Allele
# title:Altricial
# title:American Chemical Society
# title:Ananda Mohan Chakrabarty
# title:Anatomy
# title:Ancestry
# title:Animal cell culture
# title:Animals
# title:Antibiotic
# title:Antibodies
# title:Antibody
# title:Applied Science and Convergence Technology
# title:Archaea
# title:Argentina
# title:Astrobiology
# title:Bachelor of Science
# title:Bacteria
# title:Bacteriology
# title:Basic research
# title:Beer
# title:Bibcode (identifier)
# title:Bio-FET
# title:Biobased economy
# title:Biochemical
# title:Biochemical engineering
# title:Biochemistry
# title:Biodegradable plastic
# title:Biodegradation
# title:Biodiversity
# title:Biodiversity loss
# title:Bioelectronics
# title:Bioengineering
# title:Biofabrication
# title:Biofilter
# title:Biofortification
# title:Biofuel
# title:Biogeography
# title:Biogeology
# title:Bioinformatics
# title:Bioleaching
# title:Biological
# title:Biological engineering
# title:Biological warfare
# title:Biological weapons
# title:Biologist
# title:Biology
# title:Biomarker
# title:Biomass
# title:Biomechanics
# title:Biomedical
# title:Biomedical engineering
# title:Biomedical sciences
# title:Biomedicine
# title:Biomimetics
# title:Bionic architecture
# title:Biopharmaceutical
# title:Biopharmaceutics
# title:Biophysics
# title:Bioproduction
# title:Bioreactor
# title:Bioremediation
# title:Biorobotics
# title:Biosemiotics
# title:Biosensor
# title:Biostatistics
# title:Biosynthesis
# title:Biotechnology (disambiguation)
# title:Biotechnology industrial park
# title:Biotechnology law
# title:Biotechnology products
# title:Biotechnology risk
# title:Bioterrorism
# title:Biotic stress
# title:Blood
# title:Botany
# title:Brazil
# title:Brewing
# title:British Medical Association
# title:CRISPR gene editing
# title:CRISPR interference
# title:Calgene
# title:Canola
# title:Carbohydrate
# title:Cash crop
# title:Catalyst
# title:Cell (biology)
# title:Cell biology
#
#
# If the target topic of CRISPR is available, you should select the target topic CRISPR. Otherwise, select
# a next topic that is likely to be closer or fewer connections to the topic CRISPR. If no topics appear relevant
# you must still choose a topic to do next. You cannot say None. You have already visited the following pages,
# which should be avoided in the future:
#
# - Hot air balloon
# - Altimeter
# - Barometer
# - Weather forecasting
# - Thermodynamics
# - Science
# - Biology
# - Molecular biology
# - Molecular genetics
# - Genetic engineering
# - Polymerase chain reaction
# - Thermus aquaticus
# - Biotechnology
#
#
# Format your output as:
# Next topic=<topic here>
#
# Title Set
# [['1,4-Butanediol', 'Abattoir', 'Abiogenesis', 'Abiotic stress', 'Acetone', 'Adaptation', 'Adverse effect (medicine)', 'Aerobiology', 'Agricultural science', 'Agriculture', 'Agronomy', 'Agrostology', 'Alexander Fleming', 'Allele', 'Altricial', 'American Chemical Society', 'Ananda Mohan Chakrabarty', 'Anatomy', 'Ancestry', 'Animal cell culture', 'Animals', 'Antibiotic', 'Antibodies', 'Antibody', 'Applied Science and Convergence Technology', 'Archaea', 'Argentina', 'Astrobiology', 'Bachelor of Science', 'Bacteria', 'Bacteriology', 'Basic research', 'Beer', 'Bibcode (identifier)', 'Bio-FET', 'Biobased economy', 'Biochemical', 'Biochemical engineering', 'Biochemistry', 'Biodegradable plastic', 'Biodegradation', 'Biodiversity', 'Biodiversity loss', 'Bioelectronics', 'Bioengineering', 'Biofabrication', 'Biofilter', 'Biofortification', 'Biofuel', 'Biogeography', 'Biogeology', 'Bioinformatics', 'Bioleaching', 'Biological', 'Biological engineering', 'Biological warfare', 'Biological weapons', 'Biologist', 'Biology', 'Biomarker', 'Biomass', 'Biomechanics', 'Biomedical', 'Biomedical engineering', 'Biomedical sciences', 'Biomedicine', 'Biomimetics', 'Bionic architecture', 'Biopharmaceutical', 'Biopharmaceutics', 'Biophysics', 'Bioproduction', 'Bioreactor', 'Bioremediation', 'Biorobotics', 'Biosemiotics', 'Biosensor', 'Biostatistics', 'Biosynthesis', 'Biotechnology (disambiguation)', 'Biotechnology industrial park', 'Biotechnology law', 'Biotechnology products', 'Biotechnology risk', 'Bioterrorism', 'Biotic stress', 'Blood', 'Botany', 'Brazil', 'Brewing', 'British Medical Association', 'CRISPR gene editing', 'CRISPR interference', 'Calgene', 'Canola', 'Carbohydrate', 'Cash crop', 'Catalyst', 'Cell (biology)', 'Cell biology'], ['Cell culture', 'Cell immunity', 'Cell theory', 'Cellular microbiology', 'Centrifugation', 'Cereal', 'Chaim Weizmann', 'Charles Darwin', 'Cheesemaking', 'Chemical biology', 'Chemical engineering', 'Chemical field-effect transistor', 'Chemistry', 'Chemotherapeutic agent', 'China', 'Chromatography', 'Chromosomes', 'Chronobiology', 'CityTrees', 'Cloning', 'Clostridium acetobutylicum', 'Cognitive biology', 'Colors of biotechnology', 'Competitions and prizes in biotechnology', 'Computational biology', 'Computer History Museum', 'Conservation biology', 'Continuous stirred-tank reactor', 'Corn starch', 'Cotton seed oil', 'Cryobiology', 'Crystallization', 'Cultured meat', 'Cytogenetics', 'DNA', 'DNA field-effect transistor', 'DNA hybridization', 'DNA microarray', 'DSTR', 'Daniel A. Vallero', 'Dawon Kahng', 'Dendrology', 'Desert', 'Desert climate', 'Developmental biology', 'Diagnostic tests', 'Diamond v. Chakrabarty', 'Diseases', 'Doi (identifier)', 'Domain (biology)', 'Domestication', 'EUginius', 'Ecological genetics', 'Ecology', 'Ecosystem', 'Efficacy', 'Egypt', 'Electrolyte', 'Electronics Letters', 'Electrophoresis', 'Embryology', 'Engineering', 'Engineering Science', 'Environmental biotechnology', 'Environmental science', 'Environmentally friendly', 'Enzyme', 'Epidemiology', 'Epigenetics', 'Escherichia coli', 'Ethanol', 'Eukaryote', 'European Federation of Biotechnology', 'European Union', 'Evolution', 'Evolutionary biology', 'Explosive', 'Extraction (chemistry)', 'Fed-batch culture', 'Fermentation', 'Fertilize', 'Filtration', 'Flavr Savr', 'Flow cytometry', 'Food industry', 'Freshwater biology', 'Functional genomics', 'Fungi', 'Gas sensor', 'Gene', 'Gene expression', 'Gene knock-in', 'Gene knockdown', 'Gene knockout', 'Gene therapy', 'Genentech', 'General Electric', 'Generative biology', 'Genetic Modification', 'Genetic counseling'], ['Genetic disorder', 'Genetic engineering', 'Genetic technology', 'Genetic testing', 'Genetically modified', 'Genetically modified crops', 'Genetically modified fish', 'Genetically modified food', 'Genetically modified organism', 'Genetics', 'Genome editing', 'Genomics', 'Genotype', 'Geobiology', 'Gerontology', 'Glossary of biology', 'Glucose', 'Golden rice', 'Graduate students', 'Green Revo ...
# Response
# content='Next topic=Genetic engineering' response_metadata={'role': 'assistant', 'content': 'Next topic=Genetic engineering', 'token_usage': {'prompt_tokens': 822, 'total_tokens': 829, 'completion_tokens': 7}, 'model_name': 'meta/llama3-70b-instruct'} id='run-e72ac7b6-4ef2-48c2-ac27-9458bbf39db2-0' role='assistant'
# Parsed Response
# Genetic engineering
# Most similar page
# Biomedical engineering
#
#
#
#
# Template
# You must are playing the Wikipedia Game where you must find a chain of
# Wikipedia pages that connect a source topic to a target topic. Your current topic is Hot air balloon (id: 38173, ns: 0) and
# you must select a new wikipedia page closer to the target topic CRISPR. You can select a topic from
# the following list:
#
# Topic
# ----------
# title:Cell culture
# title:Cell immunity
# title:Cell theory
# title:Cellular microbiology
# title:Centrifugation
# title:Cereal
# title:Chaim Weizmann
# title:Charles Darwin
# title:Cheesemaking
# title:Chemical biology
# title:Chemical engineering
# title:Chemical field-effect transistor
# title:Chemistry
# title:Chemotherapeutic agent
# title:China
# title:Chromatography
# title:Chromosomes
# title:Chronobiology
# title:CityTrees
# title:Cloning
# title:Clostridium acetobutylicum
# title:Cognitive biology
# title:Colors of biotechnology
# title:Competitions and prizes in biotechnology
# title:Computational biology
# title:Computer History Museum
# title:Conservation biology
# title:Continuous stirred-tank reactor
# title:Corn starch
# title:Cotton seed oil
# title:Cryobiology
# title:Crystallization
# title:Cultured meat
# title:Cytogenetics
# title:DNA
# title:DNA field-effect transistor
# title:DNA hybridization
# title:DNA microarray
# title:DSTR
# title:Daniel A. Vallero
# title:Dawon Kahng
# title:Dendrology
# title:Desert
# title:Desert climate
# title:Developmental biology
# title:Diagnostic tests
# title:Diamond v. Chakrabarty
# title:Diseases
# title:Doi (identifier)
# title:Domain (biology)
# title:Domestication
# title:EUginius
# title:Ecological genetics
# title:Ecology
# title:Ecosystem
# title:Efficacy
# title:Egypt
# title:Electrolyte
# title:Electronics Letters
# title:Electrophoresis
# title:Embryology
# title:Engineering
# title:Engineering Science
# title:Environmental biotechnology
# title:Environmental science
# title:Environmentally friendly
# title:Enzyme
# title:Epidemiology
# title:Epigenetics
# title:Escherichia coli
# title:Ethanol
# title:Eukaryote
# title:European Federation of Biotechnology
# title:European Union
# title:Evolution
# title:Evolutionary biology
# title:Explosive
# title:Extraction (chemistry)
# title:Fed-batch culture
# title:Fermentation
# title:Fertilize
# title:Filtration
# title:Flavr Savr
# title:Flow cytometry
# title:Food industry
# title:Freshwater biology
# title:Functional genomics
# title:Fungi
# title:Gas sensor
# title:Gene
# title:Gene expression
# title:Gene knock-in
# title:Gene knockdown
# title:Gene knockout
# title:Gene therapy
# title:Genentech
# title:General Electric
# title:Generative biology
# title:Genetic Modification
# title:Genetic counseling
#
#
# If the target topic of CRISPR is available, you should select the target topic CRISPR. Otherwise, select
# a next topic that is likely to be closer or fewer connections to the topic CRISPR. If no topics appear relevant
# you must still choose a topic to do next. You cannot say None. You have already visited the following pages,
# which should be avoided in the future:
#
# - Hot air balloon
# - Altimeter
# - Barometer
# - Weather forecasting
# - Thermodynamics
# - Science
# - Biology
# - Molecular biology
# - Molecular genetics
# - Genetic engineering
# - Polymerase chain reaction
# - Thermus aquaticus
# - Biotechnology
#
#
# Format your output as:
# Next topic=<topic here>
#
# Title Set
# [['1,4-Butanediol', 'Abattoir', 'Abiogenesis', 'Abiotic stress', 'Acetone', 'Adaptation', 'Adverse effect (medicine)', 'Aerobiology', 'Agricultural science', 'Agriculture', 'Agronomy', 'Agrostology', 'Alexander Fleming', 'Allele', 'Altricial', 'American Chemical Society', 'Ananda Mohan Chakrabarty', 'Anatomy', 'Ancestry', 'Animal cell culture', 'Animals', 'Antibiotic', 'Antibodies', 'Antibody', 'Applied Science and Convergence Technology', 'Archaea', 'Argentina', 'Astrobiology', 'Bachelor of Science', 'Bacteria', 'Bacteriology', 'Basic research', 'Beer', 'Bibcode (identifier)', 'Bio-FET', 'Biobased economy', 'Biochemical', 'Biochemical engineering', 'Biochemistry', 'Biodegradable plastic', 'Biodegradation', 'Biodiversity', 'Biodiversity loss', 'Bioelectronics', 'Bioengineering', 'Biofabrication', 'Biofilter', 'Biofortification', 'Biofuel', 'Biogeography', 'Biogeology', 'Bioinformatics', 'Bioleaching', 'Biological', 'Biological engineering', 'Biological warfare', 'Biological weapons', 'Biologist', 'Biology', 'Biomarker', 'Biomass', 'Biomechanics', 'Biomedical', 'Biomedical engineering', 'Biomedical sciences', 'Biomedicine', 'Biomimetics', 'Bionic architecture', 'Biopharmaceutical', 'Biopharmaceutics', 'Biophysics', 'Bioproduction', 'Bioreactor', 'Bioremediation', 'Biorobotics', 'Biosemiotics', 'Biosensor', 'Biostatistics', 'Biosynthesis', 'Biotechnology (disambiguation)', 'Biotechnology industrial park', 'Biotechnology law', 'Biotechnology products', 'Biotechnology risk', 'Bioterrorism', 'Biotic stress', 'Blood', 'Botany', 'Brazil', 'Brewing', 'British Medical Association', 'CRISPR gene editing', 'CRISPR interference', 'Calgene', 'Canola', 'Carbohydrate', 'Cash crop', 'Catalyst', 'Cell (biology)', 'Cell biology'], ['Cell culture', 'Cell immunity', 'Cell theory', 'Cellular microbiology', 'Centrifugation', 'Cereal', 'Chaim Weizmann', 'Charles Darwin', 'Cheesemaking', 'Chemical biology', 'Chemical engineering', 'Chemical field-effect transistor', 'Chemistry', 'Chemotherapeutic agent', 'China', 'Chromatography', 'Chromosomes', 'Chronobiology', 'CityTrees', 'Cloning', 'Clostridium acetobutylicum', 'Cognitive biology', 'Colors of biotechnology', 'Competitions and prizes in biotechnology', 'Computational biology', 'Computer History Museum', 'Conservation biology', 'Continuous stirred-tank reactor', 'Corn starch', 'Cotton seed oil', 'Cryobiology', 'Crystallization', 'Cultured meat', 'Cytogenetics', 'DNA', 'DNA field-effect transistor', 'DNA hybridization', 'DNA microarray', 'DSTR', 'Daniel A. Vallero', 'Dawon Kahng', 'Dendrology', 'Desert', 'Desert climate', 'Developmental biology', 'Diagnostic tests', 'Diamond v. Chakrabarty', 'Diseases', 'Doi (identifier)', 'Domain (biology)', 'Domestication', 'EUginius', 'Ecological genetics', 'Ecology', 'Ecosystem', 'Efficacy', 'Egypt', 'Electrolyte', 'Electronics Letters', 'Electrophoresis', 'Embryology', 'Engineering', 'Engineering Science', 'Environmental biotechnology', 'Environmental science', 'Environmentally friendly', 'Enzyme', 'Epidemiology', 'Epigenetics', 'Escherichia coli', 'Ethanol', 'Eukaryote', 'European Federation of Biotechnology', 'European Union', 'Evolution', 'Evolutionary biology', 'Explosive', 'Extraction (chemistry)', 'Fed-batch culture', 'Fermentation', 'Fertilize', 'Filtration', 'Flavr Savr', 'Flow cytometry', 'Food industry', 'Freshwater biology', 'Functional genomics', 'Fungi', 'Gas sensor', 'Gene', 'Gene expression', 'Gene knock-in', 'Gene knockdown', 'Gene knockout', 'Gene therapy', 'Genentech', 'General Electric', 'Generative biology', 'Genetic Modification', 'Genetic counseling'], ['Genetic disorder', 'Genetic engineering', 'Genetic technology', 'Genetic testing', 'Genetically modified', 'Genetically modified crops', 'Genetically modified fish', 'Genetically modified food', 'Genetically modified organism', 'Genetics', 'Genome editing', 'Genomics', 'Genotype', 'Geobiology', 'Gerontology', 'Glossary of biology', 'Glucose', 'Golden rice', 'Graduate students', 'Green Revo ...
# Response
# content='Next topic=Gene editing' response_metadata={'role': 'assistant', 'content': 'Next topic=Gene editing', 'token_usage': {'prompt_tokens': 833, 'total_tokens': 839, 'completion_tokens': 6}, 'model_name': 'meta/llama3-70b-instruct'} id='run-e52825ae-97bb-4658-992b-70aa8ba2ce02-0' role='assistant'
# Parsed Response
# Gene editing
# Most similar page
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 4
#       2 i = 0
#       3 while not found:
# ----> 4     found = bot.take_turn()
#       5     print(bot.current_page.title)
#       6     i += 1
#
# Cell In[4], line 151, in WikiGameLLMBot.take_turn(self)
#     148 #            print('\n\n\n')
#     150             print("Most similar page")
# --> 151             most_similar = difflib.get_close_matches(proposedPage, titleSets[i], n=1)[0]
#     152             print(most_similar)
#     153 #            print('\n\n\n')
#
# IndexError: list index out of range

# %%
bot.visited
# Out:
# [Hot air balloon (id: 38173, ns: 0),
#  Altimeter (id: 47476, ns: 0),
#  Barometer (id: 47488, ns: 0),
#  Weather forecasting (id: 73231, ns: 0),
#  Thermodynamics (id: 29952, ns: 0),
#  Science (id: 26700, ns: 0),
#  Biology (id: 9127632, ns: 0),
#  Molecular biology (id: 19200, ns: 0),
#  Molecular genetics (id: 339838, ns: 0),
#  Genetic engineering (id: 12383, ns: 0),
#  Polymerase chain reaction (id: 23647, ns: 0),
#  Thermus aquaticus (id: 542410, ns: 0),
#  Biotechnology (id: 4502, ns: 0)]
